# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#sns.set() # to change theme

#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
activity = pd.read_excel('/Users/raphael/Documents/STENDO-activities/activity.xlsx')

# %% [markdown]
# # Travail en arrière plan

# %%
print('activity shape =', activity.shape)
# Out:
# activity shape = (522270, 15)

# %%
activity
# Out:
#               mac_address                          full_name  \
# 0       C0:29:34:FA:07:8B  C0:29:34:FA:07:8B 4002-0421-00203
# 1       D7:5F:AD:57:AA:38  D7:5F:AD:57:AA:38 4002-0421-00201
# 2       EA:4B:F5:67:30:F9  EA:4B:F5:67:30:F9 4002-0421-00192
# 3       C6:64:81:41:DD:33  C6:64:81:41:DD:33 4002-0721-00223
# 4       f3:0e:8d:37:39:31  f3:0e:8d:37:39:31 4001-1220-00171
# ...                   ...                                ...
# 522265  EA:1E:CF:41:CE:0B  EA:1E:CF:41:CE:0B 4002-0920-00136
# 522266  FC:83:FD:79:73:82  FC:83:FD:79:73:82 4002-0221-00187
# 522267  C0:29:34:FA:07:8B  C0:29:34:FA:07:8B 4002-0421-00203
# 522268  C0:29:34:FA:07:8B  C0:29:34:FA:07:8B 4002-0421-00203
# 522269  C0:29:34:FA:07:8B  C0:29:34:FA:07:8B 4002-0421-00203
#
#                          name                                   full_name.1  \
# 0       Charbonnier-Montaudié  T0649 - Marie-Caroline CHARBONNIER MONTAUDIE
# 1           Claire BARRILLIET                     T0723 - Claire BARRILLIET
# 2          Silver Form Alsace                         T0627 - CAPITAL SANTE
# 3              SCM TRIQUETRUM                        T0792 - SCM TRIQUETRUM
# 4                       Marro                       T0610 - Marro Joséphine
# ...                       ...                                           ...
# 522265                 Ganier                         T0417 - GANIER Nicole
# 522266        Aqua Kiné Santé                       T0613 - Aqua Kiné Santé
# 522267  Charbonnier-Montaudié  T0649 - Marie-Caroline CHARBONNIER MONTAUDIE
# 522268  Charbonnier-Montaudié  T0649 - Marie-Caroline CHARBONNIER MONTAUDIE
# 522269  Charbonnier-Montaudié  T0649 - Marie-Caroline CHARBONNIER MONTAUDIE
#
#        spare_type                  start_date  duration  real_duration  \
# 0           pants  2021-10-28 09:47:57.000000        20              0
# 1           pants  2021-10-28 10:19:38.000000        30              0
# 2           pants  2021-10-28 09:42:49.000000        30           1800
# 3           pants  2021-10-28 10:01:53.000000        20           1200
# 4           pants  2021-10-28 09:51:52.000000        20           1200
# ...           ...                         ...       ...            ...
# 522265      pants  2021-10-28 09:09:39.000000        20           1200
# 522266      pants  2021-10-28 09:27:45.000000        20           1200
# 522267      pants  2021-10-28 09:41:06.000000        20              0
# 522268      pants  2021-10-28 09:42:23.000000        20              0
# 522269      pants  2021-10-28 09:44:09.000000        20              0
#
#         percentage_real_duration  care_note ps_server economic_model  \
# 0                            0.0          0        EU      UNLIMITED
# 1                            0.0          0        EU      UNLIMITED
# 2                          100.0          0        EU      UNLIMITED
# 3                          100.0          0        EU      UNLIMITED
# 4                          100.0          0        EU      UNLIMITED
# ...                          ...        ...       ...            ...
# 522265                     100.0          5        EU      UNLIMITED
# 522266                     100.0          5        EU      UNLIMITED
# 522267                       0.0          0        EU      UNLIMITED
# 522268                       0.0          0        EU      UNLIMITED
# 522269                       0.0          0        EU      UNLIMITED
#
#         credit_number full_name.2  active
# 0                   1   Chronique    True
# 1                   1  Entretien1    True
# 2                   1       Mixte    True
# 3                   1   Chronique    True
# 4                   1        -12h    True
# ...               ...         ...     ...
# 522265              1       Détox    True
# 522266              1   Chronique    True
# 522267              1   Chronique    True
# 522268              1   Chronique    True
# 522269              1   Chronique    True
#
# [522270 rows x 15 columns]

# %%
activity.isna().sum()
# Out:
# mac_address                     0
# full_name                       0
# name                            0
# full_name.1                     0
# spare_type                      0
# start_date                      0
# duration                        0
# real_duration                   0
# percentage_real_duration    30003
# care_note                       0
# ps_server                       0
# economic_model                  0
# credit_number                   0
# full_name.2                     0
# active                          0
# dtype: int64

# %%
#activity[activity['percentage_real_duration'].isna()]

# %%
activity['percentage_real_duration'] = activity['real_duration'] / (activity['duration'] * 60) * 100

# %%
activity
# Out:
#               mac_address                          full_name  \
# 0       C0:29:34:FA:07:8B  C0:29:34:FA:07:8B 4002-0421-00203
# 1       D7:5F:AD:57:AA:38  D7:5F:AD:57:AA:38 4002-0421-00201
# 2       EA:4B:F5:67:30:F9  EA:4B:F5:67:30:F9 4002-0421-00192
# 3       C6:64:81:41:DD:33  C6:64:81:41:DD:33 4002-0721-00223
# 4       f3:0e:8d:37:39:31  f3:0e:8d:37:39:31 4001-1220-00171
# ...                   ...                                ...
# 522265  EA:1E:CF:41:CE:0B  EA:1E:CF:41:CE:0B 4002-0920-00136
# 522266  FC:83:FD:79:73:82  FC:83:FD:79:73:82 4002-0221-00187
# 522267  C0:29:34:FA:07:8B  C0:29:34:FA:07:8B 4002-0421-00203
# 522268  C0:29:34:FA:07:8B  C0:29:34:FA:07:8B 4002-0421-00203
# 522269  C0:29:34:FA:07:8B  C0:29:34:FA:07:8B 4002-0421-00203
#
#                          name                                   full_name.1  \
# 0       Charbonnier-Montaudié  T0649 - Marie-Caroline CHARBONNIER MONTAUDIE
# 1           Claire BARRILLIET                     T0723 - Claire BARRILLIET
# 2          Silver Form Alsace                         T0627 - CAPITAL SANTE
# 3              SCM TRIQUETRUM                        T0792 - SCM TRIQUETRUM
# 4                       Marro                       T0610 - Marro Joséphine
# ...                       ...                                           ...
# 522265                 Ganier                         T0417 - GANIER Nicole
# 522266        Aqua Kiné Santé                       T0613 - Aqua Kiné Santé
# 522267  Charbonnier-Montaudié  T0649 - Marie-Caroline CHARBONNIER MONTAUDIE
# 522268  Charbonnier-Montaudié  T0649 - Marie-Caroline CHARBONNIER MONTAUDIE
# 522269  Charbonnier-Montaudié  T0649 - Marie-Caroline CHARBONNIER MONTAUDIE
#
#        spare_type                  start_date  duration  real_duration  \
# 0           pants  2021-10-28 09:47:57.000000        20              0
# 1           pants  2021-10-28 10:19:38.000000        30              0
# 2           pants  2021-10-28 09:42:49.000000        30           1800
# 3           pants  2021-10-28 10:01:53.000000        20           1200
# 4           pants  2021-10-28 09:51:52.000000        20           1200
# ...           ...                         ...       ...            ...
# 522265      pants  2021-10-28 09:09:39.000000        20           1200
# 522266      pants  2021-10-28 09:27:45.000000        20           1200
# 522267      pants  2021-10-28 09:41:06.000000        20              0
# 522268      pants  2021-10-28 09:42:23.000000        20              0
# 522269      pants  2021-10-28 09:44:09.000000        20              0
#
#         percentage_real_duration  care_note ps_server economic_model  \
# 0                            0.0          0        EU      UNLIMITED
# 1                            0.0          0        EU      UNLIMITED
# 2                          100.0          0        EU      UNLIMITED
# 3                          100.0          0        EU      UNLIMITED
# 4                          100.0          0        EU      UNLIMITED
# ...                          ...        ...       ...            ...
# 522265                     100.0          5        EU      UNLIMITED
# 522266                     100.0          5        EU      UNLIMITED
# 522267                       0.0          0        EU      UNLIMITED
# 522268                       0.0          0        EU      UNLIMITED
# 522269                       0.0          0        EU      UNLIMITED
#
#         credit_number full_name.2  active
# 0                   1   Chronique    True
# 1                   1  Entretien1    True
# 2                   1       Mixte    True
# 3                   1   Chronique    True
# 4                   1        -12h    True
# ...               ...         ...     ...
# 522265              1       Détox    True
# 522266              1   Chronique    True
# 522267              1   Chronique    True
# 522268              1   Chronique    True
# 522269              1   Chronique    True
#
# [522270 rows x 15 columns]

# %%
activity.isna().sum()
# Out:
# mac_address                 0
# full_name                   0
# name                        0
# full_name.1                 0
# spare_type                  0
# start_date                  0
# duration                    0
# real_duration               0
# percentage_real_duration    0
# care_note                   0
# ps_server                   0
# economic_model              0
# credit_number               0
# full_name.2                 0
# active                      0
# dtype: int64

# %%
activity = activity.drop(columns=['mac_address', 'name', 'care_note', 'credit_number', 'active'])

# %%
#activity

# %%
activity_europe = activity[(activity['ps_server'] == 'EU') & (activity['spare_type'] == 'pants')]
#activity_europe

# %%
activity_europe = activity_europe[activity_europe['full_name.1'] != 'T0362 - LETESTEUR Ludovic']
#activity_europe

# %%
activity_asia = activity[(activity['ps_server'] == 'ASIA') & (activity['spare_type'] == 'pants')]
#activity_asia

# %%
activity_europe_50 = activity_europe[activity_europe['percentage_real_duration'] >= 50]
#activity_europe_50

# %%
activity_asia_50 = activity_asia[activity_asia['percentage_real_duration'] >= 50]
#activity_asia_50

# %%
activity_europe_50 = activity_europe_50.sort_values(by=['full_name.1'])
activity_europe_50
# Out:
#                                  full_name  \
# 447702  F2:7E:05:A5:6A:E5 400-2-0220-00004
# 195210  F2:7E:05:A5:6A:E5 400-2-0220-00004
# 40675   F2:7E:05:A5:6A:E5 400-2-0220-00004
# 103051  F2:7E:05:A5:6A:E5 400-2-0220-00004
# 4932    F2:7E:05:A5:6A:E5 400-2-0220-00004
# ...                                    ...
# 312819   C4:A3:0B:50:D2:59 4002-1124-00450
# 349427   C4:A3:0B:50:D2:59 4002-1124-00450
# 350035           f1:fb:63:1a:7e:8a PRH0008
# 335780   F0:6B:5A:DD:4A:44 4002-1124-00455
# 348395   F5:F2:15:3A:74:DE 4002-0920-00134
#
#                                 full_name.1 spare_type  \
# 447702               T0078 - Bruno WALLECAN      pants
# 195210               T0078 - Bruno WALLECAN      pants
# 40675                T0078 - Bruno WALLECAN      pants
# 103051               T0078 - Bruno WALLECAN      pants
# 4932                 T0078 - Bruno WALLECAN      pants
# ...                                     ...        ...
# 312819                 T1822 - Maud JARRIGE      pants
# 349427                 T1822 - Maud JARRIGE      pants
# 350035  T1823 - Siegrid BAUMEISTER-ABELANET      pants
# 335780                T1831 - Claire CASTRO      pants
# 348395                      T1835 - MYBRUSH      pants
#
#                         start_date  duration  real_duration  \
# 447702  2020-03-19 21:11:45.000000        30           1800
# 195210  2023-02-24 17:47:25.000000        45           2700
# 40675   2022-03-23 08:09:48.000000        30           1800
# 103051  2022-08-05 08:42:25.000000        30           1800
# 4932    2021-11-19 13:02:29.000000        20           1200
# ...                            ...       ...            ...
# 312819  2024-12-12 10:39:01.000000        45           2700
# 349427  2025-01-06 10:11:29.000000        20           1200
# 350035  2025-01-06 12:56:01.000000        20           1200
# 335780  2024-12-23 12:50:40.000000        30           1800
# 348395  2025-01-04 11:15:11.000000        30           1800
#
#         percentage_real_duration ps_server economic_model     full_name.2
# 447702                     100.0        EU      UNLIMITED  Jambes lourdes
# 195210                     100.0        EU      UNLIMITED       Chronique
# 40675                      100.0        EU      UNLIMITED       Chronique
# 103051                     100.0        EU      UNLIMITED       Chronique
# 4932                       100.0        EU      UNLIMITED       Entretien
# ...                          ...       ...            ...             ...
# 312819                     100.0        EU      UNLIMITED           Mixte
# 349427                     100.0        EU      UNLIMITED           Mixte
# 350035                     100.0        EU      UNLIMITED       Entretien
# 335780                     100.0        EU      UNLIMITED       Chronique
# 348395                     100.0        EU      UNLIMITED        Drainage
#
# [403877 rows x 10 columns]

# %%
sorted_activity_europe_50 = activity_europe_50.groupby('full_name.1').size().reset_index(name='counts')
sorted_activity_europe_50
# Out:
#                              full_name.1  counts
# 0                 T0078 - Bruno WALLECAN     906
# 1                   T0088 - André TORRES    1729
# 2                T0089 - Stefano BETTONI     709
# 3              T0091 - Selarl MEDVASC 32   11908
# 4           T0093 - POLE SANTÉ ALIMENTEC    4697
# ..                                   ...     ...
# 356                T1820 - Gemma GIMENEZ      25
# 357                 T1822 - Maud JARRIGE       7
# 358  T1823 - Siegrid BAUMEISTER-ABELANET       1
# 359                T1831 - Claire CASTRO       1
# 360                      T1835 - MYBRUSH       1
#
# [361 rows x 2 columns]

# %%
first_activity_dates = activity_europe_50.groupby('full_name.1')['start_date'].min().reset_index()
first_activity_dates.rename(columns={'start_date': 'first_activity'}, inplace=True)
sorted_activity_europe_50 = pd.merge(sorted_activity_europe_50, first_activity_dates, on='full_name.1', how='left')
sorted_activity_europe_50
# Out:
#                              full_name.1  counts              first_activity
# 0                 T0078 - Bruno WALLECAN     906  2020-02-07 14:51:51.000000
# 1                   T0088 - André TORRES    1729  2020-06-19 17:30:27.000000
# 2                T0089 - Stefano BETTONI     709  2020-02-25 15:14:20.000000
# 3              T0091 - Selarl MEDVASC 32   11908  2020-06-23 09:43:51.000000
# 4           T0093 - POLE SANTÉ ALIMENTEC    4697  2020-07-01 16:14:08.000000
# ..                                   ...     ...                         ...
# 356                T1820 - Gemma GIMENEZ      25  2024-12-20 10:05:32.000000
# 357                 T1822 - Maud JARRIGE       7  2024-12-12 10:39:01.000000
# 358  T1823 - Siegrid BAUMEISTER-ABELANET       1  2025-01-06 12:56:01.000000
# 359                T1831 - Claire CASTRO       1  2024-12-23 12:50:40.000000
# 360                      T1835 - MYBRUSH       1  2025-01-04 11:15:11.000000
#
# [361 rows x 3 columns]

# %%
last_activity_dates = activity_europe_50.groupby('full_name.1')['start_date'].max().reset_index()
last_activity_dates.rename(columns={'start_date': 'last_activity'}, inplace=True)
sorted_activity_europe_50 = pd.merge(sorted_activity_europe_50, last_activity_dates, on='full_name.1', how='left')
#sorted_activity_europe_50

# %%
sorted_activity_europe_50['first_activity'] = pd.to_datetime(sorted_activity_europe_50['first_activity'])
sorted_activity_europe_50['last_activity'] = pd.to_datetime(sorted_activity_europe_50['last_activity'])
sorted_activity_europe_50['number_days'] = 1+ (sorted_activity_europe_50['last_activity'] - sorted_activity_europe_50['first_activity']).dt.days
#sorted_activity_europe_50

# %%
# prompt: Add an extra column to sorted_activity_europe_50 called activity_last_week. The entries of the column activity_last_week should be equal to the counts of entries of full_name.1 between the current date and the curret date minus7 days

# Assuming 'start_date' column is already datetime objects. If not, convert it first:
# sorted_activity_europe_50['start_date'] = pd.to_datetime(sorted_activity_europe_50['start_date'])

import datetime

# Ensure 'start_date' in activity_europe_50 is datetime
activity_europe_50['start_date'] = pd.to_datetime(activity_europe_50['start_date'])

def count_activity_last_week(df, user):
    today = datetime.date.today()
    last_week = today - datetime.timedelta(days=7)
    user_activity = df[df['full_name.1'] == user]
    last_week_activity = user_activity[
        (user_activity['start_date'].dt.date >= last_week) &
        (user_activity['start_date'].dt.date <= today)
    ]
    return len(last_week_activity)


activity_last_week = []
for user in sorted_activity_europe_50['full_name.1']:
    activity_last_week.append(count_activity_last_week(activity_europe_50, user))

sorted_activity_europe_50['activity_last_week'] = activity_last_week
#sorted_activity_europe_50

# %%
# prompt: Add an extra column to sorted_activity_europe_50 called activity_last_2_week. The entries of the column activity_last_2_week should be equal to the counts of entries of full_name.1 between the current date and the curret date minus 14 days

# Ensure 'start_date' in activity_europe_50 is datetime
activity_europe_50['start_date'] = pd.to_datetime(activity_europe_50['start_date'])

def count_activity_last_2_weeks(df, user):
    today = datetime.date.today()
    two_weeks_ago = today - datetime.timedelta(days=14)
    user_activity = df[df['full_name.1'] == user]
    last_2_weeks_activity = user_activity[
        (user_activity['start_date'].dt.date >= two_weeks_ago) &
        (user_activity['start_date'].dt.date <= today)
    ]
    return len(last_2_weeks_activity)

activity_last_2_week = []
for user in sorted_activity_europe_50['full_name.1']:
    activity_last_2_week.append(count_activity_last_2_weeks(activity_europe_50, user))

sorted_activity_europe_50['activity_last_2_week'] = activity_last_2_week
#sorted_activity_europe_50

# %%
# prompt: Add an extra column to sorted_activity_europe_50 called activity_last_30_days. The entries of the column activity_last_30_days should be equal to the counts of entries of full_name.1 between the current date and the curret date minus 31 days

def count_activity_last_30_days(df, user):
    today = datetime.date.today()
    month_ago = today - datetime.timedelta(days=30)
    user_activity = df[df['full_name.1'] == user]
    last_month_activity = user_activity[
        (user_activity['start_date'].dt.date >= month_ago) &
        (user_activity['start_date'].dt.date <= today)
    ]
    return len(last_month_activity)

activity_last_30_days = []
for user in sorted_activity_europe_50['full_name.1']:
    activity_last_30_days.append(count_activity_last_30_days(activity_europe_50, user))

sorted_activity_europe_50['activity_last_30_days'] = activity_last_30_days
#sorted_activity_europe_50

# %%
def count_activity_last_90_days(df, user):
    today = datetime.date.today()
    month_3_ago = today - datetime.timedelta(days=90)
    user_activity = df[df['full_name.1'] == user]
    last_3_month_activity = user_activity[
        (user_activity['start_date'].dt.date >= month_3_ago) &
        (user_activity['start_date'].dt.date <= today)
    ]
    return len(last_3_month_activity)

activity_last_90_days = []
for user in sorted_activity_europe_50['full_name.1']:
    activity_last_90_days.append(count_activity_last_90_days(activity_europe_50, user))

sorted_activity_europe_50['activity_last_90_days'] = activity_last_90_days
#sorted_activity_europe_50

# %%
def count_activity_last_year(df, user):
    today = datetime.date.today()
    year_ago = today - datetime.timedelta(days=365)
    user_activity = df[df['full_name.1'] == user]
    last_year_activity = user_activity[
        (user_activity['start_date'].dt.date >= year_ago) &
        (user_activity['start_date'].dt.date <= today)
    ]
    return len(last_year_activity)

activity_last_year = []
for user in sorted_activity_europe_50['full_name.1']:
    activity_last_year.append(count_activity_last_year(activity_europe_50, user))

sorted_activity_europe_50['activity_last_year'] = activity_last_year
#sorted_activity_europe_50

# %%
sorted_activity_europe_50['activity_per_day_since_acquisition'] = sorted_activity_europe_50['counts'] / sorted_activity_europe_50['number_days']
sorted_activity_europe_50['activity_per_day_7_days'] = sorted_activity_europe_50['activity_last_week'] / 7
sorted_activity_europe_50['activity_per_day_14_days'] = sorted_activity_europe_50['activity_last_2_week'] / 14
sorted_activity_europe_50['activity_per_day_30_days'] = sorted_activity_europe_50['activity_last_30_days'] / 30
sorted_activity_europe_50['activity_per_day_90_days'] = sorted_activity_europe_50['activity_last_90_days'] / 90
sorted_activity_europe_50['activity_per_day_year'] = sorted_activity_europe_50['activity_last_year'] / 365
#sorted_activity_europe_50

# %%
sorted_activity_europe_50 = sorted_activity_europe_50.sort_values(by=['activity_per_day_since_acquisition'], ascending=False)
#sorted_activity_europe_50

# %%
sorted_activity_europe_50['rank_activity_7_days'] = sorted_activity_europe_50['activity_last_week'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_14_days'] = sorted_activity_europe_50['activity_last_2_week'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_30_days'] = sorted_activity_europe_50['activity_last_30_days'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_90_days'] = sorted_activity_europe_50['activity_last_90_days'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_year'] = sorted_activity_europe_50['activity_last_year'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_per_day_since_acquisition'] = sorted_activity_europe_50['activity_per_day_since_acquisition'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_per_day_7_days'] = sorted_activity_europe_50['activity_per_day_7_days'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_per_day_14_days'] = sorted_activity_europe_50['activity_per_day_14_days'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_per_day_30_days'] = sorted_activity_europe_50['activity_per_day_30_days'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_per_day_90_days'] = sorted_activity_europe_50['activity_per_day_90_days'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_per_day_year'] = sorted_activity_europe_50['activity_per_day_year'].rank(ascending=False, method='min').astype(int)

#sorted_activity_europe_50

# %%
sorted_activity_europe_50['percentage_total_activity_per_day'] = (sorted_activity_europe_50['activity_per_day_since_acquisition'] / sorted_activity_europe_50['activity_per_day_since_acquisition'].sum()) * 100
#sorted_activity_europe_50

# %%
sorted_activity_europe_50['cumulated_percentage_total_activity_per_day'] = sorted_activity_europe_50['percentage_total_activity_per_day'].cumsum()
#sorted_activity_europe_50

# %%
def format_timedelta(days):
    years = days // 365
    months = (days % 365) // 30
    remaining_days = (days % 365) % 30
    return f"{years} an(s), {months} mois, {remaining_days} jour(s)"

sorted_activity_europe_50['formatted_duration'] = sorted_activity_europe_50['number_days'].apply(format_timedelta)
#sorted_activity_europe_50

# %% [markdown]
# # Liste des clients non rentables

# %% [markdown]
# # Sur 7 jours

# %%
# @title
# Display sorted_activity_europe_50 with activity_last_7_days < 1.25, showing only 'full_name.1' and 'activity_last_7_days'
display_unprofitable_clients_activity_per_days_7_days = sorted_activity_europe_50[sorted_activity_europe_50['activity_per_day_7_days'] < 1.25][['full_name.1', 'activity_per_day_7_days']].sort_values(by=['activity_per_day_7_days'], ascending=False)
display_unprofitable_clients_activity_per_days_7_days = display_unprofitable_clients_activity_per_days_7_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_7_days': 'Nombre moyen séance par jours sur les 7 derniers jours',
        })
print(f"{len(display_unprofitable_clients_activity_per_days_7_days)} clients sur "+ f"{len(sorted_activity_europe_50)}" + " ne sont pas rentables sur les 7 derniers jours")
display(display_unprofitable_clients_activity_per_days_7_days.style.hide(axis='index'))
# Out:
# 327 clients sur 361 ne sont pas rentables sur les 7 derniers jours
# <style type="text/css">
# </style>
# <table id="T_25e58">
#   <thead>
#     <tr>
#       <th id="T_25e58_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_25e58_level0_col1" class="col_heading level0 col1" >Nombre moyen séance par jours sur les 7 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_25e58_row0_col0" class="data row0 col0" >T0091 - Selarl MEDVASC 32</td>
#       <td id="T_25e58_row0_col1" class="data row0 col1" >1.142857</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row1_col0" class="data row1 col0" >T0355 - ADMIN Admin</td>
#       <td id="T_25e58_row1_col1" class="data row1 col1" >1.142857</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row2_col0" class="data row2 col0" >T0839 - L'ASTRAGALE SELAS</td>
#       <td id="T_25e58_row2_col1" class="data row2 col1" >1.142857</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row3_col0" class="data row3 col0" >T0102 - Fabrice ALEMANNO</td>
#       <td id="T_25e58_row3_col1" class="data row3 col1" >1.142857</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row4_col0" class="data row4 col0" >T1757 - Cédric FORMET</td>
#       <td id="T_25e58_row4_col1" class="data row4 col1" >1.142857</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row5_col0" class="data row5 col0" >T1550 - Frédérique FITOUSSI</td>
#       <td id="T_25e58_row5_col1" class="data row5 col1" >1.142857</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row6_col0" class="data row6 col0" >T1664 - ARK Cabinet de Kiné</td>
#       <td id="T_25e58_row6_col1" class="data row6 col1" >1.142857</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row7_col0" class="data row7 col0" >T1637 - JEANNIN Cindy / Pauline CLAVEL</td>
#       <td id="T_25e58_row7_col1" class="data row7 col1" >1.142857</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row8_col0" class="data row8 col0" >T1745 - SACLAY CARE CENTRE</td>
#       <td id="T_25e58_row8_col1" class="data row8 col1" >1.142857</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row9_col0" class="data row9 col0" >T0649 - Marie-Caroline CHARBONNIER MONTAUDIE</td>
#       <td id="T_25e58_row9_col1" class="data row9 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row10_col0" class="data row10 col0" >T1817 - Laure GUIRAL</td>
#       <td id="T_25e58_row10_col1" class="data row10 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row11_col0" class="data row11 col0" >T0898 - Arnaud BARD</td>
#       <td id="T_25e58_row11_col1" class="data row11 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row12_col0" class="data row12 col0" >T1781 - AUSRA SPA</td>
#       <td id="T_25e58_row12_col1" class="data row12 col1" >0.857143</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row13_col0" class="data row13 col0" >T1727 - SELLINGSUCCESS S.L.</td>
#       <td id="T_25e58_row13_col1" class="data row13 col1" >0.857143</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row14_col0" class="data row14 col0" >T0360 - Frédéric GUELTON</td>
#       <td id="T_25e58_row14_col1" class="data row14 col1" >0.857143</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row15_col0" class="data row15 col0" >T1510 - CRYOPOLE MONTPELLIER</td>
#       <td id="T_25e58_row15_col1" class="data row15 col1" >0.857143</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row16_col0" class="data row16 col0" >T1530 - Florian ONNO</td>
#       <td id="T_25e58_row16_col1" class="data row16 col1" >0.857143</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row17_col0" class="data row17 col0" >T0745 - Thibaut LEONE</td>
#       <td id="T_25e58_row17_col1" class="data row17 col1" >0.857143</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row18_col0" class="data row18 col0" >T1450 - Centre Médical Pasteur</td>
#       <td id="T_25e58_row18_col1" class="data row18 col1" >0.714286</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row19_col0" class="data row19 col0" >T1464 - SCM BETTAN - BERDAL</td>
#       <td id="T_25e58_row19_col1" class="data row19 col1" >0.714286</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row20_col0" class="data row20 col0" >T0107 - Delphine FOUASSE</td>
#       <td id="T_25e58_row20_col1" class="data row20 col1" >0.714286</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row21_col0" class="data row21 col0" >T1463 - Tine VANDEPUT</td>
#       <td id="T_25e58_row21_col1" class="data row21 col1" >0.714286</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row22_col0" class="data row22 col0" >T1729 - Marie-Eline LABORDE</td>
#       <td id="T_25e58_row22_col1" class="data row22 col1" >0.714286</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row23_col0" class="data row23 col0" >T1315 - SCM KINEFLEX</td>
#       <td id="T_25e58_row23_col1" class="data row23 col1" >0.714286</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row24_col0" class="data row24 col0" >T0973 - GULF STREAM</td>
#       <td id="T_25e58_row24_col1" class="data row24 col1" >0.714286</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row25_col0" class="data row25 col0" >T1616 - Julie LAQUEUE (ép. GUILLIN)</td>
#       <td id="T_25e58_row25_col1" class="data row25 col1" >0.714286</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row26_col0" class="data row26 col0" >T1613 - Gloria GARCIA</td>
#       <td id="T_25e58_row26_col1" class="data row26 col1" >0.714286</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row27_col0" class="data row27 col0" >T1488 - SCM KINES SANTE FORME</td>
#       <td id="T_25e58_row27_col1" class="data row27 col1" >0.714286</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row28_col0" class="data row28 col0" >T1749 - Elise PEREZ</td>
#       <td id="T_25e58_row28_col1" class="data row28 col1" >0.714286</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row29_col0" class="data row29 col0" >T1766 - Noémie PETIT</td>
#       <td id="T_25e58_row29_col1" class="data row29 col1" >0.714286</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row30_col0" class="data row30 col0" >T0978 - SCM Challenge Rééduc</td>
#       <td id="T_25e58_row30_col1" class="data row30 col1" >0.714286</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row31_col0" class="data row31 col0" >T1779 - Anne Sophie MABILLE</td>
#       <td id="T_25e58_row31_col1" class="data row31 col1" >0.714286</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row32_col0" class="data row32 col0" >T1257 - Clinique du monde</td>
#       <td id="T_25e58_row32_col1" class="data row32 col1" >0.714286</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row33_col0" class="data row33 col0" >T1507 - AXE KINE</td>
#       <td id="T_25e58_row33_col1" class="data row33 col1" >0.714286</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row34_col0" class="data row34 col0" >T1551 - THE BODY BY CHRIS</td>
#       <td id="T_25e58_row34_col1" class="data row34 col1" >0.714286</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row35_col0" class="data row35 col0" >T1588 - ACTIF BIEN ETRE SAS</td>
#       <td id="T_25e58_row35_col1" class="data row35 col1" >0.571429</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row36_col0" class="data row36 col0" >T1266 - Jérémie LECESNE</td>
#       <td id="T_25e58_row36_col1" class="data row36 col1" >0.571429</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row37_col0" class="data row37 col0" >T1486 - BAYVIEW ESTATE LTD.</td>
#       <td id="T_25e58_row37_col1" class="data row37 col1" >0.571429</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row38_col0" class="data row38 col0" >T1765 - Ghislaine MOHA</td>
#       <td id="T_25e58_row38_col1" class="data row38 col1" >0.571429</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row39_col0" class="data row39 col0" >T0636 - Delphine PETRINI</td>
#       <td id="T_25e58_row39_col1" class="data row39 col1" >0.571429</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row40_col0" class="data row40 col0" >T1762 - Stéphanie DUCLOUS</td>
#       <td id="T_25e58_row40_col1" class="data row40 col1" >0.571429</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row41_col0" class="data row41 col0" >T0951 - Marie-Laure JUAN</td>
#       <td id="T_25e58_row41_col1" class="data row41 col1" >0.571429</td>
#     </tr>
#     <tr>
#       <td id="T_25e58_row42_col0" class="data row42 col0" >T1262 - BODY LAB</td>

# %% [markdown]
# # Sur  14 jours

# %%
# @title
display_unprofitable_clients_activity_per_days_14_days = sorted_activity_europe_50[sorted_activity_europe_50['activity_per_day_14_days'] < 1.25][['full_name.1', 'activity_per_day_14_days']].sort_values(by=['activity_per_day_14_days'], ascending=False)
display_unprofitable_clients_activity_per_days_14_days = display_unprofitable_clients_activity_per_days_14_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_14_days': 'Nombre moyen séance par jours sur les 14 derniers jours',
        })
print(f"{len(display_unprofitable_clients_activity_per_days_14_days)} clients sur "+ f"{len(sorted_activity_europe_50)}" + " ne sont pas rentables sur les 14 derniers jours")
display(display_unprofitable_clients_activity_per_days_14_days.style.hide(axis='index'))
# Out:
# 326 clients sur 361 ne sont pas rentables sur les 14 derniers jours
# <style type="text/css">
# </style>
# <table id="T_91f04">
#   <thead>
#     <tr>
#       <th id="T_91f04_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_91f04_level0_col1" class="col_heading level0 col1" >Nombre moyen séance par jours sur les 14 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_91f04_row0_col0" class="data row0 col0" >T1274 - STENDO BEAUTY AU</td>
#       <td id="T_91f04_row0_col1" class="data row0 col1" >1.214286</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row1_col0" class="data row1 col0" >T1637 - JEANNIN Cindy / Pauline CLAVEL</td>
#       <td id="T_91f04_row1_col1" class="data row1 col1" >1.214286</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row2_col0" class="data row2 col0" >T1327 - Anne TEKO GEIGER</td>
#       <td id="T_91f04_row2_col1" class="data row2 col1" >1.214286</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row3_col0" class="data row3 col0" >T1727 - SELLINGSUCCESS S.L.</td>
#       <td id="T_91f04_row3_col1" class="data row3 col1" >1.214286</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row4_col0" class="data row4 col0" >T1013 - Natalia BARTOSEK</td>
#       <td id="T_91f04_row4_col1" class="data row4 col1" >1.214286</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row5_col0" class="data row5 col0" >T1755 - SELARL DOCTEUR VALERIE LEDUC</td>
#       <td id="T_91f04_row5_col1" class="data row5 col1" >1.142857</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row6_col0" class="data row6 col0" >T1616 - Julie LAQUEUE (ép. GUILLIN)</td>
#       <td id="T_91f04_row6_col1" class="data row6 col1" >1.142857</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row7_col0" class="data row7 col0" >T1421 - Sandra BONDON</td>
#       <td id="T_91f04_row7_col1" class="data row7 col1" >1.142857</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row8_col0" class="data row8 col0" >T0102 - Fabrice ALEMANNO</td>
#       <td id="T_91f04_row8_col1" class="data row8 col1" >1.071429</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row9_col0" class="data row9 col0" >T0733 - Céline RAMAGE</td>
#       <td id="T_91f04_row9_col1" class="data row9 col1" >1.071429</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row10_col0" class="data row10 col0" >T0937 - SCM KINEMOTIV</td>
#       <td id="T_91f04_row10_col1" class="data row10 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row11_col0" class="data row11 col0" >T0360 - Frédéric GUELTON</td>
#       <td id="T_91f04_row11_col1" class="data row11 col1" >0.928571</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row12_col0" class="data row12 col0" >T1488 - SCM KINES SANTE FORME</td>
#       <td id="T_91f04_row12_col1" class="data row12 col1" >0.928571</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row13_col0" class="data row13 col0" >T1765 - Ghislaine MOHA</td>
#       <td id="T_91f04_row13_col1" class="data row13 col1" >0.928571</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row14_col0" class="data row14 col0" >T0978 - SCM Challenge Rééduc</td>
#       <td id="T_91f04_row14_col1" class="data row14 col1" >0.928571</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row15_col0" class="data row15 col0" >T1757 - Cédric FORMET</td>
#       <td id="T_91f04_row15_col1" class="data row15 col1" >0.857143</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_
td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row39_col0" class="data row39 col0" >T1647 - Elodie TISON</td>
#       <td id="T_91f04_row39_col1" class="data row39 col1" >0.571429</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row40_col0" class="data row40 col0" >T0525 - FISIOLAB 8.14 S.R.L.</td>
#       <td id="T_91f04_row40_col1" class="data row40 col1" >0.571429</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row41_col0" class="data row41 col0" >T1014 - SCM FLAUGERGUES</td>
#       <td id="T_91f04_row41_col1" class="data row41 col1" >0.571429</td>
#     </tr>
#     <tr>
#       <td id="T_91f04_row42_col0" class="data row42 col0" >T1550 - Frédérique FITOUSSI</td>

# %% [markdown]
# # Sur 30 jours

# %%
# @title
display_unprofitable_clients_activity_per_days_30_days = sorted_activity_europe_50[sorted_activity_europe_50['activity_per_day_30_days'] < 1.25][['full_name.1', 'activity_per_day_30_days']].sort_values(by=['activity_per_day_30_days'], ascending=False)
display_unprofitable_clients_activity_per_days_30_days = display_unprofitable_clients_activity_per_days_30_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_30_days': 'Nombre moyen séance par jours sur les 30 derniers jours',
        })
print(f"{len(display_unprofitable_clients_activity_per_days_30_days)} clients sur "+ f"{len(sorted_activity_europe_50)}" + " ne sont pas rentables sur les 30 derniers jours")
display(display_unprofitable_clients_activity_per_days_30_days.style.hide(axis='index'))
# Out:
# 286 clients sur 361 ne sont pas rentables sur les 30 derniers jours
# <style type="text/css">
# </style>
# <table id="T_a5b6d">
#   <thead>
#     <tr>
#       <th id="T_a5b6d_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_a5b6d_level0_col1" class="col_heading level0 col1" >Nombre moyen séance par jours sur les 30 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a5b6d_row0_col0" class="data row0 col0" >T1463 - Tine VANDEPUT</td>
#       <td id="T_a5b6d_row0_col1" class="data row0 col1" >1.233333</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row1_col0" class="data row1 col0" >T0095 - Sébastien SALLEZ</td>
#       <td id="T_a5b6d_row1_col1" class="data row1 col1" >1.233333</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row2_col0" class="data row2 col0" >T1595 - Anne-Sophie MARCHAND</td>
#       <td id="T_a5b6d_row2_col1" class="data row2 col1" >1.200000</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row3_col0" class="data row3 col0" >T0107 - Delphine FOUASSE</td>
#       <td id="T_a5b6d_row3_col1" class="data row3 col1" >1.200000</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row4_col0" class="data row4 col0" >T1274 - STENDO BEAUTY AU</td>
#       <td id="T_a5b6d_row4_col1" class="data row4 col1" >1.200000</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row5_col0" class="data row5 col0" >T1647 - Elodie TISON</td>
#       <td id="T_a5b6d_row5_col1" class="data row5 col1" >1.200000</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row6_col0" class="data row6 col0" >T1550 - Frédérique FITOUSSI</td>
#       <td id="T_a5b6d_row6_col1" class="data row6 col1" >1.200000</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row7_col0" class="data row7 col0" >T1758 - SCM ReeduKA Moulin</td>
#       <td id="T_a5b6d_row7_col1" class="data row7 col1" >1.200000</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row8_col0" class="data row8 col0" >T1698 - CRYOCARE</td>
#       <td id="T_a5b6d_row8_col1" class="data row8 col1" >1.200000</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row9_col0" class="data row9 col0" >T0733 - Céline RAMAGE</td>
#       <td id="T_a5b6d_row9_col1" class="data row9 col1" >1.200000</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row10_col0" class="data row10 col0" >T1246 - Steeve HAUSWALD</td>
#       <td id="T_a5b6d_row10_col1" class="data row10 col1" >1.166667</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row11_col0" class="data row11 col0" >T1749 - Elise PEREZ</td>
#       <td id="T_a5b6d_row11_col1" class="data row11 col1" >1.166667</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_
td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row34_col0" class="data row34 col0" >T0407 - GENTIL JEAN MARC</td>
#       <td id="T_a5b6d_row34_col1" class="data row34 col1" >0.833333</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row35_col0" class="data row35 col0" >T1745 - SACLAY CARE CENTRE</td>
#       <td id="T_a5b6d_row35_col1" class="data row35 col1" >0.833333</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row36_col0" class="data row36 col0" >T1589 - Claire DAUCHY</td>
#       <td id="T_a5b6d_row36_col1" class="data row36 col1" >0.833333</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row37_col0" class="data row37 col0" >T1289 - Alice DOBELMANN</td>
#       <td id="T_a5b6d_row37_col1" class="data row37 col1" >0.800000</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row38_col0" class="data row38 col0" >T1551 - THE BODY BY CHRIS</td>
#       <td id="T_a5b6d_row38_col1" class="data row38 col1" >0.800000</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row39_col0" class="data row39 col0" >T1655 - Dorian DOSSARPS</td>
#       <td id="T_a5b6d_row39_col1" class="data row39 col1" >0.800000</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row40_col0" class="data row40 col0" >T1415 - Adeline JOUIN</td>
#       <td id="T_a5b6d_row40_col1" class="data row40 col1" >0.800000</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row41_col0" class="data row41 col0" >T1757 - Cédric FORMET</td>
#       <td id="T_a5b6d_row41_col1" class="data row41 col1" >0.800000</td>
#     </tr>
#     <tr>
#       <td id="T_a5b6d_row42_col0" class="data row42 col0" >T0964 - Elise Castagno</td>
#       <td id="T_a5b6d_row42_col1" class="data row42 col1" >0.76666

# %% [markdown]
# # Sur 90 jours

# %%
# @title
display_unprofitable_clients_activity_per_days_90_days = sorted_activity_europe_50[sorted_activity_europe_50['activity_per_day_90_days'] < 1.25][['full_name.1', 'activity_per_day_90_days']].sort_values(by=['activity_per_day_90_days'], ascending=False)
display_unprofitable_clients_activity_per_days_90_days = display_unprofitable_clients_activity_per_days_90_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_90_days': 'Nombre moyen séance par jours sur les 90 derniers jours',
        })
print(f"{len(display_unprofitable_clients_activity_per_days_90_days)} clients sur "+ f"{len(sorted_activity_europe_50)}" + " ne sont pas rentables sur les 90 derniers jours")
display(display_unprofitable_clients_activity_per_days_90_days.style.hide(axis='index'))
# Out:
# 255 clients sur 361 ne sont pas rentables sur les 90 derniers jours
# <style type="text/css">
# </style>
# <table id="T_bf7c8">
#   <thead>
#     <tr>
#       <th id="T_bf7c8_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_bf7c8_level0_col1" class="col_heading level0 col1" >Nombre moyen séance par jours sur les 90 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bf7c8_row0_col0" class="data row0 col0" >T0636 - Delphine PETRINI</td>
#       <td id="T_bf7c8_row0_col1" class="data row0 col1" >1.244444</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row1_col0" class="data row1 col0" >T1668 - SCM Santé Danube</td>
#       <td id="T_bf7c8_row1_col1" class="data row1 col1" >1.244444</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row2_col0" class="data row2 col0" >T0964 - Elise Castagno</td>
#       <td id="T_bf7c8_row2_col1" class="data row2 col1" >1.233333</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row3_col0" class="data row3 col0" >T1729 - Marie-Eline LABORDE</td>
#       <td id="T_bf7c8_row3_col1" class="data row3 col1" >1.233333</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row4_col0" class="data row4 col0" >T1394 - KINESPORT</td>
#       <td id="T_bf7c8_row4_col1" class="data row4 col1" >1.233333</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row5_col0" class="data row5 col0" >T0669 - Laurine Peribe</td>
#       <td id="T_bf7c8_row5_col1" class="data row5 col1" >1.222222</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_
col1" >0.900000</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row28_col0" class="data row28 col0" >T1328 - Nathalie ROZE</td>
#       <td id="T_bf7c8_row28_col1" class="data row28 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row29_col0" class="data row29 col0" >T1510 - CRYOPOLE MONTPELLIER</td>
#       <td id="T_bf7c8_row29_col1" class="data row29 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row30_col0" class="data row30 col0" >T0094 - Sébastien PELLÉ</td>
#       <td id="T_bf7c8_row30_col1" class="data row30 col1" >0.888889</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row31_col0" class="data row31 col0" >T0597 - SELAS CCECB</td>
#       <td id="T_bf7c8_row31_col1" class="data row31 col1" >0.888889</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row32_col0" class="data row32 col0" >T1682 - Guida Sicura Vito Popolizio sas</td>
#       <td id="T_bf7c8_row32_col1" class="data row32 col1" >0.877778</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row33_col0" class="data row33 col0" >T0103 - Guillaume ZELLER</td>
#       <td id="T_bf7c8_row33_col1" class="data row33 col1" >0.877778</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row34_col0" class="data row34 col0" >T0634 - SCM DES CANUTS</td>
#       <td id="T_bf7c8_row34_col1" class="data row34 col1" >0.866667</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row35_col0" class="data row35 col0" >T1399 - Laurence FRAISIER</td>
#       <td id="T_bf7c8_row35_col1" class="data row35 col1" >0.844444</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row36_col0" class="data row36 col0" >T1709 - Christelle TORCHEN</td>
#       <td id="T_bf7c8_row36_col1" class="data row36 col1" >0.844444</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row37_col0" class="data row37 col0" >T0414 - AMBERTON Icaros</td>
#       <td id="T_bf7c8_row37_col1" class="data row37 col1" >0.800000</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row38_col0" class="data row38 col0" >T1708 - Edith CARTIER</td>
#       <td id="T_bf7c8_row38_col1" class="data row38 col1" >0.788889</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row39_col0" class="data row39 col0" >T1713 - Franck DUBOIS</td>
#       <td id="T_bf7c8_row39_col1" class="data row39 col1" >0.788889</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row40_col0" class="data row40 col0" >T0970 - Julien JOURDAIN</td>
#       <td id="T_bf7c8_row40_col1" class="data row40 col1" >0.777778</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row41_col0" class="data row41 col0" >T0903 - Dr Mathilde GUILLOT</td>
#       <td id="T_bf7c8_row41_col1" class="data row41 col1" >0.766667</td>
#     </tr>
#     <tr>
#       <td id="T_bf7c8_row42_col0" class="data row42 col0" >T1336 - Julien PION et Anaïs PARIS</td>
#       <td id="T_bf7c8_row42_col1" class="data ro

# %% [markdown]
# # Sur 1 an

# %%
# @title
display_unprofitable_clients_activity_per_days_year = sorted_activity_europe_50[sorted_activity_europe_50['activity_per_day_year'] < 1.25][['full_name.1', 'activity_per_day_year']].sort_values(by=['activity_per_day_year'], ascending=False)
display_unprofitable_clients_activity_per_days_year = display_unprofitable_clients_activity_per_days_year.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_year': 'Nombre moyen séance par jours sur 1 an',
        })
print(f"{len(display_unprofitable_clients_activity_per_days_90_days)} clients sur "+ f"{len(sorted_activity_europe_50)}" + " ne sont pas rentables sur 1 an")
display(display_unprofitable_clients_activity_per_days_90_days.style.hide(axis='index'))
# Out:
# 255 clients sur 361 ne sont pas rentables sur 1 an
# <style type="text/css">
# </style>
# <table id="T_e83bd">
#   <thead>
#     <tr>
#       <th id="T_e83bd_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_e83bd_level0_col1" class="col_heading level0 col1" >Nombre moyen séance par jours sur les 90 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e83bd_row0_col0" class="data row0 col0" >T0636 - Delphine PETRINI</td>
#       <td id="T_e83bd_row0_col1" class="data row0 col1" >1.244444</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row1_col0" class="data row1 col0" >T1668 - SCM Santé Danube</td>
#       <td id="T_e83bd_row1_col1" class="data row1 col1" >1.244444</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row2_col0" class="data row2 col0" >T0964 - Elise Castagno</td>
#       <td id="T_e83bd_row2_col1" class="data row2 col1" >1.233333</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row3_col0" class="data row3 col0" >T1729 - Marie-Eline LABORDE</td>
#       <td id="T_e83bd_row3_col1" class="data row3 col1" >1.233333</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row4_col0" class="data row4 col0" >T1394 - KINESPORT</td>
#       <td id="T_e83bd_row4_col1" class="data row4 col1" >1.233333</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row5_col0" class="data row5 col0" >T0669 - Laurine Peribe</td>
#       <td id="T_e83bd_row5_col1" class="data row5 col1" >1.222222</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row6_col0" class="data row6 col0" >T1431 - Cindy STANDAERT</td>
#       <td id="T_e83bd_row6_col1" class="data row6 col1" >1.177778</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row7_col0" class="data row7 col0" >T1014 - SCM FLAUGERGUES</td>
#       <td id="T_e83bd_row7_col1" class="data row7 col1" >1.166667</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row8_col0" class="data row8 col0" >T1656 - Sylvie LEROY</td>
#       <td id="T_e83bd_row8_col1" class="data row8 col1" >1.166667</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row9_col0" class="data row9 col0" >T1644 - Denise WUITHIER</td>
#       <td id="T_e83bd_row9_col1" class="data row9 col1" >1.144444</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row10_col0" class="data row10 col0" >T1266 - Jérémie LECESNE</td>
#       <td id="T_e83bd_row10_col1" class="data row10 col1" >1.122222</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row11_col0" class="data row11 col0" >T1787 - Cécile CAPE</td>
#       <td id="T_e83bd_row11_col1" class="data row11 col1" >1.111111</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row12_col0" class="data row12 col0" >T0760 - Kin’artense</td>
#       <td id="T_e83bd_row12_col1" class="data row12 col1" >1.111111</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row13_col0" class="data row13 col0" >T0407 - GENTIL JEAN MARC</td>
#       <td id="T_e83bd_row13_col1" class="data row13 col1" >1.077778</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row14_col0" class="data row14 col0" >T1311 - Audrey DELEFORTRIE</td>
#       <td id="T_e83bd_row14_col1" class="data row14 col1" >1.055556</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row15_col0" class="data row15 col0" >T0979 - Paul FAURIS</td>
#       <td id="T_e83bd_row15_col1" class="data row15 col1" >1.044444</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row16_col0" class="data row16 col0" >T0123 - CARLIER Vincent</td>
#       <td id="T_e83bd_row16_col1" class="data row16 col1" >1.033333</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row17_col0" class="data row17 col0" >T1666 - Charlotte RASTOUL</td>
#       <td id="T_e83bd_row17_col1" class="data row17 col1" >1.011111</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row18_col0" class="data row18 col0" >T0525 - FISIOLAB 8.14 S.R.L.</td>
#       <td id="T_e83bd_row18_col1" class="data row18 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row19_col0" class="data row19 col0" >T1478 - Sibylle ROBERT</td>
#       <td id="T_e83bd_row19_col1" class="data row19 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row20_col0" class="data row20 col0" >T1310 - Leatitia GONZALEZ</td>
#       <td id="T_e83bd_row20_col1" class="data row20 col1" >0.955556</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row21_col0" class="data row21 col0" >T1704 - Ozon 2000 (SRL)</td>
#       <td id="T_e83bd_row21_col1" class="data row21 col1" >0.944444</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row22_col0" class="data row22 col0" >T1274 - STENDO BEAUTY AU</td>
#       <td id="T_e83bd_row22_col1" class="data row22 col1" >0.944444</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row23_col0" class="data row23 col0" >T0402 - LHUILLERY LANNO</td>
#       <td id="T_e83bd_row23_col1" class="data row23 col1" >0.933333</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row24_col0" class="data row24 col0" >T0788 - Jéromine PASO</td>
#       <td id="T_e83bd_row24_col1" class="data row24 col1" >0.922222</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row25_col0" class="data row25 col0" >T0973 - GULF STREAM</td>
#       <td id="T_e83bd_row25_col1" class="data row25 col1" >0.922222</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row26_col0" class="data row26 col0" >T0844 - Emilie LEMETAYER</td>
#       <td id="T_e83bd_row26_col1" class="data row26 col1" >0.911111</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row27_col0" class="data row27 col0" >T1262 - BODY LAB</td>
#       <td id="T_e83bd_row27_col1" class="data row27 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row28_col0" class="data row28 col0" >T1328 - Nathalie ROZE</td>
#       <td id="T_e83bd_row28_col1" class="data row28 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row29_col0" class="data row29 col0" >T1510 - CRYOPOLE MONTPELLIER</td>
#       <td id="T_e83bd_row29_col1" class="data row29 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row30_col0" class="data row30 col0" >T0094 - Sébastien PELLÉ</td>
#       <td id="T_e83bd_row30_col1" class="data row30 col1" >0.888889</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row31_col0" class="data row31 col0" >T0597 - SELAS CCECB</td>
#       <td id="T_e83bd_row31_col1" class="data row31 col1" >0.888889</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row32_col0" class="data row32 col0" >T1682 - Guida Sicura Vito Popolizio sas</td>
#       <td id="T_e83bd_row32_col1" class="data row32 col1" >0.877778</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row33_col0" class="data row33 col0" >T0103 - Guillaume ZELLER</td>
#       <td id="T_e83bd_row33_col1" class="data row33 col1" >0.877778</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row34_col0" class="data row34 col0" >T0634 - SCM DES CANUTS</td>
#       <td id="T_e83bd_row34_col1" class="data row34 col1" >0.866667</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row35_col0" class="data row35 col0" >T1399 - Laurence FRAISIER</td>
#       <td id="T_e83bd_row35_col1" class="data row35 col1" >0.844444</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row36_col0" class="data row36 col0" >T1709 - Christelle TORCHEN</td>
#       <td id="T_e83bd_row36_col1" class="data row36 col1" >0.844444</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row37_col0" class="data row37 col0" >T0414 - AMBERTON Icaros</td>
#       <td id="T_e83bd_row37_col1" class="data row37 col1" >0.800000</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row38_col0" class="data row38 col0" >T1708 - Edith CARTIER</td>
#       <td id="T_e83bd_row38_col1" class="data row38 col1" >0.788889</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row39_col0" class="data row39 col0" >T1713 - Franck DUBOIS</td>
#       <td id="T_e83bd_row39_col1" class="data row39 col1" >0.788889</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row40_col0" class="data row40 col0" >T0970 - Julien JOURDAIN</td>
#       <td id="T_e83bd_row40_col1" class="data row40 col1" >0.777778</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row41_col0" class="data row41 col0" >T0903 - Dr Mathilde GUILLOT</td>
#       <td id="T_e83bd_row41_col1" class="data row41 col1" >0.766667</td>
#     </tr>
#     <tr>
#       <td id="T_e83bd_row42_col0" class="data row42 col0" >T1336 - Julien PION et Anaïs PARIS</td>
#       <td id="T_e83bd_row42_col1" class="data ro

# %% [markdown]
# # Classement des 30 premiers clients européens en fonction du nombre moyen de séances par jour

# %% [markdown]
# # Depuis l'acquisition de l'appareil V4

# %%
# @title
display_30_best_clients_activity_per_days_entire_period = sorted_activity_europe_50[['full_name.1', 'activity_per_day_since_acquisition', 'rank_activity_per_day_since_acquisition']]
display_30_best_clients_activity_per_days_entire_period = display_30_best_clients_activity_per_days_entire_period.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day
col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_63afc_row18_col0" class="data row18 col0" >T1408 - Mandy ROURRET</td>
#       <td id="T_63afc_row18_col1" class="data row18 col1" >4.230183</td>
#       <td id="T_63afc_row18_col2" class="data row18 col2" >19</td>
#     </tr>
#     <tr>
#       <td id="T_63afc_row19_col0" class="data row19 col0" >T1686 - SCM RHEA THERAPIE</td>
#       <td id="T_63afc_row19_col1" class="data row19 col1" >4.212560</td>
#       <td id="T_63afc_row19_col2" class="data row19 col2" >20</td>
#     </tr>
#     <tr>
#       <td id="T_63afc_row20_col0" class="data row20 col0" >T1781 - AUSRA SPA</td>
#       <td id="T_63afc_row20_col1" class="data row20 col1" >4.166667</td>
#       <td id="T_63afc_row20_col2" class="data row20 col2" >21</td>
#     </tr>
#     <tr>
#       <td id="T_63afc_row21_col0" class="data row21 col0" >T1410 - MAGIKTRADE</td>
#       <td id="T_63afc_row21_col1" class="data row21 col1" >4.140000</td>
#       <td id="T_63afc_row21_col2" class="data row21 col2" >22</td>
#     </tr>
#     <tr>
#       <td id="T_63afc_row22_col0" class="data row22 col0" >T1776 - Fanny LE GAL</td>
#       <td id="T_63afc_row22_col1" class="data row22 col1" >4.126316</td>
#       <td id="T_63afc_row22_col2" class="data row22 col2" >23</td>
#     </tr>
#     <tr>
#       <td id="T_63afc_row23_col0" class="data row23 col0" >T0139 - KIWI SANTE</td>
#       <td id="T_63afc_row23_col1" class="data row23 col1" >4.096712</td>
#       <td id="T_63afc_row23_col2" class="data row23 col2" >24</td>
#     </tr>
#     <tr>
#       <td id="T_63afc_row24_col0" class="data row24 col0" >T1637 - JEANNIN Cindy / Pauline CLAVEL</td>
#       <td id="T_63afc_row24_col1" class="data row24 col1" >4.066176</td>
#       <td id="T_63afc_row24_col2" class="data row24 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_63afc_row25_col0" class="data row25 col0" >T1315 - SCM KINEFLEX</td>
#       <td id="T_63afc_row25_col1" class="data row25 col1" >4.013665</td>
#       <td id="T_63afc_row25_col2" class="data row25 col2" >26</td>
#     </tr>
#     <tr>
#       <td id="T_63afc_row26_col0" class="data row26 col0" >T0627 - CAPITAL SANTE</td>
#       <td id="T_63afc_row26_col1" class="data row26 col1" >3.954348</td>
#       <td id="T_63afc_row26_col2" class="data row26 col2" >27</td>
#     </tr>
#     <tr>
#       <td id="T_63afc_row27_col0" class="data row27 col0" >T0820 - Nicolas BOCACCIO</td>
#       <td id="T_63afc_row27_col1" class="data row27 col1" >3.889924</td>
#       <td id="T_63afc_row27_col2" class="data row27 col2" >28</td>
#     </tr>
#     <tr>
#       <td id="T_63afc_row28_col0" class="data row28 col0" >T1507 - AXE KINE</td>
#       <td id="T_63afc_row28_col1" class="data row28 col1" >3.789588</td>
#       <td id="T_63afc_row28_col2" class="data row28 col2" >29</td>
#     </tr>
#     <tr>
#       <td id="T_63afc_row29_col0" class="data row29 col0" >T1360 - Guillaume BRUNEL - Pauline GAGNIERE</td>
#       <td id="T_63afc_row29_col1" class="data row29 col1" >3.746684</td>
#       <td id="T_63afc_row29_col2" class="data row29 col2" >30</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_per_days_entire_period.head(30)['Nom du client'], display_30_best_clients_activity_per_days_entire_period.head(30)['Nombre moyen séance par jours depuis acquisition'],  alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres moyen de séances par jours')
plt.title('Classement des 30 premiers clients européens en fonction du nombre moyen de séances par jour depuis l\'acquisition de l\'appareil V4')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # sur les 7 derniers jours

# %%
# @title
display_30_best_clients_activity_per_days_7_days = sorted_activity_europe_50[['full_name.1', 'activity_per_day_7_days', 'rank_activity_per_day_7_days']].sort_values(by=['activity_per_day_7_days'], ascending=False)
display_30_best_clients_activity_per_days_7_days = display_30_best_clients_activity_per_days_7_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_7_days': 'Nombre moyen séances par jours sur les 7 derniers jours',
    'rank_activity_per_day_7_days' : 'Classement en fonction de l\'activité sur les 7 derniers jours'
    })


display(display_30_best_clients_activity_per_days_7_days.head(30).style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_52b04">
#   <thead>
#     <tr>
#       <th id="T_52b04_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_52b04_level0_col1" class="col_heading level0 col1" >Nombre moyen séances par jours sur les 7 derniers jours</th>
#       <th id="T_52b04_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur les
col2" >21</td>
#     </tr>
#     <tr>
#       <td id="T_52b04_row22_col0" class="data row22 col0" >T1274 - STENDO BEAUTY AU</td>
#       <td id="T_52b04_row22_col1" class="data row22 col1" >1.571429</td>
#       <td id="T_52b04_row22_col2" class="data row22 col2" >23</td>
#     </tr>
#     <tr>
#       <td id="T_52b04_row23_col0" class="data row23 col0" >T0139 - KIWI SANTE</td>
#       <td id="T_52b04_row23_col1" class="data row23 col1" >1.571429</td>
#       <td id="T_52b04_row23_col2" class="data row23 col2" >23</td>
#     </tr>
#     <tr>
#       <td id="T_52b04_row24_col0" class="data row24 col0" >T1360 - Guillaume BRUNEL - Pauline GAGNIERE</td>
#       <td id="T_52b04_row24_col1" class="data row24 col1" >1.571429</td>
#       <td id="T_52b04_row24_col2" class="data row24 col2" >23</td>
#     </tr>
#     <tr>
#       <td id="T_52b04_row25_col0" class="data row25 col0" >T1754 - Christelle DUQUESNE</td>
#       <td id="T_52b04_row25_col1" class="data row25 col1" >1.571429</td>
#       <td id="T_52b04_row25_col2" class="data row25 col2" >23</td>
#     </tr>
#     <tr>
#       <td id="T_52b04_row26_col0" class="data row26 col0" >T0646 - Stéphanie BERTHON</td>
#       <td id="T_52b04_row26_col1" class="data row26 col1" >1.571429</td>
#       <td id="T_52b04_row26_col2" class="data row26 col2" >23</td>
#     </tr>
#     <tr>
#       <td id="T_52b04_row27_col0" class="data row27 col0" >T0937 - SCM KINEMOTIV</td>
#       <td id="T_52b04_row27_col1" class="data row27 col1" >1.428571</td>
#       <td id="T_52b04_row27_col2" class="data row27 col2" >28</td>
#     </tr>
#     <tr>
#       <td id="T_52b04_row28_col0" class="data row28 col0" >T0999 - Jérôme DUCHATELET</td>
#       <td id="T_52b04_row28_col1" class="data row28 col1" >1.428571</td>
#       <td id="T_52b04_row28_col2" class="data row28 col2" >28</td>
#     </tr>
#     <tr>
#       <td id="T_52b04_row29_col0" class="data row29 col0" >T0385 - BATAILLE Maxime</td>
#       <td id="T_52b04_row29_col1" class="data row29 col1" >1.285714</td>
#       <td id="T_52b04_row29_col2" class="data row29 col2" >30</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_per_days_7_days.head(30)['Nom du client'], display_30_best_clients_activity_per_days_7_days.head(30)['Nombre moyen séances par jours sur les 7 derniers jours'],  alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres moyen de séances par jours')
plt.title('Classement des 30 premiers clients européens en fonction du nombre moyen de séances par jour sur les 7 derniers jours')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # sur les 14 derniers jours

# %%
# @title
display_30_best_clients_activity_per_days_14_days = sorted_activity_europe_50[['full_name.1', 'activity_per_day_14_days', 'rank_activity_per_day_14_days']].sort_values(by=['activity_per_day_14_days'], ascending=False)
display_30_best_clients_activity_per_days_14_days = display_30_best_clients_activity_per_days_14_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_14_days': 'Nombre moyen séances par jours sur les 14 derniers jours',
    'rank_activity_per_day_14_days' : 'Classement en fonction de l\'activité sur les 14 derniers jours'
    })


display(display_30_best_clients_activity_per_days_14_days.head(30).style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_7354f">
#   <thead>
#     <tr>
#       <th id="T_7354f_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_7354f_level0_col1" class="col_heading level0 col1" >Nombre moyen séances par jours sur les 14 derniers jours</th>
#       <th id="T_7354f_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur les 14 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7354f_row0_col0" class="data row0 col0" >T0821 - PROKINETIC</td>
#       <td id="T_7354f_row0_col1" class="data row0 col1" >5.928571</td>
#       <td id="T_7354f_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_7354f_row1_col0" class="data row1 col0" >T0108 - UAB MEDA LT</td>
#       <td id="T_7354f_row1_col1" class="data row1 col1" >5.142857</td>
#       <td id="T_7354f_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_7354f_row2_col0" class="data row2 col0" >T1680 - Laure GIULIANI</td>
#       <td id="T_7354f_row2_col1" class="data row2 col1" >5.000000</td>
#       <td id="T_7354f_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_7354f_row3_col0" class="data row3 col0" >T1354 - LES CURES MARINES</td>
#       <td id="T_7354f_row3_col1" class="data row3 col1" >3.714286</td>
#       <td id="T_7354f_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_7354f_row4_col0" class="data row4 col0" >T1344 - Christine BERTERO BONNENFANT</td>
#       <td id="T
col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_7354f_row26_col0" class="data row26 col0" >T1538 - François MIGUEL</td>
#       <td id="T_7354f_row26_col1" class="data row26 col1" >1.428571</td>
#       <td id="T_7354f_row26_col2" class="data row26 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_7354f_row27_col0" class="data row27 col0" >T1776 - Fanny LE GAL</td>
#       <td id="T_7354f_row27_col1" class="data row27 col1" >1.428571</td>
#       <td id="T_7354f_row27_col2" class="data row27 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_7354f_row28_col0" class="data row28 col0" >T0091 - Selarl MEDVASC 32</td>
#       <td id="T_7354f_row28_col1" class="data row28 col1" >1.357143</td>
#       <td id="T_7354f_row28_col2" class="data row28 col2" >29</td>
#     </tr>
#     <tr>
#       <td id="T_7354f_row29_col0" class="data row29 col0" >T1754 - Christelle DUQUESNE</td>
#       <td id="T_7354f_row29_col1" class="data row29 col1" >1.357143</td>
#       <td id="T_7354f_row29_col2" class="data row29 col2" >29</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_per_days_14_days.head(30)['Nom du client'], display_30_best_clients_activity_per_days_14_days.head(30)['Nombre moyen séances par jours sur les 14 derniers jours'],  alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres moyen de séances par jours')
plt.title('Classement des 30 premiers clients européens en fonction du nombre moyen de séances par jour sur les 14 derniers jours')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # sur les 30 derniers jours

# %%
# @title
display_30_best_clients_activity_per_days_30_days = sorted_activity_europe_50[['full_name.1', 'activity_per_day_30_days', 'rank_activity_per_day_30_days']].sort_values(by=['activity_per_day_30_days'], ascending=False)
display_30_best_clients_activity_per_days_30_days = display_30_best_clients_activity_per_days_30_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_30_days': 'Nombre moyen séances par jours sur les 30 derniers jours',
    'rank_activity_per_day_30_days' : 'Classement en fonction de l\'activité sur les 30 derniers jours'
    })


display(display_30_best_clients_activity_per_days_30_days.head(30).style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_adc59">
#   <thead>
#     <tr>
#       <th id="T_adc59_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_adc59_level0_col1" class="col_heading level0 col1" >Nombre moyen séances par jours sur les 30 derniers jours</th>
#       <th id="T_adc59_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur les 30 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_adc59_row0_col0" class="data row0 col0" >T0108 - UAB MEDA LT</td>
#       <td id="T_adc59_row0_col1" class="data row0 col1" >9.066667</td>
#       <td id="T_adc59_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_adc59_row1_col0" class="data row1 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_adc59_row1_col1" class="data row1 col1" >7.933333</td>
#       <td id="T_adc59_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_adc59_row2_col0" class="data row2 col0" >T0821 - PROKINETIC</td>
#       <td id="T_adc59_row2_col1" class="data row2 col1" >7.833333</td>
#       <td id="T_adc59_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_adc59_row3_col0" class="data row3 col0" >T1680 - Laure GIULIANI</td>
#       <td id="T_adc59_row3_col1" class="data row3 col1" >6.933333</td>
#       <td id="T_adc59_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_adc59_row4_col0" class="data row4 col0" >T0100 - Franck ARCHIMBAUD</td>
#       <td id="T_adc59_row4_col1" class="data row4 col1" >4.800000</td>
#       <td id="T_adc59_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_adc59_row5_col0" class="data row5 col0" >T0792 - SCM TRIQUETRUM</td>
#       <td id="T_adc59_row5_col1" class="data row5 col1" >4.400000</td>
#       <td id="T_adc59_row5_col2" class="data row5 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_adc59_row6_col0" class="data row6 col0" >T1344 - Christine BERTERO BONNENFANT</td>
#       <td id="T_adc59_row6_col1" class="data row6 col1" >4.200000</td>
#       <td id="T_adc59_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_adc59_row7_col0" class="data row7 col0" >T0711 - KINE FLOW</td>
#       <td id="T_adc59_row7_col1" class="data row7 col1" >4.033333</td>
#       <td id="T_adc59_row7_col2" class="data row7 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_adc59_row8_col0" class="data row8 col0" >T0689 - SCM KINE FORM'</td>
#       <td id="T_adc59_row8_col1" class="data row8 col1" >3.933333</td>
#       <td id="T_adc59_row8_col2" class="data row8 col2" >9</td>
#     </tr>
#     <tr>
#       <td id="T_adc59_row9_col0" class="data row9 col0" >T1543 - SCM KINESIO</td>
#       <td id="T_adc59_row9_col1" class="data row9 col1" >3.700000</td>
#       <td id="T_adc59_row9_col2" class="data row9 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_adc59_row10_col0" class="data row10 col0" >T1640 - DIET Jean-François</td>
#       <td id="T
pha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres moyen de séances par jours')
plt.title('Classement des 30 premiers clients européens en fonction du nombre moyen de séances par jour sur les 30 derniers jours')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # sur les 90 derniers jours

# %%
# @title
display_30_best_clients_activity_per_days_90_days = sorted_activity_europe_50[['full_name.1', 'activity_per_day_90_days', 'rank_activity_per_day_90_days']].sort_values(by=['activity_per_day_90_days'], ascending=False)
display_30_best_clients_activity_per_days_90_days = display_30_best_clients_activity_per_days_90_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_90_days': 'Nombre moyen séances par jours sur les 90 derniers jours',
    'rank_activity_per_day_90_days' : 'Classement en fonction de l\'activité sur les 90 derniers jours'
    })


display(display_30_best_clients_activity_per_days_90_days.head(30).style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_3e436">
#   <thead>
#     <tr>
#       <th id="T_3e436_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_3e436_level0_col1" class="col_heading level0 col1" >Nombre moyen séances par jours sur les 90 derniers jours</th>
#       <th id="T_3e436_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur les 90 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3e436_row0_col0" class="data row0 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_3e436_row0_col1" class="data row0 col1" >11.555556</td>
#       <td id="T_3e436_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row1_col0" class="data row1 col0" >T0108 - UAB MEDA LT</td>
#       <td id="T_3e436_row1_col1" class="data row1 col1" >10.566667</td>
#       <td id="T_3e436_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row2_col0" class="data row2 col0" >T0821 - PROKINETIC</td>
#       <td id="T_3e436_row2_col1" class="data row2 col1" >8.488889</td>
#       <td id="T_3e436_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row3_col0" class="data row3 col0" >T1680 - Laure GIULIANI</td>
#       <td id="T_3e436_row3_col1" class="data row3 col1" >7.488889</td>
#       <td id="T_3e436_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row4_col0" class="data row4 col0" >T0711 - KINE FLOW</td>
#       <td id="T_3e436_row4_col1" class="data row4 col1" >6.655556</td>
#       <td id="T_3e436_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row5_col0" class="data row5 col0" >T0100 - Franck ARCHIMBAUD</td>
#       <td id="T_3e436_row5_col1" class="data row5 col1" >6.522222</td>
#       <td id="T_3e436_row5_col2" class="data row5 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row6_col0" class="data row6 col0" >T0792 - SCM TRIQUETRUM</td>
#       <td id="T_3e436_row6_col1" class="data row6 col1" >6.166667</td>
#       <td id="T_3e436_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row7_col0" class="data row7 col0" >T0689 - SCM KINE FORM'</td>
#       <td id="T_3e436_row7_col1" class="data row7 col1" >5.888889</td>
#       <td id="T_3e436_row7_col2" class="data row7 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row8_col0" class="data row8 col0" >T1344 - Christine BERTERO BONNENFANT</td>
#       <td id="T_3e436_row8_col1" class="data row8 col1" >5.855556</td>
#       <td id="T_3e436_row8_col2" class="data row8 col2" >9</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row9_col0" class="data row9 col0" >T0745 - Thibaut LEONE</td>
#       <td id="T_3e436_row9_col1" class="data row9 col1" >5.544444</td>
#       <td id="T_3e436_row9_col2" class="data row9 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row10_col0" class="data row10 col0" >T1754 - Christelle DUQUESNE</td>
#       <td id="T_3e436_row10_col1" class="data row10 col1" >4.900000</td>
#       <td id="T_3e436_row10_col2" class="data row10 col2" >11</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row11_col0" class="data row11 col0" >T1408 - Mandy ROURRET</td>
#       <td id="T_3e436_row11_col1" class="data row11 col1" >4.877778</td>
#       <td id="T_3e436_row11_col2" class="data row11 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row12_col0" class="data row12 col0" >T1013 - Natalia BARTOSEK</td>
#       <td id="T_3e436_row12_col1" class="data row12 col1" >4.877778</td>
#       <td id="T_3e436_row12_col2" class="data row12 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row13_col0" class="data row13 col0" >T1354 - LES CURES MARINES</td>
#       <td id="T_3e436_row13_col1" class="data row13 col1" >4.644444</td>
#       <td id="T_3e436_row13_col2" class="data row13 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row14_col0" class="data row14 col0" >T1543 - SCM KINESIO</td>
#       <td id="T_3e436_row14_col1" class="data row14 col1" >4.511111</td>
#       <td id="T_3e436_row14_col2" class="data row14 col2" >15</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row15_col0" class="data row15 col0" >T1507 - AXE KINE</td>
#       <td id="T_3e436_row15_col1" class="data row15 col1" >4.266667</td>
#       <td id="T_3e436_row15_col2" class="data row15 col2" >16</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row16_col0" class="data row16 col0" >T1464 - SCM BETTAN - BERDAL</td>
#       <td id="T_3e436_row16_col1" class="data row16 col1" >4.211111</td>
#       <td id="T_3e436_row16_col2" class="data row16 col2" >17</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row17_col0" class="data row17 col0" >T1406 - SOCIETE GANIER-WILLEMS-RIGOT</td>
#       <td id="T_3e436_row17_col1" class="data row17 col1" >4.077778</td>
#       <td id="T_3e436_row17_col2" class="data row17 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row18_col0" class="data row18 col0" >T0098 - CAPOT PHILIPPE </td>
#       <td id="T_3e436_row18_col1" class="data row18 col1" >4.077778</td>
#       <td id="T_3e436_row18_col2" class="data row18 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row19_col0" class="data row19 col0" >T1776 - Fanny LE GAL</td>
#       <td id="T_3e436_row19_col1" class="data row19 col1" >4.033333</td>
#       <td id="T_3e436_row19_col2" class="data row19 col2" >20</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row20_col0" class="data row20 col0" >T0649 - Marie-Caroline CHARBONNIER MONTAUDIE</td>
#       <td id="T_3e436_row20_col1" class="data row20 col1" >3.922222</td>
#       <td id="T_3e436_row20_col2" class="data row20 col2" >21</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row21_col0" class="data row21 col0" >T0385 - BATAILLE Maxime</td>
#       <td id="T_3e436_row21_col1" class="data row21 col1" >3.655556</td>
#       <td id="T_3e436_row21_col2" class="data row21 col2" >22</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row22_col0" class="data row22 col0" >T0830 - Eve CAVALIE</td>
#       <td id="T_3e436_row22_col1" class="data row22 col1" >3.477778</td>
#       <td id="T_3e436_row22_col2" class="data row22 col2" >23</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row23_col0" class="data row23 col0" >T1640 - DIET Jean-François</td>
#       <td id="T_3e436_row23_col1" class="data row23 col1" >3.455556</td>
#       <td id="T_3e436_row23_col2" class="data row23 col2" >24</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row24_col0" class="data row24 col0" >T1428 - 9298-5316 Québec Inc.</td>
#       <td id="T_3e436_row24_col1" class="data row24 col1" >3.444444</td>
#       <td id="T_3e436_row24_col2" class="data row24 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row25_col0" class="data row25 col0" >T1360 - Guillaume BRUNEL - Pauline GAGNIERE</td>
#       <td id="T_3e436_row25_col1" class="data row25 col1" >3.422222</td>
#       <td id="T_3e436_row25_col2" class="data row25 col2" >26</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row26_col0" class="data row26 col0" >T0798 - Sophie FLAGEY LETONDAL</td>
#       <td id="T_3e436_row26_col1" class="data row26 col1" >3.400000</td>
#       <td id="T_3e436_row26_col2" class="data row26 col2" >27</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row27_col0" class="data row27 col0" >T1686 - SCM RHEA THERAPIE</td>
#       <td id="T_3e436_row27_col1" class="data row27 col1" >3.388889</td>
#       <td id="T_3e436_row27_col2" class="data row27 col2" >28</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row28_col0" class="data row28 col0" >T1327 - Anne TEKO GEIGER</td>
#       <td id="T_3e436_row28_col1" class="data row28 col1" >3.366667</td>
#       <td id="T_3e436_row28_col2" class="data row28 col2" >29</td>
#     </tr>
#     <tr>
#       <td id="T_3e436_row29_col0" class="data row29 col0" >T1421 - Sandra BONDON</td>
#       <td id="T_3e436_row29_col1" class="data row29 col1" >3.333333</td>
#       <td id="T_3e436_row29_col2" class="data row29 col2" >30</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_per_days_90_days.head(30)['Nom du client'], display_30_best_clients_activity_per_days_90_days.head(30)['Nombre moyen séances par jours sur les 90 derniers jours'],  alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres moyen de séances par jours')
plt.title('Classement des 30 premiers clients européens en fonction du nombre moyen de séances par jour sur les 90 derniers jours')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # sur 1 an

# %%
# @title
display_30_best_clients_activity_per_days_year = sorted_activity_europe_50[['full_name.1', 'activity_per_day_year', 'rank_activity_per_day_year']].sort_values(by=['activity_per_day_year'], ascending=False)
display_30_best_clients_activity_per_days_year = display_30_best_clients_activity_per_days_year.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_year': 'Nombre moyen séances par jours sur 1 an',
    'rank_activity_per_day_year' : 'Classement en fonction de l\'activité sur 1 an'
    })


display(display_30_best_clients_activity_per_days_year.head(30).style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_64ef7">
#   <thead>
#     <tr>
#       <th id="T_64ef7_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_64ef7_level0_col1" class="col_heading level0 col1" >Nombre moyen séances par jours sur 1 an</th>
#       <th id="T_64ef7_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité s
col0" >T1680 - Laure GIULIANI</td>
#       <td id="T_64ef7_row22_col1" class="data row22 col1" >3.663014</td>
#       <td id="T_64ef7_row22_col2" class="data row22 col2" >23</td>
#     </tr>
#     <tr>
#       <td id="T_64ef7_row23_col0" class="data row23 col0" >T1507 - AXE KINE</td>
#       <td id="T_64ef7_row23_col1" class="data row23 col1" >3.649315</td>
#       <td id="T_64ef7_row23_col2" class="data row23 col2" >24</td>
#     </tr>
#     <tr>
#       <td id="T_64ef7_row24_col0" class="data row24 col0" >T1410 - MAGIKTRADE</td>
#       <td id="T_64ef7_row24_col1" class="data row24 col1" >3.635616</td>
#       <td id="T_64ef7_row24_col2" class="data row24 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_64ef7_row25_col0" class="data row25 col0" >T0820 - Nicolas BOCACCIO</td>
#       <td id="T_64ef7_row25_col1" class="data row25 col1" >3.608219</td>
#       <td id="T_64ef7_row25_col2" class="data row25 col2" >26</td>
#     </tr>
#     <tr>
#       <td id="T_64ef7_row26_col0" class="data row26 col0" >T0649 - Marie-Caroline CHARBONNIER MONTAUDIE</td>
#       <td id="T_64ef7_row26_col1" class="data row26 col1" >3.608219</td>
#       <td id="T_64ef7_row26_col2" class="data row26 col2" >26</td>
#     </tr>
#     <tr>
#       <td id="T_64ef7_row27_col0" class="data row27 col0" >T1315 - SCM KINEFLEX</td>
#       <td id="T_64ef7_row27_col1" class="data row27 col1" >3.583562</td>
#       <td id="T_64ef7_row27_col2" class="data row27 col2" >28</td>
#     </tr>
#     <tr>
#       <td id="T_64ef7_row28_col0" class="data row28 col0" >T0109 - Olivier BORTOLASO</td>
#       <td id="T_64ef7_row28_col1" class="data row28 col1" >3.506849</td>
#       <td id="T_64ef7_row28_col2" class="data row28 col2" >29</td>
#     </tr>
#     <tr>
#       <td id="T_64ef7_row29_col0" class="data row29 col0" >T0139 - KIWI SANTE</td>
#       <td id="T_64ef7_row29_col1" class="data row29 col1" >3.493151</td>
#       <td id="T_64ef7_row29_col2" class="data row29 col2" >30</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_per_days_year.head(30)['Nom du client'], display_30_best_clients_activity_per_days_year.head(30)['Nombre moyen séances par jours sur 1 an'],  alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres moyen de séances par jours')
plt.title('Classement des 30 premiers clients européens en fonction du nombre moyen de séances par jour sur 1 an')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # Classement des 30 premiers clients européens en fonction du nombre de séances

# %% [markdown]
# # sur 7 jours

# %%
# @title
display_30_best_clients_activity_7_days = sorted_activity_europe_50[['full_name.1', 'activity_last_week', 'rank_activity_7_days']].sort_values(by=['activity_last_week'], ascending=False)
display_30_best_clients_activity_7_days = display_30_best_clients_activity_7_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_last_week': 'Nombre de séances sur les 7 derniers jours',
    'rank_activity_7_days' : 'Classement en fonction de l\'activité sur les 7 derniers jours'
    })


display(display_30_best_clients_activity_7_days.head(30).style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_3d9c1">
#   <thead>
#     <tr>
#       <th id="T_3d9c1_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_3d9c1_level0_col1" class="col_heading level0 col1" >Nombre de séances sur les 7 derniers jours</th>
#       <th id="T_3d9c1_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur les 7 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3d9c1_row0_col0" class="data row0 col0" >T0821 - PROKINETIC</td>
#       <td id="T_3d9c1_row0_col1" class="data row0 col1" >45</td>
#       <td id="T_3d9c1_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_3d9c1_row1_col0" class="data row1 col0" >T0108 - UAB MEDA LT</td>
#       <td id="T_3d9c1_row1_col1" class="data row1 col1" >42</td>
#       <td id="T_3d9c1_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_3d9c1_row2_col0" class="data row2 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_3d9c1_row2_col1" class="data row2 col1" >35</td>
#       <td id="T_3d9c1_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_3d9c1_row3_col0" class="data row3 col0" >T0689 - SCM KINE FORM'</td>
#       <td id="T_3d9c1_row3_col1" class="data row3 col1" >25</td>
#       <td id="T_3d9c1_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_3d9c1_row4_col0" class="data row4 col0" >T1680 - Laure GIULIANI</td>
#       <td id="T_3d9c1_row4_col1" class="data row4 col1" >24</td>
#       <td id="T_3d9c1_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_3d9c1_row5_col0" class="data row5 col0" >T1344 - Christine BERTERO BONNENFANT</td>
#       <td id="T
col0" >T1754 - Christelle DUQUESNE</td>
#       <td id="T_3d9c1_row25_col1" class="data row25 col1" >11</td>
#       <td id="T_3d9c1_row25_col2" class="data row25 col2" >23</td>
#     </tr>
#     <tr>
#       <td id="T_3d9c1_row26_col0" class="data row26 col0" >T0646 - Stéphanie BERTHON</td>
#       <td id="T_3d9c1_row26_col1" class="data row26 col1" >11</td>
#       <td id="T_3d9c1_row26_col2" class="data row26 col2" >23</td>
#     </tr>
#     <tr>
#       <td id="T_3d9c1_row27_col0" class="data row27 col0" >T0937 - SCM KINEMOTIV</td>
#       <td id="T_3d9c1_row27_col1" class="data row27 col1" >10</td>
#       <td id="T_3d9c1_row27_col2" class="data row27 col2" >28</td>
#     </tr>
#     <tr>
#       <td id="T_3d9c1_row28_col0" class="data row28 col0" >T0999 - Jérôme DUCHATELET</td>
#       <td id="T_3d9c1_row28_col1" class="data row28 col1" >10</td>
#       <td id="T_3d9c1_row28_col2" class="data row28 col2" >28</td>
#     </tr>
#     <tr>
#       <td id="T_3d9c1_row29_col0" class="data row29 col0" >T0385 - BATAILLE Maxime</td>
#       <td id="T_3d9c1_row29_col1" class="data row29 col1" >9</td>
#       <td id="T_3d9c1_row29_col2" class="data row29 col2" >30</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_7_days.head(30)['Nom du client'], display_30_best_clients_activity_7_days.head(30)['Nombre de séances sur les 7 derniers jours'], alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres de séances par jours')
plt.title('Classement des 30 clients européens avec le plus de séances sur les 7 derniers jours')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # sur 14 jours

# %%
# @title
display_30_best_clients_activity_14_days = sorted_activity_europe_50[['full_name.1', 'activity_last_2_week', 'rank_activity_14_days']].sort_values(by=['activity_last_2_week'], ascending=False)
display_30_best_clients_activity_14_days = display_30_best_clients_activity_14_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_last_2_week': 'Nombre de séances sur les 14 derniers jours',
    'rank_activity_14_days' : 'Classement en fonction de l\'activité sur les 14 derniers jours'
    })


display(display_30_best_clients_activity_14_days.head(30).style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_fece8">
#   <thead>
#     <tr>
#       <th id="T_fece8_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_fece8_level0_col1" class="col_heading level0 col1" >Nombre de séances sur les 14 derniers jours</th>
#       <th id="T_fece8_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur les 14 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fece8_row0_col0" class="data row0 col0" >T0821 - PROKINETIC</td>
#       <td id="T_fece8_row0_col1" class="data row0 col1" >83</td>
#       <td id="T_fece8_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row1_col0" class="data row1 col0" >T0108 - UAB MEDA LT</td>
#       <td id="T_fece8_row1_col1" class="data row1 col1" >72</td>
#       <td id="T_fece8_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row2_col0" class="data row2 col0" >T1680 - Laure GIULIANI</td>
#       <td id="T_fece8_row2_col1" class="data row2 col1" >70</td>
#       <td id="T_fece8_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row3_col0" class="data row3 col0" >T1354 - LES CURES MARINES</td>
#       <td id="T_fece8_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_fece8_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row4_col0" class="data row4 col0" >T1344 - Christine BERTERO BONNENFANT</td>
#       <td id="T_fece8_row4_col1" class="data row4 col1" >46</td>
#       <td id="T_fece8_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row5_col0" class="data row5 col0" >T1543 - SCM KINESIO</td>
#       <td id="T_fece8_row5_col1" class="data row5 col1" >42</td>
#       <td id="T_fece8_row5_col2" class="data row5 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row6_col0" class="data row6 col0" >T0100 - Franck ARCHIMBAUD</td>
#       <td id="T_fece8_row6_col1" class="data row6 col1" >40</td>
#       <td id="T_fece8_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row7_col0" class="data row7 col0" >T0798 - Sophie FLAGEY LETONDAL</td>
#       <td id="T_fece8_row7_col1" class="data row7 col1" >40</td>
#       <td id="T_fece8_row7_col2" class="data row7 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row8_col0" class="data row8 col0" >T0711 - KINE FLOW</td>
#       <td id="T_fece8_row8_col1" class="data row8 col1" >39</td>
#       <td id="T_fece8_row8_col2" class="data row8 col2" >9</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row9_col0" class="data row9 col0" >T0098 - CAPOT PHILIPPE </td>
#       <td id="T_fece8_row9_col1" class="data row9 col1" >37</td>
#       <td id="T_fece8_row9_col2" class="data row9 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row10_col0" class="data row10 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_fece8_row10_col1" class="data row10 col1" >36</td>
#       <td id="T_fece8_row10_col2" class="data row10 col2" >11</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row11_col0" class="data row11 col0" >T1360 - Guillaume BRUNEL - Pauline GAGNIERE</td>
#       <td id="T_fece8_row11_col1" class="data row11 col1" >34</td>
#       <td id="T_fece8_row11_col2" class="data row11 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row12_col0" class="data row12 col0" >T0689 - SCM KINE FORM'</td>
#       <td id="T_fece8_row12_col1" class="data row12 col1" >33</td>
#       <td id="T_fece8_row12_col2" class="data row12 col2" >13</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row13_col0" class="data row13 col0" >T1640 - DIET Jean-François</td>
#       <td id="T_fece8_row13_col1" class="data row13 col1" >32</td>
#       <td id="T_fece8_row13_col2" class="data row13 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row14_col0" class="data row14 col0" >T0421 - SCM LAU ET CO</td>
#       <td id="T_fece8_row14_col1" class="data row14 col1" >32</td>
#       <td id="T_fece8_row14_col2" class="data row14 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row15_col0" class="data row15 col0" >T1590 - Virginie L'HERMENIER</td>
#       <td id="T_fece8_row15_col1" class="data row15 col1" >31</td>
#       <td id="T_fece8_row15_col2" class="data row15 col2" >16</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row16_col0" class="data row16 col0" >T1428 - 9298-5316 Québec Inc.</td>
#       <td id="T_fece8_row16_col1" class="data row16 col1" >30</td>
#       <td id="T_fece8_row16_col2" class="data row16 col2" >17</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row17_col0" class="data row17 col0" >T0139 - KIWI SANTE</td>
#       <td id="T_fece8_row17_col1" class="data row17 col1" >26</td>
#       <td id="T_fece8_row17_col2" class="data row17 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row18_col0" class="data row18 col0" >T1811 - Christelle GUITARD</td>
#       <td id="T_fece8_row18_col1" class="data row18 col1" >24</td>
#       <td id="T_fece8_row18_col2" class="data row18 col2" >19</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row19_col0" class="data row19 col0" >T0830 - Eve CAVALIE</td>
#       <td id="T_fece8_row19_col1" class="data row19 col1" >23</td>
#       <td id="T_fece8_row19_col2" class="data row19 col2" >20</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row20_col0" class="data row20 col0" >T1781 - AUSRA SPA</td>
#       <td id="T_fece8_row20_col1" class="data row20 col1" >23</td>
#       <td id="T_fece8_row20_col2" class="data row20 col2" >20</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row21_col0" class="data row21 col0" >T1664 - ARK Cabinet de Kiné</td>
#       <td id="T_fece8_row21_col1" class="data row21 col1" >23</td>
#       <td id="T_fece8_row21_col2" class="data row21 col2" >20</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row22_col0" class="data row22 col0" >T0385 - BATAILLE Maxime</td>
#       <td id="T_fece8_row22_col1" class="data row22 col1" >22</td>
#       <td id="T_fece8_row22_col2" class="data row22 col2" >23</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row23_col0" class="data row23 col0" >T1257 - Clinique du monde</td>
#       <td id="T_fece8_row23_col1" class="data row23 col1" >21</td>
#       <td id="T_fece8_row23_col2" class="data row23 col2" >24</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row24_col0" class="data row24 col0" >T1698 - CRYOCARE</td>
#       <td id="T_fece8_row24_col1" class="data row24 col1" >20</td>
#       <td id="T_fece8_row24_col2" class="data row24 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row25_col0" class="data row25 col0" >T0785 - Perrine SAVOURAT</td>
#       <td id="T_fece8_row25_col1" class="data row25 col1" >20</td>
#       <td id="T_fece8_row25_col2" class="data row25 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row26_col0" class="data row26 col0" >T1538 - François MIGUEL</td>
#       <td id="T_fece8_row26_col1" class="data row26 col1" >20</td>
#       <td id="T_fece8_row26_col2" class="data row26 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row27_col0" class="data row27 col0" >T1776 - Fanny LE GAL</td>
#       <td id="T_fece8_row27_col1" class="data row27 col1" >20</td>
#       <td id="T_fece8_row27_col2" class="data row27 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row28_col0" class="data row28 col0" >T0091 - Selarl MEDVASC 32</td>
#       <td id="T_fece8_row28_col1" class="data row28 col1" >19</td>
#       <td id="T_fece8_row28_col2" class="data row28 col2" >29</td>
#     </tr>
#     <tr>
#       <td id="T_fece8_row29_col0" class="data row29 col0" >T1754 - Christelle DUQUESNE</td>
#       <td id="T_fece8_row29_col1" class="data row29 col1" >19</td>
#       <td id="T_fece8_row29_col2" class="data row29 col2" >29</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_14_days.head(30)['Nom du client'], display_30_best_clients_activity_14_days.head(30)['Nombre de séances sur les 14 derniers jours'], alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres de séances par jours')
plt.title('Classement des 30 clients européens avec le plus de séances sur les 14 derniers jours')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # sur 30 jours

# %%
# @title
display_30_best_clients_activity_30_days = sorted_activity_europe_50[['full_name.1', 'activity_last_30_days', 'rank_activity_30_days']].sort_values(by=['activity_last_30_days'], ascending=False)
display_30_best_clients_activity_30_days = display_30_best_clients_activity_30_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_last_30_days': 'Nombre de séances sur les 30 derniers jours',
    'rank_activity_30_days' : 'Classement en fonction de l\'activité sur les 30 derniers jours'
    })


display(display_30_best_clients_activity_30_days.head(30).style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_710aa">
#   <thead>
#     <tr>
#       <th id="T_710aa_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_710aa_level0_col1" class="col_heading level0 col1" >Nombre de séances sur les 30 derniers jours</th>
#       <th id="T_710aa_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur les 30 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_710aa_row0_col0" class="data row0 col0" >T0108 - UAB MEDA LT</td>
#       <td id="T_710aa_row0_col1" class="data row0 col1" >272</td>
#       <td id="T_710aa_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row1_col0" class="data row1 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_710aa_row1_col1" class="data row1 col1" >238</td>
#       <td id="T_710aa_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row2_col0" class="data row2 col0" >T0821 - PROKINETIC</td>
#       <td id="T_710aa_row2_col1" class="data row2 col1" >235</td>
#       <td id="T_710aa_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row3_col0" class="data row3 col0" >T1680 - Laure GIULIANI</td>
#       <td id="T_710aa_row3_col1" class="data row3 col1" >208</td>
#       <td id="T_710aa_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row4_col0" class="data row4 col0" >T0100 - Franck ARCHIMBAUD</td>
#       <td id="T_710aa_row4_col1" class="data row4 col1" >144</td>
#       <td id="T_710aa_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row5_col0" class="data row5 col0" >T0792 - SCM TRIQUETRUM</td>
#       <td id="T_710aa_row5_col1" class="data row5 col1" >132</td>
#       <td id="T_710aa_row5_col2" class="data row5 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row6_col0" class="data row6 col0" >T1344 - Christine BERTERO BONNENFANT</td>
#       <td id="T_710aa_row6_col1" class="data row6 col1" >126</td>
#       <td id="T_710aa_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row7_col0" class="data row7 col0" >T0711 - KINE FLOW</td>
#       <td id="T_710aa_row7_col1" class="data row7 col1" >121</td>
#       <td id="T_710aa_row7_col2" class="data row7 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row8_col0" class="data row8 col0" >T0689 - SCM KINE FORM'</td>
#       <td id="T_710aa_row8_col1" class="data row8 col1" >118</td>
#       <td id="T_710aa_row8_col2" class="data row8 col2" >9</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row9_col0" class="data row9 col0" >T1543 - SCM KINESIO</td>
#       <td id="T_710aa_row9_col1" class="data row9 col1" >111</td>
#       <td id="T_710aa_row9_col2" class="data row9 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row10_col0" class="data row10 col0" >T1640 - DIET Jean-François</td>
#       <td id="T_710aa_row10_col1" class="data row10 col1" >111</td>
#       <td id="T_710aa_row10_col2" class="data row10 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row11_col0" class="data row11 col0" >T1013 - Natalia BARTOSEK</td>
#       <td id="T_710aa_row11_col1" class="data row11 col1" >110</td>
#       <td id="T_710aa_row11_col2" class="data row11 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row12_col0" class="data row12 col0" >T0098 - CAPOT PHILIPPE </td>
#       <td id="T_710aa_row12_col1" class="data row12 col1" >107</td>
#       <td id="T_710aa_row12_col2" class="data row12 col2" >13</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row13_col0" class="data row13 col0" >T1360 - Guillaume BRUNEL - Pauline GAGNIERE</td>
#       <td id="T_710aa_row13_col1" class="data row13 col1" >101</td>
#       <td id="T_710aa_row13_col2" class="data row13 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row14_col0" class="data row14 col0" >T1754 - Christelle DUQUESNE</td>
#       <td id="T_710aa_row14_col1" class="data row14 col1" >100</td>
#       <td id="T_710aa_row14_col2" class="data row14 col2" >15</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row15_col0" class="data row15 col0" >T1354 - LES CURES MARINES</td>
#       <td id="T_710aa_row15_col1" class="data row15 col1" >96</td>
#       <td id="T_710aa_row15_col2" class="data row15 col2" >16</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row16_col0" class="data row16 col0" >T0745 - Thibaut LEONE</td>
#       <td id="T_710aa_row16_col1" class="data row16 col1" >93</td>
#       <td id="T_710aa_row16_col2" class="data row16 col2" >17</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row17_col0" class="data row17 col0" >T1428 - 9298-5316 Québec Inc.</td>
#       <td id="T_710aa_row17_col1" class="data row17 col1" >90</td>
#       <td id="T_710aa_row17_col2" class="data row17 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row18_col0" class="data row18 col0" >T0798 - Sophie FLAGEY LETONDAL</td>
#       <td id="T_710aa_row18_col1" class="data row18 col1" >90</td>
#       <td id="T_710aa_row18_col2" class="data row18 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row19_col0" class="data row19 col0" >T1776 - Fanny LE GAL</td>
#       <td id="T_710aa_row19_col1" class="data row19 col1" >89</td>
#       <td id="T_710aa_row19_col2" class="data row19 col2" >20</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row20_col0" class="data row20 col0" >T0139 - KIWI SANTE</td>
#       <td id="T_710aa_row20_col1" class="data row20 col1" >87</td>
#       <td id="T_710aa_row20_col2" class="data row20 col2" >21</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row21_col0" class="data row21 col0" >T1590 - Virginie L'HERMENIER</td>
#       <td id="T_710aa_row21_col1" class="data row21 col1" >86</td>
#       <td id="T_710aa_row21_col2" class="data row21 col2" >22</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row22_col0" class="data row22 col0" >T1408 - Mandy ROURRET</td>
#       <td id="T_710aa_row22_col1" class="data row22 col1" >85</td>
#       <td id="T_710aa_row22_col2" class="data row22 col2" >23</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row23_col0" class="data row23 col0" >T1686 - SCM RHEA THERAPIE</td>
#       <td id="T_710aa_row23_col1" class="data row23 col1" >83</td>
#       <td id="T_710aa_row23_col2" class="data row23 col2" >24</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row24_col0" class="data row24 col0" >T0091 - Selarl MEDVASC 32</td>
#       <td id="T_710aa_row24_col1" class="data row24 col1" >82</td>
#       <td id="T_710aa_row24_col2" class="data row24 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row25_col0" class="data row25 col0" >T0830 - Eve CAVALIE</td>
#       <td id="T_710aa_row25_col1" class="data row25 col1" >81</td>
#       <td id="T_710aa_row25_col2" class="data row25 col2" >26</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row26_col0" class="data row26 col0" >T0421 - SCM LAU ET CO</td>
#       <td id="T_710aa_row26_col1" class="data row26 col1" >81</td>
#       <td id="T_710aa_row26_col2" class="data row26 col2" >26</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row27_col0" class="data row27 col0" >T1421 - Sandra BONDON</td>
#       <td id="T_710aa_row27_col1" class="data row27 col1" >81</td>
#       <td id="T_710aa_row27_col2" class="data row27 col2" >26</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row28_col0" class="data row28 col0" >T1507 - AXE KINE</td>
#       <td id="T_710aa_row28_col1" class="data row28 col1" >80</td>
#       <td id="T_710aa_row28_col2" class="data row28 col2" >29</td>
#     </tr>
#     <tr>
#       <td id="T_710aa_row29_col0" class="data row29 col0" >T1664 - ARK Cabinet de Kiné</td>
#       <td id="T_710aa_row29_col1" class="data row29 col1" >79</td>
#       <td id="T_710aa_row29_col2" class="data row29 col2" >30</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_30_days.head(30)['Nom du client'], display_30_best_clients_activity_30_days.head(30)['Nombre de séances sur les 30 derniers jours'], alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres de séances par jours')
plt.title('Classement des 30 clients européens avec le plus de séances sur les 30 derniers jours')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # sur 90 jours

# %%
# @title
display_30_best_clients_activity_90_days = sorted_activity_europe_50[['full_name.1', 'activity_last_90_days', 'rank_activity_90_days']].sort_values(by=['activity_last_90_days'], ascending=False)
display_30_best_clients_activity_90_days = display_30_best_clients_activity_90_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_last_90_days': 'Nombre de séances sur les 90 derniers jours',
    'rank_activity_90_days' : 'Classement en fonction de l\'activité sur les 90 derniers jours'
    })


display(display_30_best_clients_activity_90_days.head(30).style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_cc1e8">
#   <thead>
#     <tr>
#       <th id="T_cc1e8_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_cc1e8_level0_col1" class="col_heading level0 col1" >Nombre de séances sur les 90 derniers jours</th>
#       <th id="T_cc1e8_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur les 90 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cc1e8_row0_col0" class="data row0 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_cc1e8_row0_col1" class="data row0 col1" >1040</td>
#       <td id="T_cc1e8_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_cc1e8_row1_col0" class="data row1 col0" >T0108 - UAB MEDA LT</td>
#       <td id="T_cc1e8_row1_col1" class="data row1 col1" >951</td>
#       <td id="T_cc1e8_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_cc1e8_row2_col0" class="data row2 col0" >T0821 - PROKINETIC</td>
#       <td id="T_cc1e8_row2_col1" class="data row2 col1" >764</td>
#       <td id="T_cc1e8_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_cc1e8_row3_col0" class="data row3 col0" >T1680 - Laure GIULIANI</td>
#       <td id="T_cc1e8_row3_col1" class="data row3 col1" >674</td>
#       <td id="T_cc1e8_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_cc1e8_
row24_col2" class="data row24 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_cc1e8_row25_col0" class="data row25 col0" >T1360 - Guillaume BRUNEL - Pauline GAGNIERE</td>
#       <td id="T_cc1e8_row25_col1" class="data row25 col1" >308</td>
#       <td id="T_cc1e8_row25_col2" class="data row25 col2" >26</td>
#     </tr>
#     <tr>
#       <td id="T_cc1e8_row26_col0" class="data row26 col0" >T0798 - Sophie FLAGEY LETONDAL</td>
#       <td id="T_cc1e8_row26_col1" class="data row26 col1" >306</td>
#       <td id="T_cc1e8_row26_col2" class="data row26 col2" >27</td>
#     </tr>
#     <tr>
#       <td id="T_cc1e8_row27_col0" class="data row27 col0" >T1686 - SCM RHEA THERAPIE</td>
#       <td id="T_cc1e8_row27_col1" class="data row27 col1" >305</td>
#       <td id="T_cc1e8_row27_col2" class="data row27 col2" >28</td>
#     </tr>
#     <tr>
#       <td id="T_cc1e8_row28_col0" class="data row28 col0" >T1327 - Anne TEKO GEIGER</td>
#       <td id="T_cc1e8_row28_col1" class="data row28 col1" >303</td>
#       <td id="T_cc1e8_row28_col2" class="data row28 col2" >29</td>
#     </tr>
#     <tr>
#       <td id="T_cc1e8_row29_col0" class="data row29 col0" >T1421 - Sandra BONDON</td>
#       <td id="T_cc1e8_row29_col1" class="data row29 col1" >300</td>
#       <td id="T_cc1e8_row29_col2" class="data row29 col2" >30</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_90_days.head(30)['Nom du client'], display_30_best_clients_activity_90_days.head(30)['Nombre de séances sur les 90 derniers jours'], alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres de séances par jours')
plt.title('Classement des 30 clients européens avec le plus de séances sur les 90 derniers jours')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # sur 1 an

# %%
# @title
display_30_best_clients_activity_year = sorted_activity_europe_50[['full_name.1', 'activity_last_year', 'rank_activity_year']].sort_values(by=['activity_last_year'], ascending=False)
display_30_best_clients_activity_year = display_30_best_clients_activity_year.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_last_year': 'Nombre de séances sur 1 an',
    'rank_activity_year' : 'Classement en fonction de l\'activité sur 1 an'
    })


display(display_30_best_clients_activity_year.head(30).style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_bbf50">
#   <thead>
#     <tr>
#       <th id="T_bbf50_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_bbf50_level0_col1" class="col_heading level0 col1" >Nombre de séances sur 1 an</th>
#       <th id="T_bbf50_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur 1 an</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bbf50_row0_col0" class="data row0 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_bbf50_row0_col1" class="data row0 col1" >5642</td>
#       <td id="T_bbf50_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bbf50_row1_col0" class="data row1 col0" >T0100 - Franck ARCHIMBAUD</td>
#       <td id="T_bbf50_row1_col1" class="data row1 col1" >4087</td>
#       <td id="T_bbf50_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_bbf50_row2_col0" class="data row2 col0" >T0108 - UAB MEDA LT</td>
#       <td id="T_bbf50_row2_col1" class="data row2 col1" >3499</td>
#       <td id="T_bbf50_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_bbf50_row3_col0" class="data row3 col0" >T0711 - KINE FLOW</td>
#       <td id="T_bbf50_row3_col1" class="data row3 col1" >2677</td>
#       <td id="T_bbf50_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_bbf50_row4_col0" class="data row4 col0" >T0821 - PROKINETIC</td>
#       <td id="T_bbf50_row4_col1" class="data row4 col1" >2539</td>
#       <td id="T_bbf50_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_bbf50_row5_col0" class="data row5 col0" >T0745 - Thibaut LEONE</td>
#       <td id="T_bbf50_row5_col1" class="data row5 col1" >2312</td>
#       <td id="T_bbf50_row5_col2" class="data row5 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_bbf50_row6_col0" class="data row6 col0" >T0091 - Selarl MEDVASC 32</td>
#       <td id="T_bbf50_row6_col1" class="data row6 col1" >2206</td>
#       <td id="T_bbf50_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_bbf50_row7_col0" class="data row7 col0" >T0689 - SCM KINE FORM'</td>
#       <td id="T_bbf50_row7_col1" class="data row7 col1" >2127</td>
#       <td id="T_bbf50_row7_col2" class="data row7 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_bbf50_row8_col0" class="data row8 col0" >T1013 - Natalia BARTOSEK</td>
#       <td id="T_bbf50_row8_col1" class="data row8 col1" >1836</td>
#       <td id="T_bbf50_row8_col2" class="data row8 col2" >9</td>
#     </tr>
#     <tr>
#       <td id="T_bbf50_row9_col0" class="data row9 col0" >T1543 - SCM KINESIO</td>
#       <td id="T_bbf50_row9_col1" class="data row9 col1" >1810</td>
#       <td id="T_bbf50_row9_col2" class="data row9 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_bbf50_
pha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres de séances par jours')
plt.title('Classement des 30 clients européens avec le plus de séances sur 1 an')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # Tests sortie détails d'un client

# %%
# @title
# prompt: From the database sorted_activity_europe_50 display the following information:
# 1. The current date
# 2. The rank_activity_per_day of the full_name.1 called T0613 - Aqua Kiné Santé
# 3. The counts of the full_name.1 called T0613 - Aqua Kiné Santé
# 4. The activity_per_day of the full_name.1 called T0613 - Aqua Kiné Santé
# 5. The first_activity of the full_name.1 called T0613 - Aqua Kiné Santé
# 6. The last_activity of the full_name.1 called T0613 - Aqua Kiné Santé
# 7. The number_days of the full_name.1 called T0613 - Aqua Kiné Santé
# 8. The activity_last_week of the full_name.1 called T0613 - Aqua Kiné Santé
# 9. The activity_last_2_week of the full_name.1 called T0613 - Aqua Kiné Santé
# 10. The activity_last_30_days of the full_name.1 called T0613 - Aqua Kiné Santé

import datetime

# Assuming 'sorted_activity_europe_50' DataFrame is already available from the previous code

# Filter the DataFrame for the specific full_name.1
target_activity = sorted_activity_europe_50[sorted_activity_europe_50['full_name.1'] == 'T0613 - Aqua Kiné Santé']

if not target_activity.empty:
  current_date = datetime.date.today()
  rank = target_activity['rank_activity_per_day_since_acquisition'].iloc[0]
  counts = target_activity['counts'].iloc[0]
  activity_per_day = target_activity['activity_per_day_since_acquisition'].iloc[0]
  first_activity = target_activity['first_activity'].iloc[0]
  last_activity = target_activity['last_activity'].iloc[0]
  since_asquisition = target_activity['formatted_duration'].iloc[0]
  activity_last_week = target_activity['activity_last_week'].iloc[0]
  activity_per_day_last_week = target_activity['activity_per_day_7_days'].iloc[0]
  rank_last_week = target_activity['rank_activity_7_days'].iloc[0]
  activity_last_2_week = target_activity['activity_last_2_week'].iloc[0]
  activity_per_day_last_2_week = target_activity['activity_per_day_14_days'].iloc[0]
  rank_last_2_week = target_activity['rank_activity_14_days'].iloc[0]
  activity_last_30_days = target_activity['activity_last_30_days'].iloc[0]
  activity_per_day_last_30_days = target_activity['activity_per_day_30_days'].iloc[0]
  rank_last_30_days = target_activity['rank_activity_30_days'].iloc[0]
  activity_last_90_days = target_activity['activity_last_90_days'].iloc[0]
  activity_per_day_last_90_days = target_activity['activity_per_day_90_days'].iloc[0]
  rank_last_90_days = target_activity['rank_activity_90_days'].iloc[0]
  activity_last_year = target_activity['activity_last_year'].iloc[0]
  activity_per_day_last_year = target_activity['activity_per_day_year'].iloc[0]
  rank_last_year = target_activity['rank_activity_year'].iloc[0]

  print('\033[1;4m' + "Détails pour le client T0613 - Aqua Kiné Santé:" + '\033[0m')
  print("\n")
  print(f"Date d\'aujourd\'hui: {current_date}")
  print(f"Date de la première séance: {first_activity}")
  print(f"Date de la dernière séance: {last_activity}")
  print(f"Appareil acquis il y a: {since_asquisition}")
  print("\n")
  print('\033[1;4m' + "Stats sur les 7 derniers jours" + '\033[0m')
  print(f"Nombres de séances: {activity_last_week}")
  print(f"Nombres de séances par jour: {activity_per_day_last_week}")
  print(f"Classement: {rank_last_week} ")
  print("\n")
  print('\033[1;4m' + "Stats sur les 14 derniers jours" + '\033[0m')
  print(f"Nombres de séances: {activity_last_2_week}")
  print(f"Nombres de séances par jour: {activity_per_day_last_2_week}")
  print(f"Classement: {rank_last_2_week}")
  print("\n")
  print('\033[1;4m' + "Stats sur les 30 derniers jours" + '\033[0m')
  print(f"Nombres de séances: {activity_last_30_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_30_days}")
  print(f"Classement: {rank_last_30_days}")
  print("\n")
  print('\033[1;4m' + "Stats sur les 90 derniers jours" + '\033[0m')
  print(f"Nombres de séances: {activity_last_90_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_90_days}")
  print(f"Classement: {rank_last_90_days}")
  print("\n")
  print('\033[1;4m' + "Stats sur 1 an" + '\033[0m')
  print(f"Nombres de séances: {activity_last_year}")
  print(f"Nombres de séances par jour: {activity_per_day_last_year}")
  print(f"Classement: {rank_last_year}")
  print("\n")
  print('\033[1;4m' + "Stats depuis l\'acquisition" + '\033[0m')
  print(f"Nombres de séances: {counts}")
  print(f"Nombres moyen de séances par jour: {activity_per_day}")
  print(f"Classement: {rank}")
else:
  print("T0613 - Aqua Kiné Santé not found in the database.")
# Out:
# Détails pour le client T0613 - Aqua Kiné Santé:
#
#
# Date d'aujourd'hui: 2025-01-09
# Date de la première séance: 2021-05-31 08:37:59
# Date de la dernière séance: 2025-01-06 14:29:11
# Appareil acquis il y a: 3 an(s), 7 mois, 12 jour(s)
#
#
# Stats sur les 7 derniers jours
# Nombres de séances: 35
# Nombres de séances par jour: 5.0
# Classement: 3
#
#
# Stats sur les 14 derniers jours
# Nombres de séances: 36
# Nombres de séances par jour: 2.5714285714285716
# Classement: 11
#
#
# Stats sur les 30 derniers jours
# Nombres de séances: 238
# Nombres de séances par jour: 7.933333333333334
# Classement: 2
#
#
# Stats sur les 90 derniers jours
# Nombres de séances: 1040
# Nombres de séances par jour: 11.555555555555555
# Classement: 1
#
#
# Stats sur 1 an
# Nombres de séances: 5642
# Nombres de séances par jour: 15.457534246575342
# Classement: 1
#
#
# Stats depuis l'acquisition
# Nombres de séances: 21593
# Nombres moyen de séances par jour: 16.3955960516325
# Classement: 1

# %%
# @title
# Filter the DataFrame for the specific full_name.1
target_activity = sorted_activity_europe_50[sorted_activity_europe_50['full_name.1'] == 'T0100 - Franck ARCHIMBAUD']

if not target_activity.empty:
  current_date = datetime.date.today()
  rank = target_activity['rank_activity_per_day_since_acquisition'].iloc[0]
  counts = target_activity['counts'].iloc[0]
  activity_per_day = target_activity['activity_per_day_since_acquisition'].iloc[0]
  first_activity = target_activity['first_activity'].iloc[0]
  last_activity = target_activity['last_activity'].iloc[0]
  since_asquisition = target_activity['formatted_duration'].iloc[0]
  activity_last_week = target_activity['activity_last_week'].iloc[0]
  activity_per_day_last_week = target_activity['activity_per_day_7_days'].iloc[0]
  rank_last_week = target_activity['rank_activity_7_days'].iloc[0]
  activity_last_2_week = target_activity['activity_last_2_week'].iloc[0]
  activity_per_day_last_2_week = target_activity['activity_per_day_14_days'].iloc[0]
  rank_last_2_week = target_activity['rank_activity_14_days'].iloc[0]
  activity_last_30_days = target_activity['activity_last_30_days'].iloc[0]
  activity_per_day_last_30_days = target_activity['activity_per_day_30_days'].iloc[0]
  rank_last_30_days = target_activity['rank_activity_30_days'].iloc[0]
  activity_last_90_days = target_activity['activity_last_90_days'].iloc[0]
  activity_per_day_last_90_days = target_activity['activity_per_day_90_days'].iloc[0]
  rank_last_90_days = target_activity['rank_activity_90_days'].iloc[0]
  activity_last_year = target_activity['activity_last_year'].iloc[0]
  activity_per_day_last_year = target_activity['activity_per_day_year'].iloc[0]
  rank_last_year = target_activity['rank_activity_year'].iloc[0]

  print('\033[1;4m' + "Détails pour le client T0100 - Franck ARCHIMBAUD:" + '\033[0m')
  print("\n")
  print(f"Date d\'aujourd\'hui: {current_date}")
  print(f"Date de la première séance: {first_activity}")
  print(f"Date de la dernière séance: {last_activity}")
  print(f"Appareil acquis il y a: {since_asquisition}")
  print("\n")
  print('\033[1;4m' + "Stats sur les 7 derniers jours" + '\033[0m')
  print(f"Nombres de séances: {activity_last_week}")
  print(f"Nombres de séances par jour: {activity_per_day_last_week}")
  print(f"Classement: {rank_last_week} ")
  print("\n")
  print('\033[1;4m' + "Stats sur les 14 derniers jours" + '\033[0m')
  print(f"Nombres de séances: {activity_last_2_week}")
  print(f"Nombres de séances par jour: {activity_per_day_last_2_week}")
  print(f"Classement: {rank_last_2_week}")
  print("\n")
  print('\033[1;4m' + "Stats sur les 30 derniers jours" + '\033[0m')
  print(f"Nombres de séances: {activity_last_30_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_30_days}")
  print(f"Classement: {rank_last_30_days}")
  print("\n")
  print('\033[1;4m' + "Stats sur les 90 derniers jours" + '\033[0m')
  print(f"Nombres de séances: {activity_last_90_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_90_days}")
  print(f"Classement: {rank_last_90_days}")
  print("\n")
  print('\033[1;4m' + "Stats sur 1 an" + '\033[0m')
  print(f"Nombres de séances: {activity_last_year}")
  print(f"Nombres de séances par jour: {activity_per_day_last_year}")
  print(f"Classement: {rank_last_year}")
  print("\n")
  print('\033[1;4m' + "Stats depuis l\'acquisition" + '\033[0m')
  print(f"Nombres de séances: {counts}")
  print(f"Nombres moyen de séances par jour: {activity_per_day}")
  print(f"Classement: {rank}")
else:
  print("T0613 - Aqua Kiné Santé not found in the database.")
# Out:
# Détails pour le client T0100 - Franck ARCHIMBAUD:
#
#
# Date d'aujourd'hui: 2025-01-09
# Date de la première séance: 2020-02-10 16:07:32
# Date de la dernière séance: 2025-01-06 14:53:22
# Appareil acquis il y a: 4 an(s), 11 mois, 2 jour(s)
#
#
# Stats sur les 7 derniers jours
# Nombres de séances: 19
# Nombres de séances par jour: 2.7142857142857144
# Classement: 9
#
#
# Stats sur les 14 derniers jours
# Nombres de séances: 40
# Nombres de séances par jour: 2.857142857142857
# Classement: 7
#
#
# Stats sur les 30 derniers jours
# Nombres de séances: 144
# Nombres de séances par jour: 4.8
# Classement: 5
#
#
# Stats sur les 90 derniers jours
# Nombres de séances: 587
# Nombres de séances par jour: 6.522222222222222
# Classement: 6
#
#
# Stats sur 1 an
# Nombres de séances: 4087
# Nombres de séances par jour: 11.197260273972603
# Classement: 2
#
#
# Stats depuis l'acquisition
# Nombres de séances: 21681
# Nombres moyen de séances par jour: 12.098772321428571
# Classement: 2
