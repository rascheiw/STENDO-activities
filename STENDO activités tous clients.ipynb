# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#sns.set() # to change theme

#from google.colab import drive
#drive.mount('/content/drive')
#display only 1 digit after decimal point
pd.options.display.float_format = '{:.1f}'.format

# %%
activity = pd.read_excel('/Users/raphael/Documents/STENDO-activities/activity.xlsx')

# %% [markdown]
# # Travail en arrière plan

# %%
print('activity shape =', activity.shape)
# Out:
# activity shape = (522270, 15)

# %%
activity
# Out:
#               mac_address                          full_name  \
# 0       C0:29:34:FA:07:8B  C0:29:34:FA:07:8B 4002-0421-00203
# 1       D7:5F:AD:57:AA:38  D7:5F:AD:57:AA:38 4002-0421-00201
# 2       EA:4B:F5:67:30:F9  EA:4B:F5:67:30:F9 4002-0421-00192
# 3       C6:64:81:41:DD:33  C6:64:81:41:DD:33 4002-0721-00223
# 4       f3:0e:8d:37:39:31  f3:0e:8d:37:39:31 4001-1220-00171
# ...                   ...                                ...
# 522265  EA:1E:CF:41:CE:0B  EA:1E:CF:41:CE:0B 4002-0920-00136
# 522266  FC:83:FD:79:73:82  FC:83:FD:79:73:82 4002-0221-00187
# 522267  C0:29:34:FA:07:8B  C0:29:34:FA:07:8B 4002-0421-00203
# 522268  C0:29:34:FA:07:8B  C0:29:34:FA:07:8B 4002-0421-00203
# 522269  C0:29:34:FA:07:8B  C0:29:34:FA:07:8B 4002-0421-00203
#
#                          name                                   full_name.1  \
# 0       Charbonnier-Montaudié  T0649 - Marie-Caroline CHARBONNIER MONTAUDIE
# 1           Claire BARRILLIET                     T0723 - Claire BARRILLIET
# 2          Silver Form Alsace                         T0627 - CAPITAL SANTE
# 3              SCM TRIQUETRUM                        T0792 - SCM TRIQUETRUM
# 4                       Marro                       T0610 - Marro Joséphine
# ...                       ...                                           ...
# 522265                 Ganier                         T0417 - GANIER Nicole
# 522266        Aqua Kiné Santé                       T0613 - Aqua Kiné Santé
# 522267  Charbonnier-Montaudié  T0649 - Marie-Caroline CHARBONNIER MONTAUDIE
# 522268  Charbonnier-Montaudié  T0649 - Marie-Caroline CHARBONNIER MONTAUDIE
# 522269  Charbonnier-Montaudié  T0649 - Marie-Caroline CHARBONNIER MONTAUDIE
#
#        spare_type                  start_date  duration  real_duration  \
# 0           pants  2021-10-28 09:47:57.000000        20              0
# 1           pants  2021-10-28 10:19:38.000000        30              0
# 2           pants  2021-10-28 09:42:49.000000        30           1800
# 3           pants  2021-10-28 10:01:53.000000        20           1200
# 4           pants  2021-10-28 09:51:52.000000        20           1200
# ...           ...                         ...       ...            ...
# 522265      pants  2021-10-28 09:09:39.000000        20           1200
# 522266      pants  2021-10-28 09:27:45.000000        20           1200
# 522267      pants  2021-10-28 09:41:06.000000        20              0
# 522268      pants  2021-10-28 09:42:23.000000        20              0
# 522269      pants  2021-10-28 09:44:09.000000        20              0
#
#         percentage_real_duration  care_note ps_server economic_model  \
# 0                            0.0          0        EU      UNLIMITED
# 1                            0.0          0        EU      UNLIMITED
# 2                          100.0          0        EU      UNLIMITED
# 3                          100.0          0        EU      UNLIMITED
# 4                          100.0          0        EU      UNLIMITED
# ...                          ...        ...       ...            ...
# 522265                     100.0          5        EU      UNLIMITED
# 522266                     100.0          5        EU      UNLIMITED
# 522267                       0.0          0        EU      UNLIMITED
# 522268                       0.0          0        EU      UNLIMITED
# 522269                       0.0          0        EU      UNLIMITED
#
#         credit_number full_name.2  active
# 0                   1   Chronique    True
# 1                   1  Entretien1    True
# 2                   1       Mixte    True
# 3                   1   Chronique    True
# 4                   1        -12h    True
# ...               ...         ...     ...
# 522265              1       Détox    True
# 522266              1   Chronique    True
# 522267              1   Chronique    True
# 522268              1   Chronique    True
# 522269              1   Chronique    True
#
# [522270 rows x 15 columns]

# %%
activity.isna().sum()
# Out:
# mac_address                     0
# full_name                       0
# name                            0
# full_name.1                     0
# spare_type                      0
# start_date                      0
# duration                        0
# real_duration                   0
# percentage_real_duration    30003
# care_note                       0
# ps_server                       0
# economic_model                  0
# credit_number                   0
# full_name.2                     0
# active                          0
# dtype: int64

# %%
#activity[activity['percentage_real_duration'].isna()]

# %%
activity['percentage_real_duration'] = activity['real_duration'] / (activity['duration'] * 60) * 100

# %%
activity
# Out:
#               mac_address                          full_name  \
# 0       C0:29:34:FA:07:8B  C0:29:34:FA:07:8B 4002-0421-00203
# 1       D7:5F:AD:57:AA:38  D7:5F:AD:57:AA:38 4002-0421-00201
# 2       EA:4B:F5:67:30:F9  EA:4B:F5:67:30:F9 4002-0421-00192
# 3       C6:64:81:41:DD:33  C6:64:81:41:DD:33 4002-0721-00223
# 4       f3:0e:8d:37:39:31  f3:0e:8d:37:39:31 4001-1220-00171
# ...                   ...                                ...
# 522265  EA:1E:CF:41:CE:0B  EA:1E:CF:41:CE:0B 4002-0920-00136
# 522266  FC:83:FD:79:73:82  FC:83:FD:79:73:82 4002-0221-00187
# 522267  C0:29:34:FA:07:8B  C0:29:34:FA:07:8B 4002-0421-00203
# 522268  C0:29:34:FA:07:8B  C0:29:34:FA:07:8B 4002-0421-00203
# 522269  C0:29:34:FA:07:8B  C0:29:34:FA:07:8B 4002-0421-00203
#
#                          name                                   full_name.1  \
# 0       Charbonnier-Montaudié  T0649 - Marie-Caroline CHARBONNIER MONTAUDIE
# 1           Claire BARRILLIET                     T0723 - Claire BARRILLIET
# 2          Silver Form Alsace                         T0627 - CAPITAL SANTE
# 3              SCM TRIQUETRUM                        T0792 - SCM TRIQUETRUM
# 4                       Marro                       T0610 - Marro Joséphine
# ...                       ...                                           ...
# 522265                 Ganier                         T0417 - GANIER Nicole
# 522266        Aqua Kiné Santé                       T0613 - Aqua Kiné Santé
# 522267  Charbonnier-Montaudié  T0649 - Marie-Caroline CHARBONNIER MONTAUDIE
# 522268  Charbonnier-Montaudié  T0649 - Marie-Caroline CHARBONNIER MONTAUDIE
# 522269  Charbonnier-Montaudié  T0649 - Marie-Caroline CHARBONNIER MONTAUDIE
#
#        spare_type                  start_date  duration  real_duration  \
# 0           pants  2021-10-28 09:47:57.000000        20              0
# 1           pants  2021-10-28 10:19:38.000000        30              0
# 2           pants  2021-10-28 09:42:49.000000        30           1800
# 3           pants  2021-10-28 10:01:53.000000        20           1200
# 4           pants  2021-10-28 09:51:52.000000        20           1200
# ...           ...                         ...       ...            ...
# 522265      pants  2021-10-28 09:09:39.000000        20           1200
# 522266      pants  2021-10-28 09:27:45.000000        20           1200
# 522267      pants  2021-10-28 09:41:06.000000        20              0
# 522268      pants  2021-10-28 09:42:23.000000        20              0
# 522269      pants  2021-10-28 09:44:09.000000        20              0
#
#         percentage_real_duration  care_note ps_server economic_model  \
# 0                            0.0          0        EU      UNLIMITED
# 1                            0.0          0        EU      UNLIMITED
# 2                          100.0          0        EU      UNLIMITED
# 3                          100.0          0        EU      UNLIMITED
# 4                          100.0          0        EU      UNLIMITED
# ...                          ...        ...       ...            ...
# 522265                     100.0          5        EU      UNLIMITED
# 522266                     100.0          5        EU      UNLIMITED
# 522267                       0.0          0        EU      UNLIMITED
# 522268                       0.0          0        EU      UNLIMITED
# 522269                       0.0          0        EU      UNLIMITED
#
#         credit_number full_name.2  active
# 0                   1   Chronique    True
# 1                   1  Entretien1    True
# 2                   1       Mixte    True
# 3                   1   Chronique    True
# 4                   1        -12h    True
# ...               ...         ...     ...
# 522265              1       Détox    True
# 522266              1   Chronique    True
# 522267              1   Chronique    True
# 522268              1   Chronique    True
# 522269              1   Chronique    True
#
# [522270 rows x 15 columns]

# %%
activity.isna().sum()
# Out:
# mac_address                 0
# full_name                   0
# name                        0
# full_name.1                 0
# spare_type                  0
# start_date                  0
# duration                    0
# real_duration               0
# percentage_real_duration    0
# care_note                   0
# ps_server                   0
# economic_model              0
# credit_number               0
# full_name.2                 0
# active                      0
# dtype: int64

# %%
activity = activity.drop(columns=['mac_address', 'name', 'care_note', 'credit_number', 'active'])

# %%
#activity

# %%
activity_europe = activity[(activity['ps_server'] == 'EU') & (activity['spare_type'] == 'pants')]
#activity_europe

# %%
activity_europe = activity_europe[activity_europe['full_name.1'] != 'T0362 - LETESTEUR Ludovic']
#activity_europe

# %%
activity_asia = activity[(activity['ps_server'] == 'ASIA') & (activity['spare_type'] == 'pants')]
#activity_asia

# %%
activity_europe_50 = activity_europe[activity_europe['percentage_real_duration'] >= 50]
#activity_europe_50

# %%
activity_asia_50 = activity_asia[activity_asia['percentage_real_duration'] >= 50]
#activity_asia_50

# %%
activity_europe_50 = activity_europe_50.sort_values(by=['full_name.1'])
activity_europe_50
# Out:
#                                  full_name  \
# 447702  F2:7E:05:A5:6A:E5 400-2-0220-00004
# 195210  F2:7E:05:A5:6A:E5 400-2-0220-00004
# 40675   F2:7E:05:A5:6A:E5 400-2-0220-00004
# 103051  F2:7E:05:A5:6A:E5 400-2-0220-00004
# 4932    F2:7E:05:A5:6A:E5 400-2-0220-00004
# ...                                    ...
# 312819   C4:A3:0B:50:D2:59 4002-1124-00450
# 349427   C4:A3:0B:50:D2:59 4002-1124-00450
# 350035           f1:fb:63:1a:7e:8a PRH0008
# 335780   F0:6B:5A:DD:4A:44 4002-1124-00455
# 348395   F5:F2:15:3A:74:DE 4002-0920-00134
#
#                                 full_name.1 spare_type  \
# 447702               T0078 - Bruno WALLECAN      pants
# 195210               T0078 - Bruno WALLECAN      pants
# 40675                T0078 - Bruno WALLECAN      pants
# 103051               T0078 - Bruno WALLECAN      pants
# 4932                 T0078 - Bruno WALLECAN      pants
# ...                                     ...        ...
# 312819                 T1822 - Maud JARRIGE      pants
# 349427                 T1822 - Maud JARRIGE      pants
# 350035  T1823 - Siegrid BAUMEISTER-ABELANET      pants
# 335780                T1831 - Claire CASTRO      pants
# 348395                      T1835 - MYBRUSH      pants
#
#                         start_date  duration  real_duration  \
# 447702  2020-03-19 21:11:45.000000        30           1800
# 195210  2023-02-24 17:47:25.000000        45           2700
# 40675   2022-03-23 08:09:48.000000        30           1800
# 103051  2022-08-05 08:42:25.000000        30           1800
# 4932    2021-11-19 13:02:29.000000        20           1200
# ...                            ...       ...            ...
# 312819  2024-12-12 10:39:01.000000        45           2700
# 349427  2025-01-06 10:11:29.000000        20           1200
# 350035  2025-01-06 12:56:01.000000        20           1200
# 335780  2024-12-23 12:50:40.000000        30           1800
# 348395  2025-01-04 11:15:11.000000        30           1800
#
#         percentage_real_duration ps_server economic_model     full_name.2
# 447702                     100.0        EU      UNLIMITED  Jambes lourdes
# 195210                     100.0        EU      UNLIMITED       Chronique
# 40675                      100.0        EU      UNLIMITED       Chronique
# 103051                     100.0        EU      UNLIMITED       Chronique
# 4932                       100.0        EU      UNLIMITED       Entretien
# ...                          ...       ...            ...             ...
# 312819                     100.0        EU      UNLIMITED           Mixte
# 349427                     100.0        EU      UNLIMITED           Mixte
# 350035                     100.0        EU      UNLIMITED       Entretien
# 335780                     100.0        EU      UNLIMITED       Chronique
# 348395                     100.0        EU      UNLIMITED        Drainage
#
# [403877 rows x 10 columns]

# %%
sorted_activity_europe_50 = activity_europe_50.groupby('full_name.1').size().reset_index(name='counts')
sorted_activity_europe_50
# Out:
#                              full_name.1  counts
# 0                 T0078 - Bruno WALLECAN     906
# 1                   T0088 - André TORRES    1729
# 2                T0089 - Stefano BETTONI     709
# 3              T0091 - Selarl MEDVASC 32   11908
# 4           T0093 - POLE SANTÉ ALIMENTEC    4697
# ..                                   ...     ...
# 356                T1820 - Gemma GIMENEZ      25
# 357                 T1822 - Maud JARRIGE       7
# 358  T1823 - Siegrid BAUMEISTER-ABELANET       1
# 359                T1831 - Claire CASTRO       1
# 360                      T1835 - MYBRUSH       1
#
# [361 rows x 2 columns]

# %%
first_activity_dates = activity_europe_50.groupby('full_name.1')['start_date'].min().reset_index()
first_activity_dates.rename(columns={'start_date': 'first_activity'}, inplace=True)
sorted_activity_europe_50 = pd.merge(sorted_activity_europe_50, first_activity_dates, on='full_name.1', how='left')
sorted_activity_europe_50
# Out:
#                              full_name.1  counts              first_activity
# 0                 T0078 - Bruno WALLECAN     906  2020-02-07 14:51:51.000000
# 1                   T0088 - André TORRES    1729  2020-06-19 17:30:27.000000
# 2                T0089 - Stefano BETTONI     709  2020-02-25 15:14:20.000000
# 3              T0091 - Selarl MEDVASC 32   11908  2020-06-23 09:43:51.000000
# 4           T0093 - POLE SANTÉ ALIMENTEC    4697  2020-07-01 16:14:08.000000
# ..                                   ...     ...                         ...
# 356                T1820 - Gemma GIMENEZ      25  2024-12-20 10:05:32.000000
# 357                 T1822 - Maud JARRIGE       7  2024-12-12 10:39:01.000000
# 358  T1823 - Siegrid BAUMEISTER-ABELANET       1  2025-01-06 12:56:01.000000
# 359                T1831 - Claire CASTRO       1  2024-12-23 12:50:40.000000
# 360                      T1835 - MYBRUSH       1  2025-01-04 11:15:11.000000
#
# [361 rows x 3 columns]

# %%
last_activity_dates = activity_europe_50.groupby('full_name.1')['start_date'].max().reset_index()
last_activity_dates.rename(columns={'start_date': 'last_activity'}, inplace=True)
sorted_activity_europe_50 = pd.merge(sorted_activity_europe_50, last_activity_dates, on='full_name.1', how='left')
#sorted_activity_europe_50

# %%
import datetime

sorted_activity_europe_50['first_activity'] = pd.to_datetime(sorted_activity_europe_50['first_activity'])
sorted_activity_europe_50['last_activity'] = pd.to_datetime(sorted_activity_europe_50['last_activity'])
# changer le mode de calcul du nombre de jours. Ce n'est plus le nolbre de jours entre la première et la dernière activité mais le nombre de jours entre la première activité et la date du jour
# sorted_activity_europe_50['last_activity'] = pd.to_datetime(sorted_activity_europe_50['last_activity'])
sorted_activity_europe_50['number_days'] = 1 + (pd.to_datetime(datetime.date.today()) - sorted_activity_europe_50['first_activity']).dt.days
#sorted_activity_europe_50

# %%
# prompt: Add an extra column to sorted_activity_europe_50 called activity_last_7_days. The entries of the column activity_last_7_days should be equal to the counts of entries of full_name.1 between the current date and the curret date minus7 days

# Assuming 'start_date' column is already datetime objects. If not, convert it first:
# sorted_activity_europe_50['start_date'] = pd.to_datetime(sorted_activity_europe_50['start_date'])

import datetime

# Ensure 'start_date' in activity_europe_50 is datetime
activity_europe_50['start_date'] = pd.to_datetime(activity_europe_50['start_date'])

def count_activity_last_7_days(df, user):
    today = datetime.date.today()
    last_week = today - datetime.timedelta(days=7)
    user_activity = df[df['full_name.1'] == user]
    last_week_activity = user_activity[
        (user_activity['start_date'].dt.date >= last_week) &
        (user_activity['start_date'].dt.date <= today)
    ]
    return len(last_week_activity)


activity_last_7_days = []
for user in sorted_activity_europe_50['full_name.1']:
    activity_last_7_days.append(count_activity_last_7_days(activity_europe_50, user))

sorted_activity_europe_50['activity_last_7_days'] = activity_last_7_days
#sorted_activity_europe_50 = sorted_activity_europe_50.sort_values(by='activity_last_7_days', ascending=False)
#sorted_activity_europe_50

# %%
# prompt: Add an extra column to sorted_activity_europe_50 called activity_last_2_week. The entries of the column activity_last_2_week should be equal to the counts of entries of full_name.1 between the current date and the curret date minus 14 days

# Ensure 'start_date' in activity_europe_50 is datetime
activity_europe_50['start_date'] = pd.to_datetime(activity_europe_50['start_date'])

def count_activity_last_2_weeks(df, user):
    today = datetime.date.today()
    two_weeks_ago = today - datetime.timedelta(days=14)
    user_activity = df[df['full_name.1'] == user]
    last_2_weeks_activity = user_activity[
        (user_activity['start_date'].dt.date >= two_weeks_ago) &
        (user_activity['start_date'].dt.date <= today)
    ]
    return len(last_2_weeks_activity)

activity_last_2_week = []
for user in sorted_activity_europe_50['full_name.1']:
    activity_last_2_week.append(count_activity_last_2_weeks(activity_europe_50, user))

sorted_activity_europe_50['activity_last_14_days'] = activity_last_2_week
#sorted_activity_europe_50

# %%
# prompt: Add an extra column to sorted_activity_europe_50 called activity_last_30_days. The entries of the column activity_last_30_days should be equal to the counts of entries of full_name.1 between the current date and the curret date minus 31 days

def count_activity_last_30_days(df, user):
    today = datetime.date.today()
    month_ago = today - datetime.timedelta(days=30)
    user_activity = df[df['full_name.1'] == user]
    last_month_activity = user_activity[
        (user_activity['start_date'].dt.date >= month_ago) &
        (user_activity['start_date'].dt.date <= today)
    ]
    return len(last_month_activity)

activity_last_30_days = []
for user in sorted_activity_europe_50['full_name.1']:
    activity_last_30_days.append(count_activity_last_30_days(activity_europe_50, user))

sorted_activity_europe_50['activity_last_30_days'] = activity_last_30_days
#sorted_activity_europe_50

# %%
def count_activity_last_90_days(df, user):
    today = datetime.date.today()
    month_3_ago = today - datetime.timedelta(days=90)
    user_activity = df[df['full_name.1'] == user]
    last_3_month_activity = user_activity[
        (user_activity['start_date'].dt.date >= month_3_ago) &
        (user_activity['start_date'].dt.date <= today)
    ]
    return len(last_3_month_activity)

activity_last_90_days = []
for user in sorted_activity_europe_50['full_name.1']:
    activity_last_90_days.append(count_activity_last_90_days(activity_europe_50, user))

sorted_activity_europe_50['activity_last_90_days'] = activity_last_90_days
#sorted_activity_europe_50

# %%
def count_activity_last_365_days(df, user):
    today = datetime.date.today()
    year_ago = today - datetime.timedelta(days=365)
    user_activity = df[df['full_name.1'] == user]
    last_year_activity = user_activity[
        (user_activity['start_date'].dt.date >= year_ago) &
        (user_activity['start_date'].dt.date <= today)
    ]
    return len(last_year_activity)

activity_last_365_days = []
for user in sorted_activity_europe_50['full_name.1']:
    activity_last_365_days.append(count_activity_last_365_days(activity_europe_50, user))

sorted_activity_europe_50['activity_last_365_days'] = activity_last_365_days
#sorted_activity_europe_5

# %%
sorted_activity_europe_50['activity_per_day_since_acquisition'] = sorted_activity_europe_50['counts'] / sorted_activity_europe_50['number_days']
sorted_activity_europe_50['activity_per_day_7_days'] = sorted_activity_europe_50['activity_last_7_days'] / 5
sorted_activity_europe_50['activity_per_day_14_days'] = sorted_activity_europe_50['activity_last_14_days'] / 10
sorted_activity_europe_50['activity_per_day_30_days'] = sorted_activity_europe_50['activity_last_30_days'] / 20
sorted_activity_europe_50['activity_per_day_90_days'] = sorted_activity_europe_50['activity_last_90_days'] / 55
sorted_activity_europe_50['activity_per_day_year'] = sorted_activity_europe_50['activity_last_365_days'] / 220
#sorted_activity_europe_50
#round the result to 1 digit after the comma
sorted_activity_europe_50 = sorted_activity_europe_50.round({'activity_per_day_since_acquisition': 2, 'activity_per_day_7_days': 2, 'activity_per_day_14_days': 2, 'activity_per_day_30_days': 2, 'activity_per_day_90_days': 2, 'activity_per_day_year': 2})

# %%
#sorted_activity_europe_50 = sorted_activity_europe_50.sort_values(by=['activity_per_day_since_acquisition'], ascending=False)

#Test
sorted_activity_europe_50 = sorted_activity_europe_50.sort_values(by=['activity_last_365_days'], ascending=False)
#fin test


sorted_activity_europe_50
# Out:
#                      full_name.1  counts      first_activity  \
# 92       T0613 - Aqua Kiné Santé   21593 2021-05-31 08:37:59
# 8      T0100 - Franck ARCHIMBAUD   21681 2020-02-10 16:07:32
# 12           T0108 - UAB MEDA LT   12493 2021-05-19 09:56:33
# 116            T0711 - KINE FLOW    5805 2021-05-28 21:38:38
# 146           T0821 - PROKINETIC    9721 2021-11-04 12:23:33
# ..                           ...     ...                 ...
# 96        T0629 - Bouhanni Nacer       3 2021-02-19 17:41:48
# 108  T0671 - A.L.M Evreux Basket     252 2021-04-15 17:34:21
# 109       T0676 - Michel RIQUOIR      57 2022-03-21 11:08:58
# 112      T0690 - SCM KINÉ GRIGNY      59 2022-01-24 17:29:31
# 224    T1345 - S.A.S BODYESCENCE     363 2023-01-31 11:11:59
#
#           last_activity  number_days  activity_last_7_days  \
# 92  2025-01-06 14:29:11         1324                     0
# 8   2025-01-06 14:53:22         1800                     0
# 12  2025-01-06 14:56:06         1336                     0
# 116 2025-01-06 14:32:00         1327                     0
# 146 2025-01-06 14:08:15         1167                     0
# ..                  ...          ...                   ...
# 96  2021-06-04 14:14:54         1425                     0
# 108 2023-05-11 19:12:19         1370                     0
# 109 2022-04-28 09:31:45         1030                     0
# 112 2022-03-10 11:26:21         1086                     0
# 224 2023-11-04 18:16:06          714                     0
#
#      activity_last_14_days  activity_last_30_days  activity_last_90_days  \
# 92                      35                    155                    974
# 8                       22                    107                    552
# 12                      51                    186                    904
# 116                     23                     91                    562
# 146                     47                    175                    714
# ..                     ...                    ...                    ...
# 96                       0                      0                      0
# 108                      0                      0                      0
# 109                      0                      0                      0
# 112                      0                      0                      0
# 224                      0                      0                      0
#
#      activity_last_365_days  activity_per_day_since_acquisition  \
# 92                     5564                                16.3
# 8                      4026                                12.0
# 12                     3449                                 9.3
# 116                    2677                                 4.4
# 146                    2497                                 8.3
# ..                      ...                                 ...
# 96                        0                                 0.0
# 108                       0                                 0.2
# 109                       0                                 0.1
# 112                       0                                 0.1
# 224                       0                                 0.5
#
#      activity_per_day_7_days  activity_per_day_14_days  \
# 92                       0.0                       3.5
# 8                        0.0                       2.2
# 12                       0.0                       5.1
# 116                      0.0                       2.3
# 146                      0.0                       4.7
# ..                       ...                       ...
# 96                       0.0                       0.0
# 108                      0.0                       0.0
# 109                      0.0                       0.0
# 112                      0.0                       0.0
# 224                      0.0                       0.0
#
#      activity_per_day_30_days  activity_per_day_90_days  activity_per_day_year
# 92                        7.8                      17.7                   25.3
# 8                         5.3                      10.0                   18.3
# 12                        9.3                      16.4                   15.7
# 116                       4.5                      10.2                   12.2
# 146                       8.8                      13.0                   11.3
# ..                        ...                       ...                    ...
# 96                        0.0                       0.0                    0.0
# 108                       0.0                       0.0                    0.0
# 109                       0.0                       0.0                    0.0
# 112                       0.0                       0.0                    0.0
# 224                       0.0                       0.0                    0.0
#
# [361 rows x 16 columns]

# %%
sorted_activity_europe_50['rank_activity_7_days'] = sorted_activity_europe_50['activity_last_7_days'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_14_days'] = sorted_activity_europe_50['activity_last_14_days'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_30_days'] = sorted_activity_europe_50['activity_last_30_days'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_90_days'] = sorted_activity_europe_50['activity_last_90_days'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_year'] = sorted_activity_europe_50['activity_last_365_days'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_per_day_since_acquisition'] = sorted_activity_europe_50['activity_per_day_since_acquisition'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_per_day_7_days'] = sorted_activity_europe_50['activity_per_day_7_days'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_per_day_14_days'] = sorted_activity_europe_50['activity_per_day_14_days'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_per_day_30_days'] = sorted_activity_europe_50['activity_per_day_30_days'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_per_day_90_days'] = sorted_activity_europe_50['activity_per_day_90_days'].rank(ascending=False, method='min').astype(int)
sorted_activity_europe_50['rank_activity_per_day_year'] = sorted_activity_europe_50['activity_per_day_year'].rank(ascending=False, method='min').astype(int)

#sorted_activity_europe_50

# %%
sorted_activity_europe_50['percentage_total_activity_per_day'] = (sorted_activity_europe_50['activity_per_day_since_acquisition'] / sorted_activity_europe_50['activity_per_day_since_acquisition'].sum()) * 100
#sorted_activity_europe_50

# %%
sorted_activity_europe_50['cumulated_percentage_total_activity_per_day'] = sorted_activity_europe_50['percentage_total_activity_per_day'].cumsum()
#sorted_activity_europe_50

# %%
from datetime import datetime
import calendar

def format_timedelta(start_date, end_date):
  """
  Calculates the precise difference between two dates in years, months, and days.

  Args:
    start_date: The start date as a string (YYYY-MM-DD HH:MM:SS).
    end_date: The end date as a string (YYYY-MM-DD).

  Returns:
    A formatted string representing the time difference.
  """
  start_datetime = datetime.strptime(str(start_date), '%Y-%m-%d %H:%M:%S')
  end_datetime = datetime.strptime(str(end_date), '%Y-%m-%d')

  years = end_datetime.year - start_datetime.year
  months = end_datetime.month - start_datetime.month
  days = end_datetime.day - start_datetime.day

  # Adjust for negative differences
  if days < 0:
      months -= 1
      if end_datetime.month == 1:
          days += calendar.monthrange(end_datetime.year - 1, 12)[1]
      else:
          days += calendar.monthrange(end_datetime.year, end_datetime.month - 1)[1]
  if months < 0:
      years -= 1
      months += 12

  return f"{years} an(s), {months} mois, {days} jour(s)"

#add a column to sorted_activity_europe_50 called today, it should be equal to the current date
sorted_activity_europe_50['today'] = datetime.today().date()


# Example usage with your DataFrame:
sorted_activity_europe_50['formatted_duration'] = sorted_activity_europe_50.apply(
    lambda row: format_timedelta(row['first_activity'], row['today']), axis=1
)

# %% [markdown]
# # Liste des clients non rentables

# %% [markdown]
# # Sur 7 jours

# %%
# @title
# Display sorted_activity_europe_50 with activity_last_7_days < 1.25, showing only 'full_name.1' and 'activity_last_7_days'
display_unprofitable_clients_activity_per_days_7_days = sorted_activity_europe_50[sorted_activity_europe_50['activity_per_day_7_days'] < 1.25][['full_name.1', 'activity_per_day_7_days']].sort_values(by=['activity_per_day_7_days'], ascending=False)
display_unprofitable_clients_activity_per_days_7_days = display_unprofitable_clients_activity_per_days_7_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_7_days': 'Nombre moyen séance par jours sur les 7 derniers jours',
        })
print(f"{len(display_unprofitable_clients_activity_per_days_7_days)} clients sur "+ f"{len(sorted_activity_europe_50)}" + " ne sont pas rentables sur les 7 derniers jours")
display(display_unprofitable_clients_activity_per_days_7_days.style.format({"Nombre moyen séance par jours sur les 7 derniers jours": "{:.2f}"}).hide(axis='index'))
# Out:
# 361 clients sur 361 ne sont pas rentables sur les 7 derniers jours
# <style type="text/css">
# </style>
# <table id="T_35946">
#   <thead>
#     <tr>
#       <th id="T_35946_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_35946_level0_col1" class="col_heading level0 col1" >Nombre moyen séance par jours sur les 7 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_35946_row0_col0" class="data row0 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_35946_row0_col1" class="data row0 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row1_col0" class="data row1 col0" >T0631 - KANZLSPERGER GmbH</td>
#       <td id="T_35946_row1_col1" class="data row1 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row2_col0" class="data row2 col0" >T0762 - VOLANT SERVICES MANAGEMENT</td>
#       <td id="T_35946_row2_col1" class="data row2 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row3_col0" class="data row3 col0" >T1769 - LEDEN LASER</td>
#       <td id="T_35946_row3_col1" class="data row3 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row4_col0" class="data row4 col0" >T1817 - Laure GUIRAL</td>
#       <td id="T_35946_row4_col1" class="data row4 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row5_col0" class="data row5 col0" >T1620 - PENSULA SL</td>
#       <td id="T_35946_row5_col1" class="data row5 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row6_col0" class="data row6 col0" >T0806 - HOITOLA WOMAN</td>
#       <td id="T_35946_row6_col1" class="data row6 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row7_col0" class="data row7 col0" >T1764 - Marion JENNY-SAUVEBOIS</td>
#       <td id="T_35946_row7_col1" class="data row7 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row8_col0" class="data row8 col0" >T1390 - Zell Spa AG</td>
#       <td id="T_35946_row8_col1" class="data row8 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row9_col0" class="data row9 col0" >T0142 - Myriam LAVOINE (Kiné 62)</td>
#       <td id="T_35946_row9_col1" class="data row9 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row10_col0" class="data row10 col0" >T0530 - WYBO Frédéric</td>
#       <td id="T_35946_row10_col1" class="data row10 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row11_col0" class="data row11 col0" >T0971 - MTR – Health & Spa AG</td>
#       <td id="T_35946_row11_col1" class="data row11 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row12_col0" class="data row12 col0" >T0752 - DENTAL EQUIPEMENT</td>
#       <td id="T_35946_row12_col1" class="data row12 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row13_col0" class="data row13 col0" >T1766 - Noémie PETIT</td>
#       <td id="T_35946_row13_col1" class="data row13 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row14_col0" class="data row14 col0" >T1226 - SARL CALI IMAGE</td>
#       <td id="T_35946_row14_col1" class="data row14 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row15_col0" class="data row15 col0" >T1742 - Cryopôle Caissargues</td>
#       <td id="T_35946_row15_col1" class="data row15 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row16_col0" class="data row16 col0" >T1588 - ACTIF BIEN ETRE SAS</td>
#       <td id="T_35946_row16_col1" class="data row16 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row17_col0" class="data row17 col0" >T0610 - Marro Joséphine</td>
#       <td id="T_35946_row17_col1" class="data row17 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row18_col0" class="data row18 col0" >T1523 - Helicia CHERUBIN</td>
#       <td id="T_35946_row18_col1" class="data row18 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row19_col0" class="data row19 col0" >T1811 - Christelle GUITARD</td>
#       <td id="T_35946_row19_col1" class="data row19 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row20_col0" class="data row20 col0" >T1661 - Barbora Jarosaite</td>
#       <td id="T_35946_row20_col1" class="data row20 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row21_col0" class="data row21 col0" >T0663 - CryoBodyForme</td>
#       <td id="T_35946_row21_col1" class="data row21 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row22_col0" class="data row22 col0" >T0389 - ESPACE BEAUTE NATURELLE</td>
#       <td id="T_35946_row22_col1" class="data row22 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row23_col0" class="data row23 col0" >T1708 - Edith CARTIER</td>
#       <td id="T_35946_row23_col1" class="data row23 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row24_col0" class="data row24 col0" >T1290 - DOBELMANN Didier</td>
#       <td id="T_35946_row24_col1" class="data row24 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row25_col0" class="data row25 col0" >T0624 - Beauty S.O.S. Inc.</td>
#       <td id="T_35946_row25_col1" class="data row25 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row26_col0" class="data row26 col0" >T0425 - OCCHIMINUTI Jean-Claude</td>
#       <td id="T_35946_row26_col1" class="data row26 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row27_col0" class="data row27 col0" >T1740 - MRH ZERMATT SA</td>
#       <td id="T_35946_row27_col1" class="data row27 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row28_col0" class="data row28 col0" >T1380 - VIVAESTHETIC</td>
#       <td id="T_35946_row28_col1" class="data row28 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row29_col0" class="data row29 col0" >T1243 - Malang SANO</td>
#       <td id="T_35946_row29_col1" class="data row29 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row30_col0" class="data row30 col0" >T0365 - PHILIZOT Stephane</td>
#       <td id="T_35946_row30_col1" class="data row30 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row31_col0" class="data row31 col0" >T0995 - CRYO LIFE STYLE</td>
#       <td id="T_35946_row31_col1" class="data row31 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row32_col0" class="data row32 col0" >T1775 - Sophie GUIGUE PIQUET</td>
#       <td id="T_35946_row32_col1" class="data row32 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row33_col0" class="data row33 col0" >T1737 - KONCEPT SANTE</td>
#       <td id="T_35946_row33_col1" class="data row33 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row34_col0" class="data row34 col0" >T0642 - H-SPORT PERFORMANCE</td>
#       <td id="T_35946_row34_col1" class="data row34 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row35_col0" class="data row35 col0" >T1741 - Marie CONSTANTIN</td>
#       <td id="T_35946_row35_col1" class="data row35 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row36_col0" class="data row36 col0" >T1462 - Luxury Wellness</td>
#       <td id="T_35946_row36_col1" class="data row36 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row37_col0" class="data row37 col0" >T0997 - Gwladys LAMOTHE</td>
#       <td id="T_35946_row37_col1" class="data row37 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row38_col0" class="data row38 col0" >T1278 - NATURpraxis Luzern GmbH</td>
#       <td id="T_35946_row38_col1" class="data row38 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row39_col0" class="data row39 col0" >T1820 - Gemma GIMENEZ</td>
#       <td id="T_35946_row39_col1" class="data row39 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row40_col0" class="data row40 col0" >T1551 - THE BODY BY CHRIS</td>
#       <td id="T_35946_row40_col1" class="data row40 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row41_col0" class="data row41 col0" >T1808 - Caroline NIMAL</td>
#       <td id="T_35946_row41_col1" class="data row41 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row42_col0" class="data row42 col0" >T1733 - NZONZI Steven</td>
#       <td id="T_35946_row42_col1" class="data row42 col1" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_35946_row43_col0" class="data row43 col0" >T1814 - Isabelle NORET</td>

# %% [markdown]
# # Sur  14 jours

# %%
# @title
display_unprofitable_clients_activity_per_days_14_days = sorted_activity_europe_50[sorted_activity_europe_50['activity_per_day_14_days'] < 1.25][['full_name.1', 'activity_per_day_14_days']].sort_values(by=['activity_per_day_14_days'], ascending=False)
display_unprofitable_clients_activity_per_days_14_days = display_unprofitable_clients_activity_per_days_14_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_14_days': 'Nombre moyen séance par jours sur les 14 derniers jours',
        })
print(f"{len(display_unprofitable_clients_activity_per_days_14_days)} clients sur "+ f"{len(sorted_activity_europe_50)}" + " ne sont pas rentables sur les 14 derniers jours")
display(display_unprofitable_clients_activity_per_days_14_days.style.format({"Nombre moyen séance par jours sur les 14 derniers jours": "{:.2f}"}).hide(axis='index'))
# Out:
# 337 clients sur 361 ne sont pas rentables sur les 14 derniers jours
# <style type="text/css">
# </style>
# <table id="T_ee978">
#   <thead>
#     <tr>
#       <th id="T_ee978_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_ee978_level0_col1" class="col_heading level0 col1" >Nombre moyen séance par jours sur les 14 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ee978_row0_col0" class="data row0 col0" >T1757 - Cédric FORMET</td>
#       <td id="T_ee978_row0_col1" class="data row0 col1" >1.20</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row1_col0" class="data row1 col0" >T0820 - Nicolas BOCACCIO</td>
#       <td id="T_ee978_row1_col1" class="data row1 col1" >1.20</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row2_col0" class="data row2 col0" >T1754 - Christelle DUQUESNE</td>
#       <td id="T_ee978_row2_col1" class="data row2 col1" >1.20</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row3_col0" class="data row3 col0" >T1664 - ARK Cabinet de Kiné</td>
#       <td id="T_ee978_row3_col1" class="data row3 col1" >1.20</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row4_col0" class="data row4 col0" >T0385 - BATAILLE Maxime</td>
#       <td id="T_ee978_row4_col1" class="data row4 col1" >1.10</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row5_col0" class="data row5 col0" >T1697 - Stéphanie SANCHEZ</td>
#       <td id="T_ee978_row5_col1" class="data row5 col1" >1.10</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row6_col0" class="data row6 col0" >T1637 - JEANNIN Cindy / Pauline CLAVEL</td>
#       <td id="T_ee978_row6_col1" class="data row6 col1" >1.10</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row7_col0" class="data row7 col0" >T0102 - Fabrice ALEMANNO</td>
#       <td id="T_ee978_row7_col1" class="data row7 col1" >1.10</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row8_col0" class="data row8 col0" >T0646 - Stéphanie BERTHON</td>
#       <td id="T_ee978_row8_col1" class="data row8 col1" >1.10</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row9_col0" class="data row9 col0" >T1776 - Fanny LE GAL</td>
#       <td id="T_ee978_row9_col1" class="data row9 col1" >1.10</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row10_col0" class="data row10 col0" >T0999 - Jérôme DUCHATELET</td>
#       <td id="T_ee978_row10_col1" class="data row10 col1" >1.00</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row11_col0" class="data row11 col0" >T0937 - SCM KINEMOTIV</td>
#       <td id="T_ee978_row11_col1" class="data row11 col1" >1.00</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row12_col0" class="data row12 col0" >T1408 - Mandy ROURRET</td>
#       <td id="T_ee978_row12_col1" class="data row12 col1" >0.90</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row13_col0" class="data row13 col0" >T0830 - Eve CAVALIE</td>
#       <td id="T_ee978_row13_col1" class="data row13 col1" >0.90</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row14_col0" class="data row14 col0" >T0733 - Céline RAMAGE</td>
#       <td id="T_ee978_row14_col1" class="data row14 col1" >0.90</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row15_col0" class="data row15 col0" >T1781 - AUSRA SPA</td>
#       <td id="T_ee978_row15_col1" class="data row15 col1" >0.90</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row16_col0" class="data row16 col0" >T0839 - L'ASTRAGALE SELAS</td>
#       <td id="T_ee978_row16_col1" class="data row16 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row17_col0" class="data row17 col0" >T0355 - ADMIN Admin</td>
#       <td id="T_ee978_row17_col1" class="data row17 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row18_col0" class="data row18 col0" >T1765 - Ghislaine MOHA</td>
#       <td id="T_ee978_row18_col1" class="data row18 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row19_col0" class="data row19 col0" >T0091 - Selarl MEDVASC 32</td>
#       <td id="T_ee978_row19_col1" class="data row19 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row20_col0" class="data row20 col0" >T0978 - SCM Challenge Rééduc</td>
#       <td id="T_ee978_row20_col1" class="data row20 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row21_col0" class="data row21 col0" >T1817 - Laure GUIRAL</td>
#       <td id="T_ee978_row21_col1" class="data row21 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row22_col0" class="data row22 col0" >T1550 - Frédérique FITOUSSI</td>
#       <td id="T_ee978_row22_col1" class="data row22 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row23_col0" class="data row23 col0" >T1727 - SELLINGSUCCESS S.L.</td>
#       <td id="T_ee978_row23_col1" class="data row23 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row24_col0" class="data row24 col0" >T1510 - CRYOPOLE MONTPELLIER</td>
#       <td id="T_ee978_row24_col1" class="data row24 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row25_col0" class="data row25 col0" >T1745 - SACLAY CARE CENTRE</td>
#       <td id="T_ee978_row25_col1" class="data row25 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row26_col0" class="data row26 col0" >T1686 - SCM RHEA THERAPIE</td>
#       <td id="T_ee978_row26_col1" class="data row26 col1" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row27_col0" class="data row27 col0" >T1507 - AXE KINE</td>
#       <td id="T_ee978_row27_col1" class="data row27 col1" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row28_col0" class="data row28 col0" >T0649 - Marie-Caroline CHARBONNIER MONTAUDIE</td>
#       <td id="T_ee978_row28_col1" class="data row28 col1" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row29_col0" class="data row29 col0" >T0898 - Arnaud BARD</td>
#       <td id="T_ee978_row29_col1" class="data row29 col1" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row30_col0" class="data row30 col0" >T0109 - Olivier BORTOLASO</td>
#       <td id="T_ee978_row30_col1" class="data row30 col1" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row31_col0" class="data row31 col0" >T1557 - Delphine DOMERC</td>
#       <td id="T_ee978_row31_col1" class="data row31 col1" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row32_col0" class="data row32 col0" >T1488 - SCM KINES SANTE FORME</td>
#       <td id="T_ee978_row32_col1" class="data row32 col1" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row33_col0" class="data row33 col0" >T0360 - Frédéric GUELTON</td>
#       <td id="T_ee978_row33_col1" class="data row33 col1" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row34_col0" class="data row34 col0" >T1811 - Christelle GUITARD</td>
#       <td id="T_ee978_row34_col1" class="data row34 col1" >0.60</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row35_col0" class="data row35 col0" >T1758 - SCM ReeduKA Moulin</td>
#       <td id="T_ee978_row35_col1" class="data row35 col1" >0.60</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row36_col0" class="data row36 col0" >T1698 - CRYOCARE</td>
#       <td id="T_ee978_row36_col1" class="data row36 col1" >0.60</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row37_col0" class="data row37 col0" >T1530 - Florian ONNO</td>
#       <td id="T_ee978_row37_col1" class="data row37 col1" >0.60</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row38_col0" class="data row38 col0" >T1779 - Anne Sophie MABILLE</td>
#       <td id="T_ee978_row38_col1" class="data row38 col1" >0.60</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row39_col0" class="data row39 col0" >T0745 - Thibaut LEONE</td>
#       <td id="T_ee978_row39_col1" class="data row39 col1" >0.60</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row40_col0" class="data row40 col0" >T0785 - Perrine SAVOURAT</td>
#       <td id="T_ee978_row40_col1" class="data row40 col1" >0.60</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row41_col0" class="data row41 col0" >T1421 - Sandra BONDON</td>
#       <td id="T_ee978_row41_col1" class="data row41 col1" >0.60</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row42_col0" class="data row42 col0" >T1616 - Julie LAQUEUE (ép. GUILLIN)</td>
#       <td id="T_ee978_row42_col1" class="data row42 col1" >0.50</td>
#     </tr>
#     <tr>
#       <td id="T_ee978_row43_col0" class="data row43 col0" >T0973 - GULF STREAM</td>

# %% [markdown]
# # Sur 30 jours

# %%
# @title
display_unprofitable_clients_activity_per_days_30_days = sorted_activity_europe_50[(sorted_activity_europe_50['activity_per_day_30_days'] < 1.25) & (sorted_activity_europe_50['number_days'] > 30)][['full_name.1', 'activity_per_day_30_days']].sort_values(by=['activity_per_day_30_days'], ascending=False)
display_unprofitable_clients_activity_per_days_30_days = display_unprofitable_clients_activity_per_days_30_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_30_days': 'Nombre moyen séance par jours sur les 30 derniers jours',
        })
print(f"{len(display_unprofitable_clients_activity_per_days_30_days)} clients sur "+ f"{len(sorted_activity_europe_50[sorted_activity_europe_50['number_days']>30])}" + " ne sont pas rentables sur les 30 derniers jours")
display(display_unprofitable_clients_activity_per_days_30_days.style.format({"Nombre moyen séance par jours sur les 30 derniers jours": "{:.2f}"}).hide(axis='index'))
# Out:
# 273 clients sur 356 ne sont pas rentables sur les 30 derniers jours
# <style type="text/css">
# </style>
# <table id="T_d0e99">
#   <thead>
#     <tr>
#       <th id="T_d0e99_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_d0e99_level0_col1" class="col_heading level0 col1" >Nombre moyen séance par jours sur les 30 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d0e99_row0_col0" class="data row0 col0" >T0368 - RADENNE Denis</td>
#       <td id="T_d0e99_row0_col1" class="data row0 col1" >1.20</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row1_col0" class="data row1 col0" >T1779 - Anne Sophie MABILLE</td>
#       <td id="T_d0e99_row1_col1" class="data row1 col1" >1.20</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row2_col0" class="data row2 col0" >T1749 - Elise PEREZ</td>
#       <td id="T_d0e99_row2_col1" class="data row2 col1" >1.20</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row3_col0" class="data row3 col0" >T1613 - Gloria GARCIA</td>
#       <td id="T_d0e99_row3_col1" class="data row3 col1" >1.20</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row4_col0" class="data row4 col0" >T1758 - SCM ReeduKA Moulin</td>
#       <td id="T_d0e99_row4_col1" class="data row4 col1" >1.15</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row5_col0" class="data row5 col0" >T1014 - SCM FLAUGERGUES</td>
#       <td id="T_d0e99_row5_col1" class="data row5 col1" >1.10</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row6_col0" class="data row6 col0" >T1595 - Anne-Sophie MARCHAND</td>
#       <td id="T_d0e99_row6_col1" class="data row6 col1" >1.10</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row7_col0" class="data row7 col0" >T0839 - L'ASTRAGALE SELAS</td>
#       <td id="T_d0e99_row7_col1" class="data row7 col1" >1.10</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row8_col0" class="data row8 col0" >T0525 - FISIOLAB 8.14 S.R.L.</td>
#       <td id="T_d0e99_row8_col1" class="data row8 col1" >1.10</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row9_col0" class="data row9 col0" >T1329 - Brahem MESSAOUI</td>
#       <td id="T_d0e99_row9_col1" class="data row9 col1" >1.10</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row10_col0" class="data row10 col0" >T0107 - Delphine FOUASSE</td>
#       <td id="T_d0e99_row10_col1" class="data row10 col1" >1.05</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row11_col0" class="data row11 col0" >T1463 - Tine VANDEPUT</td>
#       <td id="T_d0e99_row11_col1" class="data row11 col1" >1.05</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row12_col0" class="data row12 col0" >T1535 - Jonathan BESLAY</td>
#       <td id="T_d0e99_row12_col1" class="data row12 col1" >0.95</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row13_col0" class="data row13 col0" >T1510 - CRYOPOLE MONTPELLIER</td>
#       <td id="T_d0e99_row13_col1" class="data row13 col1" >0.95</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row14_col0" class="data row14 col0" >T1757 - Cédric FORMET</td>
#       <td id="T_d0e99_row14_col1" class="data row14 col1" >0.95</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row15_col0" class="data row15 col0" >T1729 - Marie-Eline LABORDE</td>
#       <td id="T_d0e99_row15_col1" class="data row15 col1" >0.95</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row16_col0" class="data row16 col0" >T1410 - MAGIKTRADE</td>
#       <td id="T_d0e99_row16_col1" class="data row16 col1" >0.95</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row17_col0" class="data row17 col0" >T1745 - SACLAY CARE CENTRE</td>
#       <td id="T_d0e99_row17_col1" class="data row17 col1" >0.95</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row18_col0" class="data row18 col0" >T0396 - SEBBAGH Aurélien</td>
#       <td id="T_d0e99_row18_col1" class="data row18 col1" >0.95</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row19_col0" class="data row19 col0" >T0407 - GENTIL JEAN MARC</td>
#       <td id="T_d0e99_row19_col1" class="data row19 col1" >0.90</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row20_col0" class="data row20 col0" >T0370 - Laurie FONTAINE</td>
#       <td id="T_d0e99_row20_col1" class="data row20 col1" >0.90</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row21_col0" class="data row21 col0" >T1551 - THE BODY BY CHRIS</td>
#       <td id="T_d0e99_row21_col1" class="data row21 col1" >0.90</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row22_col0" class="data row22 col0" >T0418 - CABINET ESCORIZA MARTINCIC</td>
#       <td id="T_d0e99_row22_col1" class="data row22 col1" >0.90</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row23_col0" class="data row23 col0" >T1709 - Christelle TORCHEN</td>
#       <td id="T_d0e99_row23_col1" class="data row23 col1" >0.90</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row24_col0" class="data row24 col0" >T1589 - Claire DAUCHY</td>
#       <td id="T_d0e99_row24_col1" class="data row24 col1" >0.85</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row25_col0" class="data row25 col0" >T0636 - Delphine PETRINI</td>
#       <td id="T_d0e99_row25_col1" class="data row25 col1" >0.85</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row26_col0" class="data row26 col0" >T0976 - CRYO MAUGUIO (CRYOPOLE)</td>
#       <td id="T_d0e99_row26_col1" class="data row26 col1" >0.85</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row27_col0" class="data row27 col0" >T1246 - Steeve HAUSWALD</td>
#       <td id="T_d0e99_row27_col1" class="data row27 col1" >0.85</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row28_col0" class="data row28 col0" >T1704 - Ozon 2000 (SRL)</td>
#       <td id="T_d0e99_row28_col1" class="data row28 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row29_col0" class="data row29 col0" >T0404 - ODENTHAL Dominique</td>
#       <td id="T_d0e99_row29_col1" class="data row29 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row30_col0" class="data row30 col0" >T1431 - Cindy STANDAERT</td>
#       <td id="T_d0e99_row30_col1" class="data row30 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row31_col0" class="data row31 col0" >T1478 - Sibylle ROBERT</td>
#       <td id="T_d0e99_row31_col1" class="data row31 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row32_col0" class="data row32 col0" >T0583 - Di  Matteo Nicolas</td>
#       <td id="T_d0e99_row32_col1" class="data row32 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row33_col0" class="data row33 col0" >T0979 - Paul FAURIS</td>
#       <td id="T_d0e99_row33_col1" class="data row33 col1" >0.75</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row34_col0" class="data row34 col0" >T1321 - Stéphane CORNILLE</td>
#       <td id="T_d0e99_row34_col1" class="data row34 col1" >0.75</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row35_col0" class="data row35 col0" >T1764 - Marion JENNY-SAUVEBOIS</td>
#       <td id="T_d0e99_row35_col1" class="data row35 col1" >0.75</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row36_col0" class="data row36 col0" >T1655 - Dorian DOSSARPS</td>
#       <td id="T_d0e99_row36_col1" class="data row36 col1" >0.75</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row37_col0" class="data row37 col0" >T1415 - Adeline JOUIN</td>
#       <td id="T_d0e99_row37_col1" class="data row37 col1" >0.75</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row38_col0" class="data row38 col0" >T1311 - Audrey DELEFORTRIE</td>
#       <td id="T_d0e99_row38_col1" class="data row38 col1" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row39_col0" class="data row39 col0" >T1713 - Franck DUBOIS</td>
#       <td id="T_d0e99_row39_col1" class="data row39 col1" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row40_col0" class="data row40 col0" >T0414 - AMBERTON Icaros</td>
#       <td id="T_d0e99_row40_col1" class="data row40 col1" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row41_col0" class="data row41 col0" >T0903 - Dr Mathilde GUILLOT</td>
#       <td id="T_d0e99_row41_col1" class="data row41 col1" >0.65</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row42_col0" class="data row42 col0" >T1530 - Florian ONNO</td>
#       <td id="T_d0e99_row42_col1" class="data row42 col1" >0.65</td>
#     </tr>
#     <tr>
#       <td id="T_d0e99_row43_col0" class="data row43 col0" >T1575 - KATIA VIGNAL</td>
#       <t

# %% [markdown]
# # Sur 90 jours

# %%
# @title
display_unprofitable_clients_activity_per_days_90_days = sorted_activity_europe_50[(sorted_activity_europe_50['activity_per_day_90_days'] < 1.25) & (sorted_activity_europe_50['number_days'] > 90)][['full_name.1', 'activity_per_day_90_days']].sort_values(by=['activity_per_day_90_days'], ascending=False)
display_unprofitable_clients_activity_per_days_90_days = display_unprofitable_clients_activity_per_days_90_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_90_days': 'Nombre moyen séance par jours sur les 90 derniers jours',
        })
print(f"{len(display_unprofitable_clients_activity_per_days_90_days)} clients sur "+ f"{len(sorted_activity_europe_50[sorted_activity_europe_50['number_days']>90])}" + " ne sont pas rentables sur les 90 derniers jours")
display(display_unprofitable_clients_activity_per_days_90_days.style.format({"Nombre moyen séance par jours sur les 90 derniers jours": "{:.2f}"}).hide(axis='index'))
# Out:
# 200 clients sur 339 ne sont pas rentables sur les 90 derniers jours
# <style type="text/css">
# </style>
# <table id="T_79d66">
#   <thead>
#     <tr>
#       <th id="T_79d66_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_79d66_level0_col1" class="col_heading level0 col1" >Nombre moyen séance par jours sur les 90 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_79d66_row0_col0" class="data row0 col0" >T0094 - Sébastien PELLÉ</td>
#       <td id="T_79d66_row0_col1" class="data row0 col1" >1.24</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row1_col0" class="data row1 col0" >T0970 - Julien JOURDAIN</td>
#       <td id="T_79d66_row1_col1" class="data row1 col1" >1.24</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row2_col0" class="data row2 col0" >T0903 - Dr Mathilde GUILLOT</td>
#       <td id="T_79d66_row2_col1" class="data row2 col1" >1.24</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row3_col0" class="data row3 col0" >T1714 - Francois BRUGIDOU</td>
#       <td id="T_79d66_row3_col1" class="data row3 col1" >1.13</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row4_col0" class="data row4 col0" >T1336 - Julien PION et Anaïs PARIS</td>
#       <td id="T_79d66_row4_col1" class="data row4 col1" >1.11</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row5_col0" class="data row5 col0" >T1708 - Edith CARTIER</td>
#       <td id="T_79d66_row5_col1" class="data row5 col1" >1.09</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row6_col0" class="data row6 col0" >T0781 - SPRL MERCURE</td>
#       <td id="T_79d66_row6_col1" class="data row6 col1" >1.09</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row7_col0" class="data row7 col0" >T0701 - Romain BOTTOIS</td>
#       <td id="T_79d66_row7_col1" class="data row7 col1" >1.07</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row8_col0" class="data row8 col0" >T1657 - Christophe HELIN</td>
#       <td id="T_79d66_row8_col1" class="data row8 col1" >1.07</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row9_col0" class="data row9 col0" >T1450 - Centre Médical Pasteur</td>
#       <td id="T_79d66_row9_col1" class="data row9 col1" >1.05</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row10_col0" class="data row10 col0" >T1530 - Florian ONNO</td>
#       <td id="T_79d66_row10_col1" class="data row10 col1" >1.04</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row11_col0" class="data row11 col0" >T1545 - SELAS EKEUH</td>
#       <td id="T_79d66_row11_col1" class="data row11 col1" >1.00</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row12_col0" class="data row12 col0" >T0668 - Dreissigacker Katrin</td>
#       <td id="T_79d66_row12_col1" class="data row12 col1" >1.00</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row13_col0" class="data row13 col0" >T0976 - CRYO MAUGUIO (CRYOPOLE)</td>
#       <td id="T_79d66_row13_col1" class="data row13 col1" >1.00</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row14_col0" class="data row14 col0" >T1424 - ESTHETIQUE PORDIC</td>
#       <td id="T_79d66_row14_col1" class="data row14 col1" >0.93</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row15_col0" class="data row15 col0" >T1542 - Hermes Fisiofarma sagl</td>
#       <td id="T_79d66_row15_col1" class="data row15 col1" >0.91</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row16_col0" class="data row16 col0" >T0401 - Sébastien HALLER</td>
#       <td id="T_79d66_row16_col1" class="data row16 col1" >0.91</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row17_col0" class="data row17 col0" >T1757 - Cédric FORMET</td>
#       <td id="T_79d66_row17_col1" class="data row17 col1" >0.89</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row18_col0" class="data row18 col0" >T1356 - Cellu 06</td>
#       <td id="T_79d66_row18_col1" class="data row18 col1" >0.89</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row19_col0" class="data row19 col0" >T0404 - ODENTHAL Dominique</td>
#       <td id="T_79d66_row19_col1" class="data row19 col1" >0.89</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row20_col0" class="data row20 col0" >T0819 - Bérengère BAS</td>
#       <td id="T_79d66_row20_col1" class="data row20 col1" >0.87</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row21_col0" class="data row21 col0" >T0818 - Vicky MONTEIRO</td>
#       <td id="T_79d66_row21_col1" class="data row21 col1" >0.85</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row22_col0" class="data row22 col0" >T0583 - Di  Matteo Nicolas</td>
#       <td id="T_79d66_row22_col1" class="data row22 col1" >0.84</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row23_col0" class="data row23 col0" >T0423 - Julien ALDEGUER</td>
#       <td id="T_79d66_row23_col1" class="data row23 col1" >0.82</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row24_col0" class="data row24 col0" >T1766 - Noémie PETIT</td>
#       <td id="T_79d66_row24_col1" class="data row24 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row25_col0" class="data row25 col0" >T0842 - BLC SYSTEM</td>
#       <td id="T_79d66_row25_col1" class="data row25 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row26_col0" class="data row26 col0" >T1587 - Christelle DAL-ZOTTO</td>
#       <td id="T_79d66_row26_col1" class="data row26 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row27_col0" class="data row27 col0" >T1532 - Noémie TARDY</td>
#       <td id="T_79d66_row27_col1" class="data row27 col1" >0.76</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row28_col0" class="data row28 col0" >T0393 - CRYOSUD SARL</td>
#       <td id="T_79d66_row28_col1" class="data row28 col1" >0.76</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row29_col0" class="data row29 col0" >T1486 - BAYVIEW ESTATE LTD.</td>
#       <td id="T_79d66_row29_col1" class="data row29 col1" >0.75</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row30_col0" class="data row30 col0" >T1426 - BEAUTY CONCEPT</td>
#       <td id="T_79d66_row30_col1" class="data row30 col1" >0.75</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row31_col0" class="data row31 col0" >T0780 - Esther ELUERE</td>
#       <td id="T_79d66_row31_col1" class="data row31 col1" >0.73</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row32_col0" class="data row32 col0" >T1213 - Scheller Claudia</td>
#       <td id="T_79d66_row32_col1" class="data row32 col1" >0.65</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row33_col0" class="data row33 col0" >T1588 - ACTIF BIEN ETRE SAS</td>
#       <td id="T_79d66_row33_col1" class="data row33 col1" >0.64</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row34_col0" class="data row34 col0" >T0969 - ANATOMIK</td>
#       <td id="T_79d66_row34_col1" class="data row34 col1" >0.64</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row35_col0" class="data row35 col0" >T0375 - KINZ Joerg</td>
#       <td id="T_79d66_row35_col1" class="data row35 col1" >0.56</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row36_col0" class="data row36 col0" >T0409 - LES JARDINS D'HEBE</td>
#       <td id="T_79d66_row36_col1" class="data row36 col1" >0.56</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row37_col0" class="data row37 col0" >T1237 - CS PHYSIO</td>
#       <td id="T_79d66_row37_col1" class="data row37 col1" >0.56</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row38_col0" class="data row38 col0" >T1742 - Cryopôle Caissargues</td>
#       <td id="T_79d66_row38_col1" class="data row38 col1" >0.56</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row39_col0" class="data row39 col0" >T1623 - michalik marta</td>
#       <td id="T_79d66_row39_col1" class="data row39 col1" >0.55</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row40_col0" class="data row40 col0" >T1006 - Arnold health AG</td>
#       <td id="T_79d66_row40_col1" class="data row40 col1" >0.55</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row41_col0" class="data row41 col0" >T1653 - Cryopôle Saint-Affrique</td>
#       <td id="T_79d66_row41_col1" class="data row41 col1" >0.53</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row42_col0" class="data row42 col0" >T0384 - PHYSIO RECUP</td>
#       <td id="T_79d66_row42_col1" class="data row42 col1" >0.51</td>
#     </tr>
#     <tr>
#       <td id="T_79d66_row43_col0" class="data row43 col0" >T0630 - Nicolas PETITBOIS (AQUAPHYSIOSPORT)</td>
#       <td id="

# %% [markdown]
# # Sur 1 an

# %%
# @title
display_unprofitable_clients_activity_per_days_year = sorted_activity_europe_50[(sorted_activity_europe_50['activity_per_day_year'] < 1.25) & (sorted_activity_europe_50['number_days'] > 365)][['full_name.1', 'activity_per_day_year']].sort_values(by=['activity_per_day_year'], ascending=False)
display_unprofitable_clients_activity_per_days_year = display_unprofitable_clients_activity_per_days_year.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_year': 'Nombre moyen séance par jours sur 1 an',
        })
print(f"{len(display_unprofitable_clients_activity_per_days_year)} clients sur "+ f"{len(sorted_activity_europe_50[sorted_activity_europe_50['number_days']>365])}" + " ne sont pas rentables sur 1 an")
display(display_unprofitable_clients_activity_per_days_year.style.format({"Nombre moyen séance par jours sur 1 an": "{:.2f}"}).hide(axis='index'))
# Out:
# 151 clients sur 275 ne sont pas rentables sur 1 an
# <style type="text/css">
# </style>
# <table id="T_b4f20">
#   <thead>
#     <tr>
#       <th id="T_b4f20_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_b4f20_level0_col1" class="col_heading level0 col1" >Nombre moyen séance par jours sur 1 an</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b4f20_row0_col0" class="data row0 col0" >T0597 - SELAS CCECB</td>
#       <td id="T_b4f20_row0_col1" class="data row0 col1" >1.22</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row1_col0" class="data row1 col0" >T0976 - CRYO MAUGUIO (CRYOPOLE)</td>
#       <td id="T_b4f20_row1_col1" class="data row1 col1" >1.16</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row2_col0" class="data row2 col0" >T1476 - Loïc LAFON</td>
#       <td id="T_b4f20_row2_col1" class="data row2 col1" >1.14</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row3_col0" class="data row3 col0" >T0404 - ODENTHAL Dominique</td>
#       <td id="T_b4f20_row3_col1" class="data row3 col1" >1.14</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row4_col0" class="data row4 col0" >T0788 - Jéromine PASO</td>
#       <td id="T_b4f20_row4_col1" class="data row4 col1" >1.10</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row5_col0" class="data row5 col0" >T0819 - Bérengère BAS</td>
#       <td id="T_b4f20_row5_col1" class="data row5 col1" >1.07</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row6_col0" class="data row6 col0" >T1450 - Centre Médical Pasteur</td>
#       <td id="T_b4f20_row6_col1" class="data row6 col1" >1.05</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row7_col0" class="data row7 col0" >T1280 - MAGUS APOTHICAIRE DE BEAUTE</td>
#       <td id="T_b4f20_row7_col1" class="data row7 col1" >1.02</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row8_col0" class="data row8 col0" >T1208 - Priscilla BERTHOME</td>
#       <td id="T_b4f20_row8_col1" class="data row8 col1" >0.99</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row9_col0" class="data row9 col0" >T1563 - BeautySpace</td>
#       <td id="T_b4f20_row9_col1" class="data row9 col1" >0.92</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row10_col0" class="data row10 col0" >T0736 - CENTRE ESTHETIQUE DESTINEE</td>
#       <td id="T_b4f20_row10_col1" class="data row10 col1" >0.87</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row11_col0" class="data row11 col0" >T0818 - Vicky MONTEIRO</td>
#       <td id="T_b4f20_row11_col1" class="data row11 col1" >0.86</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row12_col0" class="data row12 col0" >T1572 - Sébastien BRAME</td>
#       <td id="T_b4f20_row12_col1" class="data row12 col1" >0.86</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row13_col0" class="data row13 col0" >T0766 - Blandine AYMARD LARTIGUE</td>
#       <td id="T_b4f20_row13_col1" class="data row13 col1" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row14_col0" class="data row14 col0" >T0409 - LES JARDINS D'HEBE</td>
#       <td id="T_b4f20_row14_col1" class="data row14 col1" >0.79</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row15_col0" class="data row15 col0" >T0401 - Sébastien HALLER</td>
#       <td id="T_b4f20_row15_col1" class="data row15 col1" >0.77</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row16_col0" class="data row16 col0" >T0583 - Di  Matteo Nicolas</td>
#       <td id="T_b4f20_row16_col1" class="data row16 col1" >0.74</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row17_col0" class="data row17 col0" >T1301 - ESTHETIQUEMENT VOTRE</td>
#       <td id="T_b4f20_row17_col1" class="data row17 col1" >0.73</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row18_col0" class="data row18 col0" >T1525 - Tom CAHN</td>
#       <td id="T_b4f20_row18_col1" class="data row18 col1" >0.71</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row19_col0" class="data row19 col0" >T1587 - Christelle DAL-ZOTTO</td>
#       <td id="T_b4f20_row19_col1" class="data row19 col1" >0.71</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row20_col0" class="data row20 col0" >T0822 - Madreperla Skincare / Giomat GmbH</td>
#       <td id="T_b4f20_row20_col1" class="data row20 col1" >0.68</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row21_col0" class="data row21 col0" >T1423 - Rachel LABBE</td>
#       <td id="T_b4f20_row21_col1" class="data row21 col1" >0.66</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row22_col0" class="data row22 col0" >T1213 - Scheller Claudia</td>
#       <td id="T_b4f20_row22_col1" class="data row22 col1" >0.66</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row23_col0" class="data row23 col0" >T1006 - Arnold health AG</td>
#       <td id="T_b4f20_row23_col1" class="data row23 col1" >0.65</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row24_col0" class="data row24 col0" >T0845 - Anne-Laure ULLIAC</td>
#       <td id="T_b4f20_row24_col1" class="data row24 col1" >0.61</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row25_col0" class="data row25 col0" >T0383 - ARGOUD Béatrice</td>
#       <td id="T_b4f20_row25_col1" class="data row25 col1" >0.59</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row26_col0" class="data row26 col0" >T1265 - Catherine GOTTERO</td>
#       <td id="T_b4f20_row26_col1" class="data row26 col1" >0.49</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row27_col0" class="data row27 col0" >T1326 - Ines CUBILLOS</td>
#       <td id="T_b4f20_row27_col1" class="data row27 col1" >0.48</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row28_col0" class="data row28 col0" >T0405 - WATTEAU Clémentine</td>
#       <td id="T_b4f20_row28_col1" class="data row28 col1" >0.46</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row29_col0" class="data row29 col0" >T1578 - NEURO RECUP</td>
#       <td id="T_b4f20_row29_col1" class="data row29 col1" >0.45</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row30_col0" class="data row30 col0" >T0384 - PHYSIO RECUP</td>
#       <td id="T_b4f20_row30_col1" class="data row30 col1" >0.45</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row31_col0" class="data row31 col0" >T0423 - Julien ALDEGUER</td>
#       <td id="T_b4f20_row31_col1" class="data row31 col1" >0.41</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row32_col0" class="data row32 col0" >T1212 - Herz Monica</td>
#       <td id="T_b4f20_row32_col1" class="data row32 col1" >0.40</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row33_col0" class="data row33 col0" >T0410 - SCHWARZER Myriam</td>
#       <td id="T_b4f20_row33_col1" class="data row33 col1" >0.39</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row34_col0" class="data row34 col0" >T0413 - CENTRE CORINNE MALIKIAN</td>
#       <td id="T_b4f20_row34_col1" class="data row34 col1" >0.39</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row35_col0" class="data row35 col0" >T1486 - BAYVIEW ESTATE LTD.</td>
#       <td id="T_b4f20_row35_col1" class="data row35 col1" >0.39</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row36_col0" class="data row36 col0" >T0089 - Stefano BETTONI</td>
#       <td id="T_b4f20_row36_col1" class="data row36 col1" >0.38</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row37_col0" class="data row37 col0" >T1259 - SOCIETE NOUVELLE COMMERCIA</td>
#       <td id="T_b4f20_row37_col1" class="data row37 col1" >0.37</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row38_col0" class="data row38 col0" >T1333 - Alizée LE BRUN</td>
#       <td id="T_b4f20_row38_col1" class="data row38 col1" >0.35</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row39_col0" class="data row39 col0" >T1237 - CS PHYSIO</td>
#       <td id="T_b4f20_row39_col1" class="data row39 col1" >0.34</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row40_col0" class="data row40 col0" >T0668 - Dreissigacker Katrin</td>
#       <td id="T_b4f20_row40_col1" class="data row40 col1" >0.32</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row41_col0" class="data row41 col0" >T1452 - ONDYNEO</td>
#       <td id="T_b4f20_row41_col1" class="data row41 col1" >0.32</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row42_col0" class="data row42 col0" >T1484 - Cécilia Filippini</td>
#       <td id="T_b4f20_row42_col1" class="data row42 col1" >0.31</td>
#     </tr>
#     <tr>
#       <td id="T_b4f20_row43_col0" class="data row43 col0" >T0710 - EMC (Elettro Medical

# %% [markdown]
# # Depuis la première utilisation

# %%
# @title
display_unprofitable_clients_activity_per_days_year = sorted_activity_europe_50[sorted_activity_europe_50['activity_per_day_since_acquisition'] < 0.87][['full_name.1', 'activity_per_day_since_acquisition']].sort_values(by=['activity_per_day_since_acquisition'], ascending=False)
display_unprofitable_clients_activity_per_days_year = display_unprofitable_clients_activity_per_days_year.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_since_acquisition': 'Nombre moyen séance par jours sur 1 an',
        })
print(f"{len(display_unprofitable_clients_activity_per_days_year)} clients sur "+ f"{len(sorted_activity_europe_50)}" + " ne sont pas rentables")
display(display_unprofitable_clients_activity_per_days_year.style.format({"Nombre moyen séance par jours depuis la première séance": "{:.2f}"}).hide(axis='index'))
# Out:
# 197 clients sur 361 ne sont pas rentables
# <style type="text/css">
# </style>
# <table id="T_3afe4">
#   <thead>
#     <tr>
#       <th id="T_3afe4_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_3afe4_level0_col1" class="col_heading level0 col1" >Nombre moyen séance par jours sur 1 an</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3afe4_row0_col0" class="data row0 col0" >T1329 - Brahem MESSAOUI</td>
#       <td id="T_3afe4_row0_col1" class="data row0 col1" >0.860000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row1_col0" class="data row1 col0" >T0393 - CRYOSUD SARL</td>
#       <td id="T_3afe4_row1_col1" class="data row1 col1" >0.860000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row2_col0" class="data row2 col0" >T0903 - Dr Mathilde GUILLOT</td>
#       <td id="T_3afe4_row2_col1" class="data row2 col1" >0.860000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row3_col0" class="data row3 col0" >T0842 - BLC SYSTEM</td>
#       <td id="T_3afe4_row3_col1" class="data row3 col1" >0.830000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row4_col0" class="data row4 col0" >T0396 - SEBBAGH Aurélien</td>
#       <td id="T_3afe4_row4_col1" class="data row4 col1" >0.830000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row5_col0" class="data row5 col0" >T1704 - Ozon 2000 (SRL)</td>
#       <td id="T_3afe4_row5_col1" class="data row5 col1" >0.820000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row6_col0" class="data row6 col0" >T0819 - Bérengère BAS</td>
#       <td id="T_3afe4_row6_col1" class="data row6 col1" >0.810000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row7_col0" class="data row7 col0" >T1311 - Audrey DELEFORTRIE</td>
#       <td id="T_3afe4_row7_col1" class="data row7 col1" >0.780000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row8_col0" class="data row8 col0" >T1708 - Edith CARTIER</td>
#       <td id="T_3afe4_row8_col1" class="data row8 col1" >0.780000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row9_col0" class="data row9 col0" >T1280 - MAGUS APOTHICAIRE DE BEAUTE</td>
#       <td id="T_3afe4_row9_col1" class="data row9 col1" >0.770000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row10_col0" class="data row10 col0" >T1709 - Christelle TORCHEN</td>
#       <td id="T_3afe4_row10_col1" class="data row10 col1" >0.770000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row11_col0" class="data row11 col0" >T0597 - SELAS CCECB</td>
#       <td id="T_3afe4_row11_col1" class="data row11 col1" >0.770000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row12_col0" class="data row12 col0" >T0818 - Vicky MONTEIRO</td>
#       <td id="T_3afe4_row12_col1" class="data row12 col1" >0.760000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row13_col0" class="data row13 col0" >T0398 - HOMBOURGER ERIC</td>
#       <td id="T_3afe4_row13_col1" class="data row13 col1" >0.750000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row14_col0" class="data row14 col0" >T0844 - Emilie LEMETAYER</td>
#       <td id="T_3afe4_row14_col1" class="data row14 col1" >0.740000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row15_col0" class="data row15 col0" >T1653 - Cryopôle Saint-Affrique</td>
#       <td id="T_3afe4_row15_col1" class="data row15 col1" >0.730000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row16_col0" class="data row16 col0" >T1545 - SELAS EKEUH</td>
#       <td id="T_3afe4_row16_col1" class="data row16 col1" >0.730000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row17_col0" class="data row17 col0" >T0766 - Blandine AYMARD LARTIGUE</td>
#       <td id="T_3afe4_row17_col1" class="data row17 col1" >0.720000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row18_col0" class="data row18 col0" >T1551 - THE BODY BY CHRIS</td>
#       <td id="T_3afe4_row18_col1" class="data row18 col1" >0.720000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row19_col0" class="data row19 col0" >T0976 - CRYO MAUGUIO (CRYOPOLE)</td>
#       <td id="T_3afe4_row19_col1" class="data row19 col1" >0.710000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row20_col0" class="data row20 col0" >T1391 - PHYSIO BREIZH</td>
#       <td id="T_3afe4_row20_col1" class="data row20 col1" >0.700000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row21_col0" class="data row21 col0" >T0409 - LES JARDINS D'HEBE</td>
#       <td id="T_3afe4_row21_col1" class="data row21 col1" >0.700000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row22_col0" class="data row22 col0" >T1253 - SCM BAUVIN PARSIANI</td>
#       <td id="T_3afe4_row22_col1" class="data row22 col1" >0.690000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row23_col0" class="data row23 col0" >T1713 - Franck DUBOIS</td>
#       <td id="T_3afe4_row23_col1" class="data row23 col1" >0.680000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row24_col0" class="data row24 col0" >T0997 - Gwladys LAMOTHE</td>
#       <td id="T_3afe4_row24_col1" class="data row24 col1" >0.630000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row25_col0" class="data row25 col0" >T0631 - KANZLSPERGER GmbH</td>
#       <td id="T_3afe4_row25_col1" class="data row25 col1" >0.630000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row26_col0" class="data row26 col0" >T1714 - Francois BRUGIDOU</td>
#       <td id="T_3afe4_row26_col1" class="data row26 col1" >0.610000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row27_col0" class="data row27 col0" >T0404 - ODENTHAL Dominique</td>
#       <td id="T_3afe4_row27_col1" class="data row27 col1" >0.610000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row28_col0" class="data row28 col0" >T1450 - Centre Médical Pasteur</td>
#       <td id="T_3afe4_row28_col1" class="data row28 col1" >0.600000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row29_col0" class="data row29 col0" >T1476 - Loïc LAFON</td>
#       <td id="T_3afe4_row29_col1" class="data row29 col1" >0.590000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row30_col0" class="data row30 col0" >T1326 - Ines CUBILLOS</td>
#       <td id="T_3afe4_row30_col1" class="data row30 col1" >0.590000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row31_col0" class="data row31 col0" >T0736 - CENTRE ESTHETIQUE DESTINEE</td>
#       <td id="T_3afe4_row31_col1" class="data row31 col1" >0.570000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row32_col0" class="data row32 col0" >T1721 - Mathieu PICHOFF</td>
#       <td id="T_3afe4_row32_col1" class="data row32 col1" >0.560000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row33_col0" class="data row33 col0" >T1006 - Arnold health AG</td>
#       <td id="T_3afe4_row33_col1" class="data row33 col1" >0.560000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row34_col0" class="data row34 col0" >T1336 - Julien PION et Anaïs PARIS</td>
#       <td id="T_3afe4_row34_col1" class="data row34 col1" >0.560000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row35_col0" class="data row35 col0" >T1764 - Marion JENNY-SAUVEBOIS</td>
#       <td id="T_3afe4_row35_col1" class="data row35 col1" >0.560000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row36_col0" class="data row36 col0" >T1757 - Cédric FORMET</td>
#       <td id="T_3afe4_row36_col1" class="data row36 col1" >0.560000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row37_col0" class="data row37 col0" >T0738 - Stéphanie DURAND</td>
#       <td id="T_3afe4_row37_col1" class="data row37 col1" >0.550000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row38_col0" class="data row38 col0" >T1744 - Selarl Antoine CLEMENT</td>
#       <td id="T_3afe4_row38_col1" class="data row38 col1" >0.540000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row39_col0" class="data row39 col0" >T0663 - CryoBodyForme</td>
#       <td id="T_3afe4_row39_col1" class="data row39 col1" >0.540000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row40_col0" class="data row40 col0" >T1808 - Caroline NIMAL</td>
#       <td id="T_3afe4_row40_col1" class="data row40 col1" >0.540000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row41_col0" class="data row41 col0" >T0413 - CENTRE CORINNE MALIKIAN</td>
#       <td id="T_3afe4_row41_col1" class="data row41 col1" >0.520000</td>
#     </tr>
#     <tr>
#       <td id="T_3afe4_row42_col0" class="data row42 col0" >T1766 - Noémie PETIT</td>

# %% [markdown]
# # Classement des 30 premiers clients européens en fonction du nombre moyen de séances par jour

# %% [markdown]
# # Depuis l'acquisition de l'appareil V4

# %%
# @title
display_30_best_clients_activity_per_days_entire_period = sorted_activity_europe_50[['full_name.1', 'activity_per_day_since_acquisition', 'rank_activity_per_day_since_acquisition']]
display_30_best_clients_activity_per_days_entire_period = display_30_best_clients_activity_per_days_entire_period.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_since_acquisition': 'Nombre moyen séance par jours depuis acquisition',
    'rank_activity_per_day_since_acquisition' : 'Classement en fonction de l\'activité depuis l\'acquisition'
    })

#display_30_best_clients_activity_per_days_entire_period
#display(display_30_best_clients_activity_per_days_entire_period.head(30).style.hide(axis='index'))
display(display_30_best_clients_activity_per_days_entire_period.head(30).style.format({"Nombre moyen séance par jours depuis acquisition": "{:.1f}"}).hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_5b673">
#   <thead>
#     <tr>
#       <th id="T_5b673_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_5b673_level0_col1" class="col_heading level0 col1" >Nombre moyen séance par jours depuis acquisition</th>
#       <th id="T_5b673_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité depuis l'acquisition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5b673_row0_col0" class="data row0 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_5b673_row0_col1" class="data row0 col1" >16.3</td>
#       <td id="T_5b673_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row1_col0" class="data row1 col0" >T0100 - Franck ARCHIMBAUD</td>
#       <td id="T_5b673_row1_col1" class="data row1 col1" >12.0</td>
#       <td id="T_5b673_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row2_col0" class="data row2 col0" >T0108 - UAB MEDA LT</td>
#       <td id="T_5b673_row2_col1" class="data row2 col1" >9.3</td>
#       <td id="T_5b673_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row3_col0" class="data row3 col0" >T0711 - KINE FLOW</td>
#       <td id="T_5b673_row3_col1" class="data row3 col1" >4.4</td>
#       <td id="T_5b673_row3_col2" class="data row3 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row4_col0" class="data row4 col0" >T0821 - PROKINETIC</td>
#       <td id="T_5b673_row4_col1" class="data row4 col1" >8.3</td>
#       <td id="T_5b673_row4_col2" class="data row4 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row5_col0" class="data row5 col0" >T0745 - Thibaut LEONE</td>
#       <td id="T_5b673_row5_col1" class="data row5 col1" >4.7</td>
#       <td id="T_5b673_row5_col2" class="data row5 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row6_col0" class="data row6 col0" >T0091 - Selarl MEDVASC 32</td>
#       <td id="T_5b673_row6_col1" class="data row6 col1" >7.2</td>
#       <td id="T_5b673_row6_col2" class="data row6 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row7_col0" class="data row7 col0" >T0689 - SCM KINE FORM'</td>
#       <td id="T_5b673_row7_col1" class="data row7 col1" >6.0</td>
#       <td id="T_5b673_row7_col2" class="data row7 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row8_col0" class="data row8 col0" >T1013 - Natalia BARTOSEK</td>
#       <td id="T_5b673_row8_col1" class="data row8 col1" >3.2</td>
#       <td id="T_5b673_row8_col2" class="data row8 col2" >36</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row9_col0" class="data row9 col0" >T1543 - SCM KINESIO</td>
#       <td id="T_5b673_row9_col1" class="data row9 col1" >4.9</td>
#       <td id="T_5b673_row9_col2" class="data row9 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row10_col0" class="data row10 col0" >T1464 - SCM BETTAN - BERDAL</td>
#       <td id="T_5b673_row10_col1" class="data row10 col1" >4.7</td>
#       <td id="T_5b673_row10_col2" class="data row10 col2" >11</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row11_col0" class="data row11 col0" >T1408 - Mandy ROURRET</td>
#       <td id="T_5b673_row11_col1" class="data row11 col1" >4.2</td>
#       <td id="T_5b673_row11_col2" class="data row11 col2" >17</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row12_col0" class="data row12 col0" >T1406 - SOCIETE GANIER-WILLEMS-RIGOT</td>
#       <td id="T_5b673_row12_col1" class="data row12 col1" >4.8</td>
#       <td id="T_5b673_row12_col2" class="data row12 col2" >9</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row13_col0" class="data row13 col0" >T1344 - Christine BERTERO BONNENFANT</td>
#       <td id="T_5b673_row13_col1" class="data row13 col1" >3.3</td>
#       <td id="T_5b673_row13_col2" class="data row13 col2" >35</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row14_col0" class="data row14 col0" >T0098 - CAPOT PHILIPPE </td>
#       <td id="T_5b673_row14_col1" class="data row14 col1" >4.2</td>
#       <td id="T_5b673_row14_col2" class="data row14 col2" >16</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row15_col0" class="data row15 col0" >T1354 - LES CURES MARINES</td>
#       <td id="T_5b673_row15_col1" class="data row15 col1" >2.7</td>
#       <td id="T_5b673_row15_col2" class="data row15 col2" >55</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row16_col0" class="data row16 col0" >T1640 - DIET Jean-François</td>
#       <td id="T_5b673_row16_col1" class="data row16 col1" >4.7</td>
#       <td id="T_5b673_row16_col2" class="data row16 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row17_col0" class="data row17 col0" >T1421 - Sandra BONDON</td>
#       <td id="T_5b673_row17_col1" class="data row17 col1" >3.4</td>
#       <td id="T_5b673_row17_col2" class="data row17 col2" >31</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row18_col0" class="data row18 col0" >T0798 - Sophie FLAGEY LETONDAL</td>
#       <td id="T_5b673_row18_col1" class="data row18 col1" >3.1</td>
#       <td id="T_5b673_row18_col2" class="data row18 col2" >41</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row19_col0" class="data row19 col0" >T1428 - 9298-5316 Québec Inc.</td>
#       <td id="T_5b673_row19_col1" class="data row19 col1" >4.3</td>
#       <td id="T_5b673_row19_col2" class="data row19 col2" >15</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row20_col0" class="data row20 col0" >T1360 - Guillaume BRUNEL - Pauline GAGNIERE</td>
#       <td id="T_5b673_row20_col1" class="data row20 col1" >3.7</td>
#       <td id="T_5b673_row20_col2" class="data row20 col2" >27</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row21_col0" class="data row21 col0" >T1680 - Laure GIULIANI</td>
#       <td id="T_5b673_row21_col1" class="data row21 col1" >7.4</td>
#       <td id="T_5b673_row21_col2" class="data row21 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row22_col0" class="data row22 col0" >T0421 - SCM LAU ET CO</td>
#       <td id="T_5b673_row22_col1" class="data row22 col1" >2.9</td>
#       <td id="T_5b673_row22_col2" class="data row22 col2" >44</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row23_col0" class="data row23 col0" >T1507 - AXE KINE</td>
#       <td id="T_5b673_row23_col1" class="data row23 col1" >3.7</td>
#       <td id="T_5b673_row23_col2" class="data row23 col2" >26</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row24_col0" class="data row24 col0" >T0649 - Marie-Caroline CHARBONNIER MONTAUDIE</td>
#       <td id="T_5b673_row24_col1" class="data row24 col1" >3.5</td>
#       <td id="T_5b673_row24_col2" class="data row24 col2" >30</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row25_col0" class="data row25 col0" >T0820 - Nicolas BOCACCIO</td>
#       <td id="T_5b673_row25_col1" class="data row25 col1" >3.9</td>
#       <td id="T_5b673_row25_col2" class="data row25 col2" >24</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row26_col0" class="data row26 col0" >T1315 - SCM KINEFLEX</td>
#       <td id="T_5b673_row26_col1" class="data row26 col1" >4.0</td>
#       <td id="T_5b673_row26_col2" class="data row26 col2" >21</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row27_col0" class="data row27 col0" >T1410 - MAGIKTRADE</td>
#       <td id="T_5b673_row27_col1" class="data row27 col1" >4.1</td>
#       <td id="T_5b673_row27_col2" class="data row27 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row28_col0" class="data row28 col0" >T0139 - KIWI SANTE</td>
#       <td id="T_5b673_row28_col1" class="data row28 col1" >4.1</td>
#       <td id="T_5b673_row28_col2" class="data row28 col2" >19</td>
#     </tr>
#     <tr>
#       <td id="T_5b673_row29_col0" class="data row29 col0" >T0109 - Olivier BORTOLASO</td>
#       <td id="T_5b673_row29_col1" class="data row29 col1" >2.7</td>
#       <td id="T_5b673_row29_col2" class="data row29 col2" >53</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_per_days_entire_period.head(30)['Nom du client'], display_30_best_clients_activity_per_days_entire_period.head(30)['Nombre moyen séance par jours depuis acquisition'],  alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres moyen de séances par jours')
plt.title('Classement des 30 premiers clients européens en fonction du nombre moyen de séances par jour depuis l\'acquisition de l\'appareil V4')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # sur les 7 derniers jours

# %%
# @title
#display_30_best_clients_activity_per_days_7_days = sorted_activity_europe_50[['full_name.1', 'activity_per_day_7_days', 'rank_activity_per_day_7_days']].sort_values(by=['activity_per_day_7_days'], ascending=False)
display_30_best_clients_activity_per_days_7_days = sorted_activity_europe_50[sorted_activity_europe_50['number_days'] > 7][['full_name.1', 'activity_per_day_7_days', 'rank_activity_per_day_7_days']].sort_values(by=['activity_per_day_7_days'], ascending=False)
display_30_best_clients_activity_per_days_7_days = display_30_best_clients_activity_per_days_7_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_7_days': 'Nombre moyen séances par jours sur les 7 derniers jours',
    'rank_activity_per_day_7_days' : 'Classement en fonction de l\'activité sur les 7 derniers jours'
    })


#display(display_30_best_clients_activity_per_days_7_days.head(30).style.hide(axis='index'))
display(display_30_best_clients_activity_per_days_7_days.head(30).style.format({"Nombre moyen séances par jours sur les 7 derniers jours": "{:.1f}"}).hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_623bf">
#   <thead>
#     <tr>
#       <th id="T_623bf_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_623bf_level0_col1" class="col_heading level0 col1" >Nombre moyen séances par jours sur les 7 derniers jours</th>
#       <th id="T_623bf_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur les 7 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_623bf_row0_col0" class="data row0 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_623bf_row0_col1" class="data row0 col1" >0.0</td>
#       <td id="T_623bf_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row1_col0" class="data row1 col0" >T0631 - KANZLSPERGER GmbH</td>
#       <td id="T_623bf_row1_col1" class="data row1 col1" >0.0</td>
#       <td id="T_623bf_row1_col2" class="data row1 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row2_col0" class="data row2 col0" >T0762 - VOLANT SERVICES MANAGEMENT</td>
#       <td id="T_623bf_row2_col1" class="data row2 col1" >0.0</td>
#       <td id="T_623bf_row2_col2" class="data row2 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row3_col0" class="data row3 col0" >T1769 - LEDEN LASER</td>
#       <td id="T_623bf_row3_col1" class="data row3 col1" >0.0</td>
#       <td id="T_623bf_row3_col2" class="data row3 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row4_col0" class="data row4 col0" >T1817 - Laure GUIRAL</td>
#       <td id="T_623bf_row4_col1" class="data row4 col1" >0.0</td>
#       <td id="T_623bf_row4_col2" class="data row4 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row5_col0" class="data row5 col0" >T1620 - PENSULA SL</td>
#       <td id="T_623bf_row5_col1" class="data row5 col1" >0.0</td>
#       <td id="T_623bf_row5_col2" class="data row5 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row6_col0" class="data row6 col0" >T0806 - HOITOLA WOMAN</td>
#       <td id="T_623bf_row6_col1" class="data row6 col1" >0.0</td>
#       <td id="T_623bf_row6_col2" class="data row6 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row7_col0" class="data row7 col0" >T1764 - Marion JENNY-SAUVEBOIS</td>
#       <td id="T_623bf_row7_col1" class="data row7 col1" >0.0</td>
#       <td id="T_623bf_row7_col2" class="data row7 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row8_col0" class="data row8 col0" >T1390 - Zell Spa AG</td>
#       <td id="T_623bf_row8_col1" class="data row8 col1" >0.0</td>
#       <td id="T_623bf_row8_col2" class="data row8 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row9_col0" class="data row9 col0" >T0142 - Myriam LAVOINE (Kiné 62)</td>
#       <td id="T_623bf_row9_col1" class="data row9 col1" >0.0</td>
#       <td id="T_623bf_row9_col2" class="data row9 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row10_col0" class="data row10 col0" >T0530 - WYBO Frédéric</td>
#       <td id="T_623bf_row10_col1" class="data row10 col1" >0.0</td>
#       <td id="T_623bf_row10_col2" class="data row10 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row11_col0" class="data row11 col0" >T0971 - MTR – Health & Spa AG</td>
#       <td id="T_623bf_row11_col1" class="data row11 col1" >0.0</td>
#       <td id="T_623bf_row11_col2" class="data row11 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row12_col0" class="data row12 col0" >T0752 - DENTAL EQUIPEMENT</td>
#       <td id="T_623bf_row12_col1" class="data row12 col1" >0.0</td>
#       <td id="T_623bf_row12_col2" class="data row12 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row13_col0" class="data row13 col0" >T1766 - Noémie PETIT</td>
#       <td id="T_623bf_row13_col1" class="data row13 col1" >0.0</td>
#       <td id="T_623bf_row13_col2" class="data row13 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row14_col0" class="data row14 col0" >T1226 - SARL CALI IMAGE</td>
#       <td id="T_623bf_row14_col1" class="data row14 col1" >0.0</td>
#       <td id="T_623bf_row14_col2" class="data row14 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row15_col0" class="data row15 col0" >T1742 - Cryopôle Caissargues</td>
#       <td id="T_623bf_row15_col1" class="data row15 col1" >0.0</td>
#       <td id="T_623bf_row15_col2" class="data row15 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row16_col0" class="data row16 col0" >T1588 - ACTIF BIEN ETRE SAS</td>
#       <td id="T_623bf_row16_col1" class="data row16 col1" >0.0</td>
#       <td id="T_623bf_row16_col2" class="data row16 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row17_col0" class="data row17 col0" >T0610 - Marro Joséphine</td>
#       <td id="T_623bf_row17_col1" class="data row17 col1" >0.0</td>
#       <td id="T_623bf_row17_col2" class="data row17 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row18_col0" class="data row18 col0" >T1523 - Helicia CHERUBIN</td>
#       <td id="T_623bf_row18_col1" class="data row18 col1" >0.0</td>
#       <td id="T_623bf_row18_col2" class="data row18 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row19_col0" class="data row19 col0" >T1811 - Christelle GUITARD</td>
#       <td id="T_623bf_row19_col1" class="data row19 col1" >0.0</td>
#       <td id="T_623bf_row19_col2" class="data row19 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row20_col0" class="data row20 col0" >T1661 - Barbora Jarosaite</td>
#       <td id="T_623bf_row20_col1" class="data row20 col1" >0.0</td>
#       <td id="T_623bf_row20_col2" class="data row20 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row21_col0" class="data row21 col0" >T0663 - CryoBodyForme</td>
#       <td id="T_623bf_row21_col1" class="data row21 col1" >0.0</td>
#       <td id="T_623bf_row21_col2" class="data row21 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row22_col0" class="data row22 col0" >T0389 - ESPACE BEAUTE NATURELLE</td>
#       <td id="T_623bf_row22_col1" class="data row22 col1" >0.0</td>
#       <td id="T_623bf_row22_col2" class="data row22 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row23_col0" class="data row23 col0" >T1708 - Edith CARTIER</td>
#       <td id="T_623bf_row23_col1" class="data row23 col1" >0.0</td>
#       <td id="T_623bf_row23_col2" class="data row23 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row24_col0" class="data row24 col0" >T1290 - DOBELMANN Didier</td>
#       <td id="T_623bf_row24_col1" class="data row24 col1" >0.0</td>
#       <td id="T_623bf_row24_col2" class="data row24 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row25_col0" class="data row25 col0" >T0624 - Beauty S.O.S. Inc.</td>
#       <td id="T_623bf_row25_col1" class="data row25 col1" >0.0</td>
#       <td id="T_623bf_row25_col2" class="data row25 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row26_col0" class="data row26 col0" >T0425 - OCCHIMINUTI Jean-Claude</td>
#       <td id="T_623bf_row26_col1" class="data row26 col1" >0.0</td>
#       <td id="T_623bf_row26_col2" class="data row26 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row27_col0" class="data row27 col0" >T1740 - MRH ZERMATT SA</td>
#       <td id="T_623bf_row27_col1" class="data row27 col1" >0.0</td>
#       <td id="T_623bf_row27_col2" class="data row27 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row28_col0" class="data row28 col0" >T1380 - VIVAESTHETIC</td>
#       <td id="T_623bf_row28_col1" class="data row28 col1" >0.0</td>
#       <td id="T_623bf_row28_col2" class="data row28 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_623bf_row29_col0" class="data row29 col0" >T1243 - Malang SANO</td>
#       <td id="T_623bf_row29_col1" class="data row29 col1" >0.0</td>
#       <td id="T_623bf_row29_col2" class="data row29 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_per_days_7_days.head(30)['Nom du client'], display_30_best_clients_activity_per_days_7_days.head(30)['Nombre moyen séances par jours sur les 7 derniers jours'],  alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres moyen de séances par jours')
plt.title('Classement des 30 premiers clients européens en fonction du nombre moyen de séances par jour sur les 7 derniers jours')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # sur les 14 derniers jours

# %%
# @title
#display_30_best_clients_activity_per_days_14_days = sorted_activity_europe_50[['full_name.1', 'activity_per_day_14_days', 'rank_activity_per_day_14_days']].sort_values(by=['activity_per_day_14_days'], ascending=False)
display_30_best_clients_activity_per_days_14_days = sorted_activity_europe_50[sorted_activity_europe_50['number_days'] > 14][['full_name.1', 'activity_per_day_14_days', 'rank_activity_per_day_14_days']].sort_values(by=['activity_per_day_14_days'], ascending=False)
display_30_best_clients_activity_per_days_14_days = display_30_best_clients_activity_per_days_14_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_14_days': 'Nombre moyen séances par jours sur les 14 derniers jours',
    'rank_activity_per_day_14_days' : 'Classement en fonction de l\'activité sur les 14 derniers jours'
    })


#display(display_30_best_clients_activity_per_days_14_days.head(30).style.hide(axis='index'))
display(display_30_best_clients_activity_per_days_14_days.head(30).style.format({"Nombre moyen séances par jours sur les 14 derniers jours": "{:.1f}"}).hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_52370">
#   <thead>
#     <tr>
#       <th id="T_52370_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_52370_level0_col1" class="col_heading level0 col1" >Nombre moyen séances par jours sur les 14 derniers jours</th>
#       <th id="T_52370_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur les 14 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_52370_row0_col0" class="data row0 col0" >T0108 - UAB MEDA LT</td>
#       <td id="T_52370_row0_col1" class="data row0 col1" >5.1</td>
#       <td id="T_52370_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row1_col0" class="data row1 col0" >T0821 - PROKINETIC</td>
#       <td id="T_52370_row1_col1" class="data row1 col1" >4.7</td>
#       <td id="T_52370_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row2_col0" class="data row2 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_52370_row2_col1" class="data row2 col1" >3.5</td>
#       <td id="T_52370_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row3_col0" class="data row3 col0" >T1680 - Laure GIULIANI</td>
#       <td id="T_52370_row3_col1" class="data row3 col1" >3.4</td>
#       <td id="T_52370_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row4_col0" class="data row4 col0" >T1354 - LES CURES MARINES</td>
#       <td id="T_52370_row4_col1" class="data row4 col1" >3.1</td>
#       <td id="T_52370_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row5_col0" class="data row5 col0" >T1344 - Christine BERTERO BONNENFANT</td>
#       <td id="T_52370_row5_col1" class="data row5 col1" >2.6</td>
#       <td id="T_52370_row5_col2" class="data row5 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row6_col0" class="data row6 col0" >T0689 - SCM KINE FORM'</td>
#       <td id="T_52370_row6_col1" class="data row6 col1" >2.6</td>
#       <td id="T_52370_row6_col2" class="data row6 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row7_col0" class="data row7 col0" >T0711 - KINE FLOW</td>
#       <td id="T_52370_row7_col1" class="data row7 col1" >2.3</td>
#       <td id="T_52370_row7_col2" class="data row7 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row8_col0" class="data row8 col0" >T1543 - SCM KINESIO</td>
#       <td id="T_52370_row8_col1" class="data row8 col1" >2.3</td>
#       <td id="T_52370_row8_col2" class="data row8 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row9_col0" class="data row9 col0" >T0100 - Franck ARCHIMBAUD</td>
#       <td id="T_52370_row9_col1" class="data row9 col1" >2.2</td>
#       <td id="T_52370_row9_col2" class="data row9 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row10_col0" class="data row10 col0" >T0798 - Sophie FLAGEY LETONDAL</td>
#       <td id="T_52370_row10_col1" class="data row10 col1" >2.2</td>
#       <td id="T_52370_row10_col2" class="data row10 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row11_col0" class="data row11 col0" >T1640 - DIET Jean-François</td>
#       <td id="T_52370_row11_col1" class="data row11 col1" >2.1</td>
#       <td id="T_52370_row11_col2" class="data row11 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row12_col0" class="data row12 col0" >T1590 - Virginie L'HERMENIER</td>
#       <td id="T_52370_row12_col1" class="data row12 col1" >2.1</td>
#       <td id="T_52370_row12_col2" class="data row12 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row13_col0" class="data row13 col0" >T0098 - CAPOT PHILIPPE </td>
#       <td id="T_52370_row13_col1" class="data row13 col1" >2.0</td>
#       <td id="T_52370_row13_col2" class="data row13 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row14_col0" class="data row14 col0" >T0421 - SCM LAU ET CO</td>
#       <td id="T_52370_row14_col1" class="data row14 col1" >1.8</td>
#       <td id="T_52370_row14_col2" class="data row14 col2" >15</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row15_col0" class="data row15 col0" >T1428 - 9298-5316 Québec Inc.</td>
#       <td id="T_52370_row15_col1" class="data row15 col1" >1.8</td>
#       <td id="T_52370_row15_col2" class="data row15 col2" >15</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row16_col0" class="data row16 col0" >T1360 - Guillaume BRUNEL - Pauline GAGNIERE</td>
#       <td id="T_52370_row16_col1" class="data row16 col1" >1.7</td>
#       <td id="T_52370_row16_col2" class="data row16 col2" >17</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row17_col0" class="data row17 col0" >T1327 - Anne TEKO GEIGER</td>
#       <td id="T_52370_row17_col1" class="data row17 col1" >1.7</td>
#       <td id="T_52370_row17_col2" class="data row17 col2" >17</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row18_col0" class="data row18 col0" >T0792 - SCM TRIQUETRUM</td>
#       <td id="T_52370_row18_col1" class="data row18 col1" >1.6</td>
#       <td id="T_52370_row18_col2" class="data row18 col2" >19</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row19_col0" class="data row19 col0" >T0139 - KIWI SANTE</td>
#       <td id="T_52370_row19_col1" class="data row19 col1" >1.4</td>
#       <td id="T_52370_row19_col2" class="data row19 col2" >20</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row20_col0" class="data row20 col0" >T1814 - Isabelle NORET</td>
#       <td id="T_52370_row20_col1" class="data row20 col1" >1.4</td>
#       <td id="T_52370_row20_col2" class="data row20 col2" >20</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row21_col0" class="data row21 col0" >T0941 - Lionel BOUDON</td>
#       <td id="T_52370_row21_col1" class="data row21 col1" >1.3</td>
#       <td id="T_52370_row21_col2" class="data row21 col2" >22</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row22_col0" class="data row22 col0" >T1274 - STENDO BEAUTY AU</td>
#       <td id="T_52370_row22_col1" class="data row22 col1" >1.3</td>
#       <td id="T_52370_row22_col2" class="data row22 col2" >22</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row23_col0" class="data row23 col0" >T1538 - François MIGUEL</td>
#       <td id="T_52370_row23_col1" class="data row23 col1" >1.3</td>
#       <td id="T_52370_row23_col2" class="data row23 col2" >22</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row24_col0" class="data row24 col0" >T1757 - Cédric FORMET</td>
#       <td id="T_52370_row24_col1" class="data row24 col1" >1.2</td>
#       <td id="T_52370_row24_col2" class="data row24 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row25_col0" class="data row25 col0" >T1664 - ARK Cabinet de Kiné</td>
#       <td id="T_52370_row25_col1" class="data row25 col1" >1.2</td>
#       <td id="T_52370_row25_col2" class="data row25 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row26_col0" class="data row26 col0" >T0820 - Nicolas BOCACCIO</td>
#       <td id="T_52370_row26_col1" class="data row26 col1" >1.2</td>
#       <td id="T_52370_row26_col2" class="data row26 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row27_col0" class="data row27 col0" >T1754 - Christelle DUQUESNE</td>
#       <td id="T_52370_row27_col1" class="data row27 col1" >1.2</td>
#       <td id="T_52370_row27_col2" class="data row27 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row28_col0" class="data row28 col0" >T0385 - BATAILLE Maxime</td>
#       <td id="T_52370_row28_col1" class="data row28 col1" >1.1</td>
#       <td id="T_52370_row28_col2" class="data row28 col2" >29</td>
#     </tr>
#     <tr>
#       <td id="T_52370_row29_col0" class="data row29 col0" >T1697 - Stéphanie SANCHEZ</td>
#       <td id="T_52370_row29_col1" class="data row29 col1" >1.1</td>
#       <td id="T_52370_row29_col2" class="data row29 col2" >29</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_per_days_14_days.head(30)['Nom du client'], display_30_best_clients_activity_per_days_14_days.head(30)['Nombre moyen séances par jours sur les 14 derniers jours'],  alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres moyen de séances par jours')
plt.title('Classement des 30 premiers clients européens en fonction du nombre moyen de séances par jour sur les 14 derniers jours')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # sur les 30 derniers jours

# %%
# @title
#display_30_best_clients_activity_per_days_30_days = sorted_activity_europe_50[['full_name.1', 'activity_per_day_30_days', 'rank_activity_per_day_30_days']].sort_values(by=['activity_per_day_30_days'], ascending=False)
display_30_best_clients_activity_per_days_30_days = sorted_activity_europe_50[sorted_activity_europe_50['number_days'] > 30][['full_name.1', 'activity_per_day_30_days', 'rank_activity_per_day_30_days']].sort_values(by=['activity_per_day_30_days'], ascending=False)
display_30_best_clients_activity_per_days_30_days = display_30_best_clients_activity_per_days_30_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_30_days': 'Nombre moyen séances par jours sur les 30 derniers jours',
    'rank_activity_per_day_30_days' : 'Classement en fonction de l\'activité sur les 30 derniers jours'
    })


#display(display_30_best_clients_activity_per_days_30_days.head(30).style.hide(axis='index'))
display(display_30_best_clients_activity_per_days_30_days.head(30).style.format({"Nombre moyen séances par jours sur les 30 derniers jours": "{:.1f}"}).hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_07e27">
#   <thead>
#     <tr>
#       <th id="T_07e27_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_07e27_level0_col1" class="col_heading level0 col1" >Nombre moyen séances par jours sur les 30 derniers jours</th>
#       <th id="T_07e27_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur les 30 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_07e27_row0_col0" class="data row0 col0" >T0108 - UAB MEDA LT</td>
#       <td id="T_07e27_row0_col1" class="data row0 col1" >9.3</td>
#       <td id="T_07e27_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row1_col0" class="data row1 col0" >T0821 - PROKINETIC</td>
#       <td id="T_07e27_row1_col1" class="data row1 col1" >8.8</td>
#       <td id="T_07e27_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row2_col0" class="data row2 col0" >T1680 - Laure GIULIANI</td>
#       <td id="T_07e27_row2_col1" class="data row2 col1" >8.0</td>
#       <td id="T_07e27_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row3_col0" class="data row3 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_07e27_row3_col1" class="data row3 col1" >7.8</td>
#       <td id="T_07e27_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row4_col0" class="data row4 col0" >T0100 - Franck ARCHIMBAUD</td>
#       <td id="T_07e27_row4_col1" class="data row4 col1" >5.3</td>
#       <td id="T_07e27_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row5_col0" class="data row5 col0" >T0711 - KINE FLOW</td>
#       <td id="T_07e27_row5_col1" class="data row5 col1" >4.5</td>
#       <td id="T_07e27_row5_col2" class="data row5 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row6_col0" class="data row6 col0" >T1344 - Christine BERTERO BONNENFANT</td>
#       <td id="T_07e27_row6_col1" class="data row6 col1" >4.3</td>
#       <td id="T_07e27_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row7_col0" class="data row7 col0" >T1640 - DIET Jean-François</td>
#       <td id="T_07e27_row7_col1" class="data row7 col1" >4.2</td>
#       <td id="T_07e27_row7_col2" class="data row7 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row8_col0" class="data row8 col0" >T0689 - SCM KINE FORM'</td>
#       <td id="T_07e27_row8_col1" class="data row8 col1" >4.1</td>
#       <td id="T_07e27_row8_col2" class="data row8 col2" >9</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row9_col0" class="data row9 col0" >T1543 - SCM KINESIO</td>
#       <td id="T_07e27_row9_col1" class="data row9 col1" >4.0</td>
#       <td id="T_07e27_row9_col2" class="data row9 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row10_col0" class="data row10 col0" >T0792 - SCM TRIQUETRUM</td>
#       <td id="T_07e27_row10_col1" class="data row10 col1" >4.0</td>
#       <td id="T_07e27_row10_col2" class="data row10 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row11_col0" class="data row11 col0" >T0098 - CAPOT PHILIPPE </td>
#       <td id="T_07e27_row11_col1" class="data row11 col1" >3.9</td>
#       <td id="T_07e27_row11_col2" class="data row11 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row12_col0" class="data row12 col0" >T1013 - Natalia BARTOSEK</td>
#       <td id="T_07e27_row12_col1" class="data row12 col1" >3.9</td>
#       <td id="T_07e27_row12_col2" class="data row12 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row13_col0" class="data row13 col0" >T0798 - Sophie FLAGEY LETONDAL</td>
#       <td id="T_07e27_row13_col1" class="data row13 col1" >3.9</td>
#       <td id="T_07e27_row13_col2" class="data row13 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row14_col0" class="data row14 col0" >T1354 - LES CURES MARINES</td>
#       <td id="T_07e27_row14_col1" class="data row14 col1" >3.9</td>
#       <td id="T_07e27_row14_col2" class="data row14 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row15_col0" class="data row15 col0" >T1360 - Guillaume BRUNEL - Pauline GAGNIERE</td>
#       <td id="T_07e27_row15_col1" class="data row15 col1" >3.8</td>
#       <td id="T_07e27_row15_col2" class="data row15 col2" >16</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row16_col0" class="data row16 col0" >T1754 - Christelle DUQUESNE</td>
#       <td id="T_07e27_row16_col1" class="data row16 col1" >3.7</td>
#       <td id="T_07e27_row16_col2" class="data row16 col2" >17</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row17_col0" class="data row17 col0" >T1428 - 9298-5316 Québec Inc.</td>
#       <td id="T_07e27_row17_col1" class="data row17 col1" >3.5</td>
#       <td id="T_07e27_row17_col2" class="data row17 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row18_col0" class="data row18 col0" >T0421 - SCM LAU ET CO</td>
#       <td id="T_07e27_row18_col1" class="data row18 col1" >3.2</td>
#       <td id="T_07e27_row18_col2" class="data row18 col2" >19</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row19_col0" class="data row19 col0" >T0139 - KIWI SANTE</td>
#       <td id="T_07e27_row19_col1" class="data row19 col1" >3.1</td>
#       <td id="T_07e27_row19_col2" class="data row19 col2" >20</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row20_col0" class="data row20 col0" >T1590 - Virginie L'HERMENIER</td>
#       <td id="T_07e27_row20_col1" class="data row20 col1" >3.1</td>
#       <td id="T_07e27_row20_col2" class="data row20 col2" >20</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row21_col0" class="data row21 col0" >T0830 - Eve CAVALIE</td>
#       <td id="T_07e27_row21_col1" class="data row21 col1" >3.0</td>
#       <td id="T_07e27_row21_col2" class="data row21 col2" >22</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row22_col0" class="data row22 col0" >T1776 - Fanny LE GAL</td>
#       <td id="T_07e27_row22_col1" class="data row22 col1" >3.0</td>
#       <td id="T_07e27_row22_col2" class="data row22 col2" >22</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row23_col0" class="data row23 col0" >T1664 - ARK Cabinet de Kiné</td>
#       <td id="T_07e27_row23_col1" class="data row23 col1" >3.0</td>
#       <td id="T_07e27_row23_col2" class="data row23 col2" >24</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row24_col0" class="data row24 col0" >T0091 - Selarl MEDVASC 32</td>
#       <td id="T_07e27_row24_col1" class="data row24 col1" >2.8</td>
#       <td id="T_07e27_row24_col2" class="data row24 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row25_col0" class="data row25 col0" >T1421 - Sandra BONDON</td>
#       <td id="T_07e27_row25_col1" class="data row25 col1" >2.7</td>
#       <td id="T_07e27_row25_col2" class="data row25 col2" >26</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row26_col0" class="data row26 col0" >T1686 - SCM RHEA THERAPIE</td>
#       <td id="T_07e27_row26_col1" class="data row26 col1" >2.6</td>
#       <td id="T_07e27_row26_col2" class="data row26 col2" >27</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row27_col0" class="data row27 col0" >T1408 - Mandy ROURRET</td>
#       <td id="T_07e27_row27_col1" class="data row27 col1" >2.6</td>
#       <td id="T_07e27_row27_col2" class="data row27 col2" >27</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row28_col0" class="data row28 col0" >T1257 - Clinique du monde</td>
#       <td id="T_07e27_row28_col1" class="data row28 col1" >2.6</td>
#       <td id="T_07e27_row28_col2" class="data row28 col2" >27</td>
#     </tr>
#     <tr>
#       <td id="T_07e27_row29_col0" class="data row29 col0" >T0745 - Thibaut LEONE</td>
#       <td id="T_07e27_row29_col1" class="data row29 col1" >2.6</td>
#       <td id="T_07e27_row29_col2" class="data row29 col2" >30</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_per_days_30_days.head(30)['Nom du client'], display_30_best_clients_activity_per_days_30_days.head(30)['Nombre moyen séances par jours sur les 30 derniers jours'],  alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres moyen de séances par jours')
plt.title('Classement des 30 premiers clients européens en fonction du nombre moyen de séances par jour sur les 30 derniers jours')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # sur les 90 derniers jours

# %%
# @title
#display_30_best_clients_activity_per_days_90_days = sorted_activity_europe_50[['full_name.1', 'activity_per_day_90_days', 'rank_activity_per_day_90_days']].sort_values(by=['activity_per_day_90_days'], ascending=False)
display_30_best_clients_activity_per_days_90_days = sorted_activity_europe_50[sorted_activity_europe_50['number_days'] > 90][['full_name.1', 'activity_per_day_90_days', 'rank_activity_per_day_90_days']].sort_values(by=['activity_per_day_90_days'], ascending=False)
display_30_best_clients_activity_per_days_90_days = display_30_best_clients_activity_per_days_90_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_90_days': 'Nombre moyen séances par jours sur les 90 derniers jours',
    'rank_activity_per_day_90_days' : 'Classement en fonction de l\'activité sur les 90 derniers jours'
    })


#display(display_30_best_clients_activity_per_days_90_days.head(30).style.hide(axis='index'))
display(display_30_best_clients_activity_per_days_90_days.head(30).style.format({"Nombre moyen séances par jours sur les 90 derniers jours": "{:.1f}"}).hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_46d5c">
#   <thead>
#     <tr>
#       <th id="T_46d5c_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_46d5c_level0_col1" class="col_heading level0 col1" >Nombre moyen séances par jours sur les 90 derniers jours</th>
#       <th id="T_46d5c_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur les 90 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_46d5c_row0_col0" class="data row0 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_46d5c_row0_col1" class="data row0 col1" >17.7</td>
#       <td id="T_46d5c_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row1_col0" class="data row1 col0" >T0108 - UAB MEDA LT</td>
#       <td id="T_46d5c_row1_col1" class="data row1 col1" >16.4</td>
#       <td id="T_46d5c_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row2_col0" class="data row2 col0" >T0821 - PROKINETIC</td>
#       <td id="T_46d5c_row2_col1" class="data row2 col1" >13.0</td>
#       <td id="T_46d5c_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row3_col0" class="data row3 col0" >T1680 - Laure GIULIANI</td>
#       <td id="T_46d5c_row3_col1" class="data row3 col1" >11.6</td>
#       <td id="T_46d5c_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row4_col0" class="data row4 col0" >T0711 - KINE FLOW</td>
#       <td id="T_46d5c_row4_col1" class="data row4 col1" >10.2</td>
#       <td id="T_46d5c_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row5_col0" class="data row5 col0" >T0792 - SCM TRIQUETRUM</td>
#       <td id="T_46d5c_row5_col1" class="data row5 col1" >10.1</td>
#       <td id="T_46d5c_row5_col2" class="data row5 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row6_col0" class="data row6 col0" >T0100 - Franck ARCHIMBAUD</td>
#       <td id="T_46d5c_row6_col1" class="data row6 col1" >10.0</td>
#       <td id="T_46d5c_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row7_col0" class="data row7 col0" >T1344 - Christine BERTERO BONNENFANT</td>
#       <td id="T_46d5c_row7_col1" class="data row7 col1" >9.1</td>
#       <td id="T_46d5c_row7_col2" class="data row7 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row8_col0" class="data row8 col0" >T0689 - SCM KINE FORM'</td>
#       <td id="T_46d5c_row8_col1" class="data row8 col1" >9.1</td>
#       <td id="T_46d5c_row8_col2" class="data row8 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row9_col0" class="data row9 col0" >T0745 - Thibaut LEONE</td>
#       <td id="T_46d5c_row9_col1" class="data row9 col1" >8.5</td>
#       <td id="T_46d5c_row9_col2" class="data row9 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row10_col0" class="data row10 col0" >T1754 - Christelle DUQUESNE</td>
#       <td id="T_46d5c_row10_col1" class="data row10 col1" >7.7</td>
#       <td id="T_46d5c_row10_col2" class="data row10 col2" >11</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row11_col0" class="data row11 col0" >T1408 - Mandy ROURRET</td>
#       <td id="T_46d5c_row11_col1" class="data row11 col1" >7.5</td>
#       <td id="T_46d5c_row11_col2" class="data row11 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row12_col0" class="data row12 col0" >T1013 - Natalia BARTOSEK</td>
#       <td id="T_46d5c_row12_col1" class="data row12 col1" >7.3</td>
#       <td id="T_46d5c_row12_col2" class="data row12 col2" >13</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row13_col0" class="data row13 col0" >T1543 - SCM KINESIO</td>
#       <td id="T_46d5c_row13_col1" class="data row13 col1" >7.0</td>
#       <td id="T_46d5c_row13_col2" class="data row13 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row14_col0" class="data row14 col0" >T1354 - LES CURES MARINES</td>
#       <td id="T_46d5c_row14_col1" class="data row14 col1" >6.9</td>
#       <td id="T_46d5c_row14_col2" class="data row14 col2" >15</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row15_col0" class="data row15 col0" >T1464 - SCM BETTAN - BERDAL</td>
#       <td id="T_46d5c_row15_col1" class="data row15 col1" >6.6</td>
#       <td id="T_46d5c_row15_col2" class="data row15 col2" >16</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row16_col0" class="data row16 col0" >T1507 - AXE KINE</td>
#       <td id="T_46d5c_row16_col1" class="data row16 col1" >6.6</td>
#       <td id="T_46d5c_row16_col2" class="data row16 col2" >17</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row17_col0" class="data row17 col0" >T0098 - CAPOT PHILIPPE </td>
#       <td id="T_46d5c_row17_col1" class="data row17 col1" >6.3</td>
#       <td id="T_46d5c_row17_col2" class="data row17 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row18_col0" class="data row18 col0" >T1406 - SOCIETE GANIER-WILLEMS-RIGOT</td>
#       <td id="T_46d5c_row18_col1" class="data row18 col1" >6.2</td>
#       <td id="T_46d5c_row18_col2" class="data row18 col2" >19</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row19_col0" class="data row19 col0" >T1776 - Fanny LE GAL</td>
#       <td id="T_46d5c_row19_col1" class="data row19 col1" >6.0</td>
#       <td id="T_46d5c_row19_col2" class="data row19 col2" >20</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row20_col0" class="data row20 col0" >T0649 - Marie-Caroline CHARBONNIER MONTAUDIE</td>
#       <td id="T_46d5c_row20_col1" class="data row20 col1" >6.0</td>
#       <td id="T_46d5c_row20_col2" class="data row20 col2" >21</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row21_col0" class="data row21 col0" >T0385 - BATAILLE Maxime</td>
#       <td id="T_46d5c_row21_col1" class="data row21 col1" >5.7</td>
#       <td id="T_46d5c_row21_col2" class="data row21 col2" >22</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row22_col0" class="data row22 col0" >T1428 - 9298-5316 Québec Inc.</td>
#       <td id="T_46d5c_row22_col1" class="data row22 col1" >5.4</td>
#       <td id="T_46d5c_row22_col2" class="data row22 col2" >23</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row23_col0" class="data row23 col0" >T0830 - Eve CAVALIE</td>
#       <td id="T_46d5c_row23_col1" class="data row23 col1" >5.3</td>
#       <td id="T_46d5c_row23_col2" class="data row23 col2" >24</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row24_col0" class="data row24 col0" >T1640 - DIET Jean-François</td>
#       <td id="T_46d5c_row24_col1" class="data row24 col1" >5.3</td>
#       <td id="T_46d5c_row24_col2" class="data row24 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row25_col0" class="data row25 col0" >T0798 - Sophie FLAGEY LETONDAL</td>
#       <td id="T_46d5c_row25_col1" class="data row25 col1" >5.2</td>
#       <td id="T_46d5c_row25_col2" class="data row25 col2" >26</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row26_col0" class="data row26 col0" >T1360 - Guillaume BRUNEL - Pauline GAGNIERE</td>
#       <td id="T_46d5c_row26_col1" class="data row26 col1" >5.2</td>
#       <td id="T_46d5c_row26_col2" class="data row26 col2" >27</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row27_col0" class="data row27 col0" >T1327 - Anne TEKO GEIGER</td>
#       <td id="T_46d5c_row27_col1" class="data row27 col1" >5.2</td>
#       <td id="T_46d5c_row27_col2" class="data row27 col2" >27</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row28_col0" class="data row28 col0" >T1421 - Sandra BONDON</td>
#       <td id="T_46d5c_row28_col1" class="data row28 col1" >5.2</td>
#       <td id="T_46d5c_row28_col2" class="data row28 col2" >29</td>
#     </tr>
#     <tr>
#       <td id="T_46d5c_row29_col0" class="data row29 col0" >T1686 - SCM RHEA THERAPIE</td>
#       <td id="T_46d5c_row29_col1" class="data row29 col1" >5.2</td>
#       <td id="T_46d5c_row29_col2" class="data row29 col2" >29</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_per_days_90_days.head(30)['Nom du client'], display_30_best_clients_activity_per_days_90_days.head(30)['Nombre moyen séances par jours sur les 90 derniers jours'],  alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres moyen de séances par jours')
plt.title('Classement des 30 premiers clients européens en fonction du nombre moyen de séances par jour sur les 90 derniers jours')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # sur 1 an

# %%
# @title
display_30_best_clients_activity_per_days_year = sorted_activity_europe_50[sorted_activity_europe_50['number_days'] > 365][['full_name.1', 'activity_per_day_year', 'rank_activity_per_day_year']].sort_values(by=['activity_per_day_year'], ascending=False)
display_30_best_clients_activity_per_days_year = display_30_best_clients_activity_per_days_year.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_per_day_year': 'Nombre moyen séances par jours sur 1 an',
    'rank_activity_per_day_year' : 'Classement en fonction de l\'activité sur 1 an'
    })


#display(display_30_best_clients_activity_per_days_year.head(30).style.hide(axis='index'))
display(display_30_best_clients_activity_per_days_year.head(30).style.format({"Nombre moyen séances par jours sur 1 an": "{:.1f}"}).hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_a9e52">
#   <thead>
#     <tr>
#       <th id="T_a9e52_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_a9e52_level0_col1" class="col_heading level0 col1" >Nombre moyen séances par jours sur 1 an</th>
#       <th id="T_a9e52_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur 1 an</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a9e52_row0_col0" class="data row0 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_a9e52_row0_col1" class="data row0 col1" >25.3</td>
#       <td id="T_a9e52_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row1_col0" class="data row1 col0" >T0100 - Franck ARCHIMBAUD</td>
#       <td id="T_a9e52_row1_col1" class="data row1 col1" >18.3</td>
#       <td id="T_a9e52_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row2_col0" class="data row2 col0" >T0108 - UAB MEDA LT</td>
#       <td id="T_a9e52_row2_col1" class="data row2 col1" >15.7</td>
#       <td id="T_a9e52_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row3_col0" class="data row3 col0" >T0711 - KINE FLOW</td>
#       <td id="T_a9e52_row3_col1" class="data row3 col1" >12.2</td>
#       <td id="T_a9e52_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row4_col0" class="data row4 col0" >T0821 - PROKINETIC</td>
#       <td id="T_a9e52_row4_col1" class="data row4 col1" >11.3</td>
#       <td id="T_a9e52_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row5_col0" class="data row5 col0" >T0745 - Thibaut LEONE</td>
#       <td id="T_a9e52_row5_col1" class="data row5 col1" >10.4</td>
#       <td id="T_a9e52_row5_col2" class="data row5 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row6_col0" class="data row6 col0" >T0091 - Selarl MEDVASC 32</td>
#       <td id="T_a9e52_row6_col1" class="data row6 col1" >10.0</td>
#       <td id="T_a9e52_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row7_col0" class="data row7 col0" >T0689 - SCM KINE FORM'</td>
#       <td id="T_a9e52_row7_col1" class="data row7 col1" >9.6</td>
#       <td id="T_a9e52_row7_col2" class="data row7 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row8_col0" class="data row8 col0" >T1013 - Natalia BARTOSEK</td>
#       <td id="T_a9e52_row8_col1" class="data row8 col1" >8.2</td>
#       <td id="T_a9e52_row8_col2" class="data row8 col2" >9</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row9_col0" class="data row9 col0" >T1543 - SCM KINESIO</td>
#       <td id="T_a9e52_row9_col1" class="data row9 col1" >8.1</td>
#       <td id="T_a9e52_row9_col2" class="data row9 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row10_col0" class="data row10 col0" >T1464 - SCM BETTAN - BERDAL</td>
#       <td id="T_a9e52_row10_col1" class="data row10 col1" >7.9</td>
#       <td id="T_a9e52_row10_col2" class="data row10 col2" >11</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row11_col0" class="data row11 col0" >T1408 - Mandy ROURRET</td>
#       <td id="T_a9e52_row11_col1" class="data row11 col1" >7.8</td>
#       <td id="T_a9e52_row11_col2" class="data row11 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row12_col0" class="data row12 col0" >T1406 - SOCIETE GANIER-WILLEMS-RIGOT</td>
#       <td id="T_a9e52_row12_col1" class="data row12 col1" >7.5</td>
#       <td id="T_a9e52_row12_col2" class="data row12 col2" >13</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row13_col0" class="data row13 col0" >T1344 - Christine BERTERO BONNENFANT</td>
#       <td id="T_a9e52_row13_col1" class="data row13 col1" >7.2</td>
#       <td id="T_a9e52_row13_col2" class="data row13 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row14_col0" class="data row14 col0" >T0098 - CAPOT PHILIPPE </td>
#       <td id="T_a9e52_row14_col1" class="data row14 col1" >7.0</td>
#       <td id="T_a9e52_row14_col2" class="data row14 col2" >15</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row15_col0" class="data row15 col0" >T1354 - LES CURES MARINES</td>
#       <td id="T_a9e52_row15_col1" class="data row15 col1" >6.9</td>
#       <td id="T_a9e52_row15_col2" class="data row15 col2" >16</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row16_col0" class="data row16 col0" >T1421 - Sandra BONDON</td>
#       <td id="T_a9e52_row16_col1" class="data row16 col1" >6.3</td>
#       <td id="T_a9e52_row16_col2" class="data row16 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row17_col0" class="data row17 col0" >T1428 - 9298-5316 Québec Inc.</td>
#       <td id="T_a9e52_row17_col1" class="data row17 col1" >6.2</td>
#       <td id="T_a9e52_row17_col2" class="data row17 col2" >19</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row18_col0" class="data row18 col0" >T0798 - Sophie FLAGEY LETONDAL</td>
#       <td id="T_a9e52_row18_col1" class="data row18 col1" >6.2</td>
#       <td id="T_a9e52_row18_col2" class="data row18 col2" >19</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row19_col0" class="data row19 col0" >T1360 - Guillaume BRUNEL - Pauline GAGNIERE</td>
#       <td id="T_a9e52_row19_col1" class="data row19 col1" >6.1</td>
#       <td id="T_a9e52_row19_col2" class="data row19 col2" >21</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row20_col0" class="data row20 col0" >T0421 - SCM LAU ET CO</td>
#       <td id="T_a9e52_row20_col1" class="data row20 col1" >6.0</td>
#       <td id="T_a9e52_row20_col2" class="data row20 col2" >23</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row21_col0" class="data row21 col0" >T1507 - AXE KINE</td>
#       <td id="T_a9e52_row21_col1" class="data row21 col1" >6.0</td>
#       <td id="T_a9e52_row21_col2" class="data row21 col2" >24</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row22_col0" class="data row22 col0" >T0649 - Marie-Caroline CHARBONNIER MONTAUDIE</td>
#       <td id="T_a9e52_row22_col1" class="data row22 col1" >5.9</td>
#       <td id="T_a9e52_row22_col2" class="data row22 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row23_col0" class="data row23 col0" >T0820 - Nicolas BOCACCIO</td>
#       <td id="T_a9e52_row23_col1" class="data row23 col1" >5.9</td>
#       <td id="T_a9e52_row23_col2" class="data row23 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row24_col0" class="data row24 col0" >T1315 - SCM KINEFLEX</td>
#       <td id="T_a9e52_row24_col1" class="data row24 col1" >5.9</td>
#       <td id="T_a9e52_row24_col2" class="data row24 col2" >27</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row25_col0" class="data row25 col0" >T1410 - MAGIKTRADE</td>
#       <td id="T_a9e52_row25_col1" class="data row25 col1" >5.8</td>
#       <td id="T_a9e52_row25_col2" class="data row25 col2" >28</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row26_col0" class="data row26 col0" >T0139 - KIWI SANTE</td>
#       <td id="T_a9e52_row26_col1" class="data row26 col1" >5.8</td>
#       <td id="T_a9e52_row26_col2" class="data row26 col2" >29</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row27_col0" class="data row27 col0" >T0109 - Olivier BORTOLASO</td>
#       <td id="T_a9e52_row27_col1" class="data row27 col1" >5.8</td>
#       <td id="T_a9e52_row27_col2" class="data row27 col2" >29</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row28_col0" class="data row28 col0" >T0830 - Eve CAVALIE</td>
#       <td id="T_a9e52_row28_col1" class="data row28 col1" >5.7</td>
#       <td id="T_a9e52_row28_col2" class="data row28 col2" >31</td>
#     </tr>
#     <tr>
#       <td id="T_a9e52_row29_col0" class="data row29 col0" >T1488 - SCM KINES SANTE FORME</td>
#       <td id="T_a9e52_row29_col1" class="data row29 col1" >5.6</td>
#       <td id="T_a9e52_row29_col2" class="data row29 col2" >32</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_per_days_year.head(30)['Nom du client'], display_30_best_clients_activity_per_days_year.head(30)['Nombre moyen séances par jours sur 1 an'],  alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres moyen de séances par jours')
plt.title('Classement des 30 premiers clients européens en fonction du nombre moyen de séances par jour sur 1 an')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # Classement des 30 premiers clients européens en fonction du nombre de séances

# %% [markdown]
# # sur 7 jours

# %%
# @title
display_30_best_clients_activity_7_days = sorted_activity_europe_50[sorted_activity_europe_50['number_days'] > 7][['full_name.1', 'activity_last_7_days', 'rank_activity_7_days']].sort_values(by=['activity_last_7_days'], ascending=False)
display_30_best_clients_activity_7_days = display_30_best_clients_activity_7_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_last_7_days': 'Nombre de séances sur les 7 derniers jours',
    'rank_activity_7_days' : 'Classement en fonction de l\'activité sur les 7 derniers jours'
    })


display(display_30_best_clients_activity_7_days.head(30).style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_bf5c5">
#   <thead>
#     <tr>
#       <th id="T_bf5c5_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_bf5c5_level0_col1" class="col_heading level0 col1" >Nombre de séances sur les 7 derniers jours</th>
#       <th id="T_bf5c5_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur les 7 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bf5c5_row0_col0" class="data row0 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_bf5c5_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_bf5c5_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row1_col0" class="data row1 col0" >T0631 - KANZLSPERGER GmbH</td>
#       <td id="T_bf5c5_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_bf5c5_row1_col2" class="data row1 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row2_col0" class="data row2 col0" >T0762 - VOLANT SERVICES MANAGEMENT</td>
#       <td id="T_bf5c5_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_bf5c5_row2_col2" class="data row2 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row3_col0" class="data row3 col0" >T1769 - LEDEN LASER</td>
#       <td id="T_bf5c5_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_bf5c5_row3_col2" class="data row3 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row4_col0" class="data row4 col0" >T1817 - Laure GUIRAL</td>
#       <td id="T_bf5c5_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_bf5c5_row4_col2" class="data row4 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row5_col0" class="data row5 col0" >T1620 - PENSULA SL</td>
#       <td id="T_bf5c5_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_bf5c5_row5_col2" class="data row5 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row6_col0" class="data row6 col0" >T0806 - HOITOLA WOMAN</td>
#       <td id="T_bf5c5_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_bf5c5_row6_col2" class="data row6 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row7_col0" class="data row7 col0" >T1764 - Marion JENNY-SAUVEBOIS</td>
#       <td id="T_bf5c5_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_bf5c5_row7_col2" class="data row7 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row8_col0" class="data row8 col0" >T1390 - Zell Spa AG</td>
#       <td id="T_bf5c5_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_bf5c5_row8_col2" class="data row8 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row9_col0" class="data row9 col0" >T0142 - Myriam LAVOINE (Kiné 62)</td>
#       <td id="T_bf5c5_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_bf5c5_row9_col2" class="data row9 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row10_col0" class="data row10 col0" >T0530 - WYBO Frédéric</td>
#       <td id="T_bf5c5_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_bf5c5_row10_col2" class="data row10 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row11_col0" class="data row11 col0" >T0971 - MTR – Health & Spa AG</td>
#       <td id="T_bf5c5_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_bf5c5_row11_col2" class="data row11 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row12_col0" class="data row12 col0" >T0752 - DENTAL EQUIPEMENT</td>
#       <td id="T_bf5c5_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_bf5c5_row12_col2" class="data row12 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row13_col0" class="data row13 col0" >T1766 - Noémie PETIT</td>
#       <td id="T_bf5c5_row13_col1" class="data row13 col1" >0</td>
#       <td id="T_bf5c5_row13_col2" class="data row13 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row14_col0" class="data row14 col0" >T1226 - SARL CALI IMAGE</td>
#       <td id="T_bf5c5_row14_col1" class="data row14 col1" >0</td>
#       <td id="T_bf5c5_row14_col2" class="data row14 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row15_col0" class="data row15 col0" >T1742 - Cryopôle Caissargues</td>
#       <td id="T_bf5c5_row15_col1" class="data row15 col1" >0</td>
#       <td id="T_bf5c5_row15_col2" class="data row15 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row16_col0" class="data row16 col0" >T1588 - ACTIF BIEN ETRE SAS</td>
#       <td id="T_bf5c5_row16_col1" class="data row16 col1" >0</td>
#       <td id="T_bf5c5_row16_col2" class="data row16 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row17_col0" class="data row17 col0" >T0610 - Marro Joséphine</td>
#       <td id="T_bf5c5_row17_col1" class="data row17 col1" >0</td>
#       <td id="T_bf5c5_row17_col2" class="data row17 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row18_col0" class="data row18 col0" >T1523 - Helicia CHERUBIN</td>
#       <td id="T_bf5c5_row18_col1" class="data row18 col1" >0</td>
#       <td id="T_bf5c5_row18_col2" class="data row18 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row19_col0" class="data row19 col0" >T1811 - Christelle GUITARD</td>
#       <td id="T_bf5c5_row19_col1" class="data row19 col1" >0</td>
#       <td id="T_bf5c5_row19_col2" class="data row19 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row20_col0" class="data row20 col0" >T1661 - Barbora Jarosaite</td>
#       <td id="T_bf5c5_row20_col1" class="data row20 col1" >0</td>
#       <td id="T_bf5c5_row20_col2" class="data row20 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row21_col0" class="data row21 col0" >T0663 - CryoBodyForme</td>
#       <td id="T_bf5c5_row21_col1" class="data row21 col1" >0</td>
#       <td id="T_bf5c5_row21_col2" class="data row21 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row22_col0" class="data row22 col0" >T0389 - ESPACE BEAUTE NATURELLE</td>
#       <td id="T_bf5c5_row22_col1" class="data row22 col1" >0</td>
#       <td id="T_bf5c5_row22_col2" class="data row22 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row23_col0" class="data row23 col0" >T1708 - Edith CARTIER</td>
#       <td id="T_bf5c5_row23_col1" class="data row23 col1" >0</td>
#       <td id="T_bf5c5_row23_col2" class="data row23 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row24_col0" class="data row24 col0" >T1290 - DOBELMANN Didier</td>
#       <td id="T_bf5c5_row24_col1" class="data row24 col1" >0</td>
#       <td id="T_bf5c5_row24_col2" class="data row24 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row25_col0" class="data row25 col0" >T0624 - Beauty S.O.S. Inc.</td>
#       <td id="T_bf5c5_row25_col1" class="data row25 col1" >0</td>
#       <td id="T_bf5c5_row25_col2" class="data row25 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row26_col0" class="data row26 col0" >T0425 - OCCHIMINUTI Jean-Claude</td>
#       <td id="T_bf5c5_row26_col1" class="data row26 col1" >0</td>
#       <td id="T_bf5c5_row26_col2" class="data row26 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row27_col0" class="data row27 col0" >T1740 - MRH ZERMATT SA</td>
#       <td id="T_bf5c5_row27_col1" class="data row27 col1" >0</td>
#       <td id="T_bf5c5_row27_col2" class="data row27 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row28_col0" class="data row28 col0" >T1380 - VIVAESTHETIC</td>
#       <td id="T_bf5c5_row28_col1" class="data row28 col1" >0</td>
#       <td id="T_bf5c5_row28_col2" class="data row28 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_bf5c5_row29_col0" class="data row29 col0" >T1243 - Malang SANO</td>
#       <td id="T_bf5c5_row29_col1" class="data row29 col1" >0</td>
#       <td id="T_bf5c5_row29_col2" class="data row29 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_7_days.head(30)['Nom du client'], display_30_best_clients_activity_7_days.head(30)['Nombre de séances sur les 7 derniers jours'], alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres de séances par jours')
plt.title('Classement des 30 clients européens avec le plus de séances sur les 7 derniers jours')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # sur 14 jours

# %%
# @title
display_30_best_clients_activity_14_days = sorted_activity_europe_50[sorted_activity_europe_50['number_days'] > 14][['full_name.1', 'activity_last_14_days', 'rank_activity_14_days']].sort_values(by=['activity_last_14_days'], ascending=False)
display_30_best_clients_activity_14_days = display_30_best_clients_activity_14_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_last_14_days': 'Nombre de séances sur les 14 derniers jours',
    'rank_activity_14_days' : 'Classement en fonction de l\'activité sur les 14 derniers jours'
    })


display(display_30_best_clients_activity_14_days.head(30).style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_57c0d">
#   <thead>
#     <tr>
#       <th id="T_57c0d_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_57c0d_level0_col1" class="col_heading level0 col1" >Nombre de séances sur les 14 derniers jours</th>
#       <th id="T_57c0d_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur les 14 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_57c0d_row0_col0" class="data row0 col0" >T0108 - UAB MEDA LT</td>
#       <td id="T_57c0d_row0_col1" class="data row0 col1" >51</td>
#       <td id="T_57c0d_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row1_col0" class="data row1 col0" >T0821 - PROKINETIC</td>
#       <td id="T_57c0d_row1_col1" class="data row1 col1" >47</td>
#       <td id="T_57c0d_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row2_col0" class="data row2 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_57c0d_row2_col1" class="data row2 col1" >35</td>
#       <td id="T_57c0d_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row3_col0" class="data row3 col0" >T1680 - Laure GIULIANI</td>
#       <td id="T_57c0d_row3_col1" class="data row3 col1" >34</td>
#       <td id="T_57c0d_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row4_col0" class="data row4 col0" >T1354 - LES CURES MARINES</td>
#       <td id="T_57c0d_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_57c0d_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row5_col0" class="data row5 col0" >T1344 - Christine BERTERO BONNENFANT</td>
#       <td id="T_57c0d_row5_col1" class="data row5 col1" >26</td>
#       <td id="T_57c0d_row5_col2" class="data row5 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row6_col0" class="data row6 col0" >T0689 - SCM KINE FORM'</td>
#       <td id="T_57c0d_row6_col1" class="data row6 col1" >26</td>
#       <td id="T_57c0d_row6_col2" class="data row6 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row7_col0" class="data row7 col0" >T0711 - KINE FLOW</td>
#       <td id="T_57c0d_row7_col1" class="data row7 col1" >23</td>
#       <td id="T_57c0d_row7_col2" class="data row7 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row8_col0" class="data row8 col0" >T1543 - SCM KINESIO</td>
#       <td id="T_57c0d_row8_col1" class="data row8 col1" >23</td>
#       <td id="T_57c0d_row8_col2" class="data row8 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row9_col0" class="data row9 col0" >T0100 - Franck ARCHIMBAUD</td>
#       <td id="T_57c0d_row9_col1" class="data row9 col1" >22</td>
#       <td id="T_57c0d_row9_col2" class="data row9 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row10_col0" class="data row10 col0" >T0798 - Sophie FLAGEY LETONDAL</td>
#       <td id="T_57c0d_row10_col1" class="data row10 col1" >22</td>
#       <td id="T_57c0d_row10_col2" class="data row10 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row11_col0" class="data row11 col0" >T1640 - DIET Jean-François</td>
#       <td id="T_57c0d_row11_col1" class="data row11 col1" >21</td>
#       <td id="T_57c0d_row11_col2" class="data row11 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row12_col0" class="data row12 col0" >T1590 - Virginie L'HERMENIER</td>
#       <td id="T_57c0d_row12_col1" class="data row12 col1" >21</td>
#       <td id="T_57c0d_row12_col2" class="data row12 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row13_col0" class="data row13 col0" >T0098 - CAPOT PHILIPPE </td>
#       <td id="T_57c0d_row13_col1" class="data row13 col1" >20</td>
#       <td id="T_57c0d_row13_col2" class="data row13 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row14_col0" class="data row14 col0" >T0421 - SCM LAU ET CO</td>
#       <td id="T_57c0d_row14_col1" class="data row14 col1" >18</td>
#       <td id="T_57c0d_row14_col2" class="data row14 col2" >15</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row15_col0" class="data row15 col0" >T1428 - 9298-5316 Québec Inc.</td>
#       <td id="T_57c0d_row15_col1" class="data row15 col1" >18</td>
#       <td id="T_57c0d_row15_col2" class="data row15 col2" >15</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row16_col0" class="data row16 col0" >T1360 - Guillaume BRUNEL - Pauline GAGNIERE</td>
#       <td id="T_57c0d_row16_col1" class="data row16 col1" >17</td>
#       <td id="T_57c0d_row16_col2" class="data row16 col2" >17</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row17_col0" class="data row17 col0" >T1327 - Anne TEKO GEIGER</td>
#       <td id="T_57c0d_row17_col1" class="data row17 col1" >17</td>
#       <td id="T_57c0d_row17_col2" class="data row17 col2" >17</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row18_col0" class="data row18 col0" >T0792 - SCM TRIQUETRUM</td>
#       <td id="T_57c0d_row18_col1" class="data row18 col1" >16</td>
#       <td id="T_57c0d_row18_col2" class="data row18 col2" >19</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row19_col0" class="data row19 col0" >T0139 - KIWI SANTE</td>
#       <td id="T_57c0d_row19_col1" class="data row19 col1" >14</td>
#       <td id="T_57c0d_row19_col2" class="data row19 col2" >20</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row20_col0" class="data row20 col0" >T1814 - Isabelle NORET</td>
#       <td id="T_57c0d_row20_col1" class="data row20 col1" >14</td>
#       <td id="T_57c0d_row20_col2" class="data row20 col2" >20</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row21_col0" class="data row21 col0" >T0941 - Lionel BOUDON</td>
#       <td id="T_57c0d_row21_col1" class="data row21 col1" >13</td>
#       <td id="T_57c0d_row21_col2" class="data row21 col2" >22</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row22_col0" class="data row22 col0" >T1274 - STENDO BEAUTY AU</td>
#       <td id="T_57c0d_row22_col1" class="data row22 col1" >13</td>
#       <td id="T_57c0d_row22_col2" class="data row22 col2" >22</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row23_col0" class="data row23 col0" >T1538 - François MIGUEL</td>
#       <td id="T_57c0d_row23_col1" class="data row23 col1" >13</td>
#       <td id="T_57c0d_row23_col2" class="data row23 col2" >22</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row24_col0" class="data row24 col0" >T1757 - Cédric FORMET</td>
#       <td id="T_57c0d_row24_col1" class="data row24 col1" >12</td>
#       <td id="T_57c0d_row24_col2" class="data row24 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row25_col0" class="data row25 col0" >T1664 - ARK Cabinet de Kiné</td>
#       <td id="T_57c0d_row25_col1" class="data row25 col1" >12</td>
#       <td id="T_57c0d_row25_col2" class="data row25 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row26_col0" class="data row26 col0" >T0820 - Nicolas BOCACCIO</td>
#       <td id="T_57c0d_row26_col1" class="data row26 col1" >12</td>
#       <td id="T_57c0d_row26_col2" class="data row26 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row27_col0" class="data row27 col0" >T1754 - Christelle DUQUESNE</td>
#       <td id="T_57c0d_row27_col1" class="data row27 col1" >12</td>
#       <td id="T_57c0d_row27_col2" class="data row27 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row28_col0" class="data row28 col0" >T0385 - BATAILLE Maxime</td>
#       <td id="T_57c0d_row28_col1" class="data row28 col1" >11</td>
#       <td id="T_57c0d_row28_col2" class="data row28 col2" >29</td>
#     </tr>
#     <tr>
#       <td id="T_57c0d_row29_col0" class="data row29 col0" >T1697 - Stéphanie SANCHEZ</td>
#       <td id="T_57c0d_row29_col1" class="data row29 col1" >11</td>
#       <td id="T_57c0d_row29_col2" class="data row29 col2" >29</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_14_days.head(30)['Nom du client'], display_30_best_clients_activity_14_days.head(30)['Nombre de séances sur les 14 derniers jours'], alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres de séances par jours')
plt.title('Classement des 30 clients européens avec le plus de séances sur les 14 derniers jours')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # sur 30 jours

# %%
# @title
display_30_best_clients_activity_30_days = sorted_activity_europe_50[sorted_activity_europe_50['number_days'] > 30][['full_name.1', 'activity_last_30_days', 'rank_activity_30_days']].sort_values(by=['activity_last_30_days'], ascending=False)
display_30_best_clients_activity_30_days = display_30_best_clients_activity_30_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_last_30_days': 'Nombre de séances sur les 30 derniers jours',
    'rank_activity_30_days' : 'Classement en fonction de l\'activité sur les 30 derniers jours'
    })


display(display_30_best_clients_activity_30_days.head(30).style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_377a2">
#   <thead>
#     <tr>
#       <th id="T_377a2_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_377a2_level0_col1" class="col_heading level0 col1" >Nombre de séances sur les 30 derniers jours</th>
#       <th id="T_377a2_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur les 30 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_377a2_row0_col0" class="data row0 col0" >T0108 - UAB MEDA LT</td>
#       <td id="T_377a2_row0_col1" class="data row0 col1" >186</td>
#       <td id="T_377a2_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row1_col0" class="data row1 col0" >T0821 - PROKINETIC</td>
#       <td id="T_377a2_row1_col1" class="data row1 col1" >175</td>
#       <td id="T_377a2_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row2_col0" class="data row2 col0" >T1680 - Laure GIULIANI</td>
#       <td id="T_377a2_row2_col1" class="data row2 col1" >160</td>
#       <td id="T_377a2_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row3_col0" class="data row3 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_377a2_row3_col1" class="data row3 col1" >155</td>
#       <td id="T_377a2_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row4_col0" class="data row4 col0" >T0100 - Franck ARCHIMBAUD</td>
#       <td id="T_377a2_row4_col1" class="data row4 col1" >107</td>
#       <td id="T_377a2_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row5_col0" class="data row5 col0" >T0711 - KINE FLOW</td>
#       <td id="T_377a2_row5_col1" class="data row5 col1" >91</td>
#       <td id="T_377a2_row5_col2" class="data row5 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row6_col0" class="data row6 col0" >T1344 - Christine BERTERO BONNENFANT</td>
#       <td id="T_377a2_row6_col1" class="data row6 col1" >86</td>
#       <td id="T_377a2_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row7_col0" class="data row7 col0" >T1640 - DIET Jean-François</td>
#       <td id="T_377a2_row7_col1" class="data row7 col1" >84</td>
#       <td id="T_377a2_row7_col2" class="data row7 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row8_col0" class="data row8 col0" >T0689 - SCM KINE FORM'</td>
#       <td id="T_377a2_row8_col1" class="data row8 col1" >82</td>
#       <td id="T_377a2_row8_col2" class="data row8 col2" >9</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row9_col0" class="data row9 col0" >T1543 - SCM KINESIO</td>
#       <td id="T_377a2_row9_col1" class="data row9 col1" >81</td>
#       <td id="T_377a2_row9_col2" class="data row9 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row10_col0" class="data row10 col0" >T0792 - SCM TRIQUETRUM</td>
#       <td id="T_377a2_row10_col1" class="data row10 col1" >81</td>
#       <td id="T_377a2_row10_col2" class="data row10 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row11_col0" class="data row11 col0" >T0098 - CAPOT PHILIPPE </td>
#       <td id="T_377a2_row11_col1" class="data row11 col1" >78</td>
#       <td id="T_377a2_row11_col2" class="data row11 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row12_col0" class="data row12 col0" >T1013 - Natalia BARTOSEK</td>
#       <td id="T_377a2_row12_col1" class="data row12 col1" >78</td>
#       <td id="T_377a2_row12_col2" class="data row12 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row13_col0" class="data row13 col0" >T0798 - Sophie FLAGEY LETONDAL</td>
#       <td id="T_377a2_row13_col1" class="data row13 col1" >77</td>
#       <td id="T_377a2_row13_col2" class="data row13 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row14_col0" class="data row14 col0" >T1354 - LES CURES MARINES</td>
#       <td id="T_377a2_row14_col1" class="data row14 col1" >77</td>
#       <td id="T_377a2_row14_col2" class="data row14 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row15_col0" class="data row15 col0" >T1360 - Guillaume BRUNEL - Pauline GAGNIERE</td>
#       <td id="T_377a2_row15_col1" class="data row15 col1" >76</td>
#       <td id="T_377a2_row15_col2" class="data row15 col2" >16</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row16_col0" class="data row16 col0" >T1754 - Christelle DUQUESNE</td>
#       <td id="T_377a2_row16_col1" class="data row16 col1" >74</td>
#       <td id="T_377a2_row16_col2" class="data row16 col2" >17</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row17_col0" class="data row17 col0" >T1428 - 9298-5316 Québec Inc.</td>
#       <td id="T_377a2_row17_col1" class="data row17 col1" >69</td>
#       <td id="T_377a2_row17_col2" class="data row17 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row18_col0" class="data row18 col0" >T0421 - SCM LAU ET CO</td>
#       <td id="T_377a2_row18_col1" class="data row18 col1" >64</td>
#       <td id="T_377a2_row18_col2" class="data row18 col2" >19</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row19_col0" class="data row19 col0" >T0139 - KIWI SANTE</td>
#       <td id="T_377a2_row19_col1" class="data row19 col1" >62</td>
#       <td id="T_377a2_row19_col2" class="data row19 col2" >20</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row20_col0" class="data row20 col0" >T1590 - Virginie L'HERMENIER</td>
#       <td id="T_377a2_row20_col1" class="data row20 col1" >62</td>
#       <td id="T_377a2_row20_col2" class="data row20 col2" >20</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row21_col0" class="data row21 col0" >T0830 - Eve CAVALIE</td>
#       <td id="T_377a2_row21_col1" class="data row21 col1" >60</td>
#       <td id="T_377a2_row21_col2" class="data row21 col2" >22</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row22_col0" class="data row22 col0" >T1776 - Fanny LE GAL</td>
#       <td id="T_377a2_row22_col1" class="data row22 col1" >60</td>
#       <td id="T_377a2_row22_col2" class="data row22 col2" >22</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row23_col0" class="data row23 col0" >T1664 - ARK Cabinet de Kiné</td>
#       <td id="T_377a2_row23_col1" class="data row23 col1" >59</td>
#       <td id="T_377a2_row23_col2" class="data row23 col2" >24</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row24_col0" class="data row24 col0" >T0091 - Selarl MEDVASC 32</td>
#       <td id="T_377a2_row24_col1" class="data row24 col1" >56</td>
#       <td id="T_377a2_row24_col2" class="data row24 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row25_col0" class="data row25 col0" >T1421 - Sandra BONDON</td>
#       <td id="T_377a2_row25_col1" class="data row25 col1" >54</td>
#       <td id="T_377a2_row25_col2" class="data row25 col2" >26</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row26_col0" class="data row26 col0" >T1686 - SCM RHEA THERAPIE</td>
#       <td id="T_377a2_row26_col1" class="data row26 col1" >53</td>
#       <td id="T_377a2_row26_col2" class="data row26 col2" >27</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row27_col0" class="data row27 col0" >T1408 - Mandy ROURRET</td>
#       <td id="T_377a2_row27_col1" class="data row27 col1" >53</td>
#       <td id="T_377a2_row27_col2" class="data row27 col2" >27</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row28_col0" class="data row28 col0" >T1257 - Clinique du monde</td>
#       <td id="T_377a2_row28_col1" class="data row28 col1" >53</td>
#       <td id="T_377a2_row28_col2" class="data row28 col2" >27</td>
#     </tr>
#     <tr>
#       <td id="T_377a2_row29_col0" class="data row29 col0" >T0745 - Thibaut LEONE</td>
#       <td id="T_377a2_row29_col1" class="data row29 col1" >52</td>
#       <td id="T_377a2_row29_col2" class="data row29 col2" >30</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_30_days.head(30)['Nom du client'], display_30_best_clients_activity_30_days.head(30)['Nombre de séances sur les 30 derniers jours'], alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres de séances par jours')
plt.title('Classement des 30 clients européens avec le plus de séances sur les 30 derniers jours')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # sur 90 jours

# %%
# @title
display_30_best_clients_activity_90_days = sorted_activity_europe_50[sorted_activity_europe_50['number_days'] > 90][['full_name.1', 'activity_last_90_days', 'rank_activity_90_days']].sort_values(by=['activity_last_90_days'], ascending=False)
display_30_best_clients_activity_90_days = display_30_best_clients_activity_90_days.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_last_90_days': 'Nombre de séances sur les 90 derniers jours',
    'rank_activity_90_days' : 'Classement en fonction de l\'activité sur les 90 derniers jours'
    })


display(display_30_best_clients_activity_90_days.head(30).style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_277a2">
#   <thead>
#     <tr>
#       <th id="T_277a2_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_277a2_level0_col1" class="col_heading level0 col1" >Nombre de séances sur les 90 derniers jours</th>
#       <th id="T_277a2_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur les 90 derniers jours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_277a2_row0_col0" class="data row0 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_277a2_row0_col1" class="data row0 col1" >974</td>
#       <td id="T_277a2_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row1_col0" class="data row1 col0" >T0108 - UAB MEDA LT</td>
#       <td id="T_277a2_row1_col1" class="data row1 col1" >904</td>
#       <td id="T_277a2_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row2_col0" class="data row2 col0" >T0821 - PROKINETIC</td>
#       <td id="T_277a2_row2_col1" class="data row2 col1" >714</td>
#       <td id="T_277a2_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row3_col0" class="data row3 col0" >T1680 - Laure GIULIANI</td>
#       <td id="T_277a2_row3_col1" class="data row3 col1" >639</td>
#       <td id="T_277a2_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row4_col0" class="data row4 col0" >T0711 - KINE FLOW</td>
#       <td id="T_277a2_row4_col1" class="data row4 col1" >562</td>
#       <td id="T_277a2_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row5_col0" class="data row5 col0" >T0792 - SCM TRIQUETRUM</td>
#       <td id="T_277a2_row5_col1" class="data row5 col1" >555</td>
#       <td id="T_277a2_row5_col2" class="data row5 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row6_col0" class="data row6 col0" >T0100 - Franck ARCHIMBAUD</td>
#       <td id="T_277a2_row6_col1" class="data row6 col1" >552</td>
#       <td id="T_277a2_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row7_col0" class="data row7 col0" >T1344 - Christine BERTERO BONNENFANT</td>
#       <td id="T_277a2_row7_col1" class="data row7 col1" >500</td>
#       <td id="T_277a2_row7_col2" class="data row7 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row8_col0" class="data row8 col0" >T0689 - SCM KINE FORM'</td>
#       <td id="T_277a2_row8_col1" class="data row8 col1" >500</td>
#       <td id="T_277a2_row8_col2" class="data row8 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row9_col0" class="data row9 col0" >T0745 - Thibaut LEONE</td>
#       <td id="T_277a2_row9_col1" class="data row9 col1" >468</td>
#       <td id="T_277a2_row9_col2" class="data row9 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row10_col0" class="data row10 col0" >T1754 - Christelle DUQUESNE</td>
#       <td id="T_277a2_row10_col1" class="data row10 col1" >421</td>
#       <td id="T_277a2_row10_col2" class="data row10 col2" >11</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row11_col0" class="data row11 col0" >T1408 - Mandy ROURRET</td>
#       <td id="T_277a2_row11_col1" class="data row11 col1" >410</td>
#       <td id="T_277a2_row11_col2" class="data row11 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row12_col0" class="data row12 col0" >T1013 - Natalia BARTOSEK</td>
#       <td id="T_277a2_row12_col1" class="data row12 col1" >403</td>
#       <td id="T_277a2_row12_col2" class="data row12 col2" >13</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row13_col0" class="data row13 col0" >T1543 - SCM KINESIO</td>
#       <td id="T_277a2_row13_col1" class="data row13 col1" >384</td>
#       <td id="T_277a2_row13_col2" class="data row13 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row14_col0" class="data row14 col0" >T1354 - LES CURES MARINES</td>
#       <td id="T_277a2_row14_col1" class="data row14 col1" >381</td>
#       <td id="T_277a2_row14_col2" class="data row14 col2" >15</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row15_col0" class="data row15 col0" >T1464 - SCM BETTAN - BERDAL</td>
#       <td id="T_277a2_row15_col1" class="data row15 col1" >363</td>
#       <td id="T_277a2_row15_col2" class="data row15 col2" >16</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row16_col0" class="data row16 col0" >T1507 - AXE KINE</td>
#       <td id="T_277a2_row16_col1" class="data row16 col1" >361</td>
#       <td id="T_277a2_row16_col2" class="data row16 col2" >17</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row17_col0" class="data row17 col0" >T0098 - CAPOT PHILIPPE </td>
#       <td id="T_277a2_row17_col1" class="data row17 col1" >348</td>
#       <td id="T_277a2_row17_col2" class="data row17 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row18_col0" class="data row18 col0" >T1406 - SOCIETE GANIER-WILLEMS-RIGOT</td>
#       <td id="T_277a2_row18_col1" class="data row18 col1" >341</td>
#       <td id="T_277a2_row18_col2" class="data row18 col2" >19</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row19_col0" class="data row19 col0" >T1776 - Fanny LE GAL</td>
#       <td id="T_277a2_row19_col1" class="data row19 col1" >333</td>
#       <td id="T_277a2_row19_col2" class="data row19 col2" >20</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row20_col0" class="data row20 col0" >T0649 - Marie-Caroline CHARBONNIER MONTAUDIE</td>
#       <td id="T_277a2_row20_col1" class="data row20 col1" >327</td>
#       <td id="T_277a2_row20_col2" class="data row20 col2" >21</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row21_col0" class="data row21 col0" >T0385 - BATAILLE Maxime</td>
#       <td id="T_277a2_row21_col1" class="data row21 col1" >313</td>
#       <td id="T_277a2_row21_col2" class="data row21 col2" >22</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row22_col0" class="data row22 col0" >T1428 - 9298-5316 Québec Inc.</td>
#       <td id="T_277a2_row22_col1" class="data row22 col1" >295</td>
#       <td id="T_277a2_row22_col2" class="data row22 col2" >23</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row23_col0" class="data row23 col0" >T0830 - Eve CAVALIE</td>
#       <td id="T_277a2_row23_col1" class="data row23 col1" >292</td>
#       <td id="T_277a2_row23_col2" class="data row23 col2" >24</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row24_col0" class="data row24 col0" >T1640 - DIET Jean-François</td>
#       <td id="T_277a2_row24_col1" class="data row24 col1" >291</td>
#       <td id="T_277a2_row24_col2" class="data row24 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row25_col0" class="data row25 col0" >T0798 - Sophie FLAGEY LETONDAL</td>
#       <td id="T_277a2_row25_col1" class="data row25 col1" >287</td>
#       <td id="T_277a2_row25_col2" class="data row25 col2" >26</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row26_col0" class="data row26 col0" >T1360 - Guillaume BRUNEL - Pauline GAGNIERE</td>
#       <td id="T_277a2_row26_col1" class="data row26 col1" >286</td>
#       <td id="T_277a2_row26_col2" class="data row26 col2" >27</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row27_col0" class="data row27 col0" >T1327 - Anne TEKO GEIGER</td>
#       <td id="T_277a2_row27_col1" class="data row27 col1" >286</td>
#       <td id="T_277a2_row27_col2" class="data row27 col2" >27</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row28_col0" class="data row28 col0" >T1421 - Sandra BONDON</td>
#       <td id="T_277a2_row28_col1" class="data row28 col1" >283</td>
#       <td id="T_277a2_row28_col2" class="data row28 col2" >29</td>
#     </tr>
#     <tr>
#       <td id="T_277a2_row29_col0" class="data row29 col0" >T1686 - SCM RHEA THERAPIE</td>
#       <td id="T_277a2_row29_col1" class="data row29 col1" >283</td>
#       <td id="T_277a2_row29_col2" class="data row29 col2" >29</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_90_days.head(30)['Nom du client'], display_30_best_clients_activity_90_days.head(30)['Nombre de séances sur les 90 derniers jours'], alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres de séances par jours')
plt.title('Classement des 30 clients européens avec le plus de séances sur les 90 derniers jours')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # sur 1 an

# %%
# @title
display_30_best_clients_activity_year = sorted_activity_europe_50[sorted_activity_europe_50['number_days'] > 365][['full_name.1', 'activity_last_365_days', 'rank_activity_year']].sort_values(by=['activity_last_365_days'], ascending=False)
display_30_best_clients_activity_year = display_30_best_clients_activity_year.rename(columns={
    'full_name.1' : 'Nom du client',
    'activity_last_365_days': 'Nombre de séances sur 1 an',
    'rank_activity_year' : 'Classement en fonction de l\'activité sur 1 an'
    })


display(display_30_best_clients_activity_year.head(30).style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_e404a">
#   <thead>
#     <tr>
#       <th id="T_e404a_level0_col0" class="col_heading level0 col0" >Nom du client</th>
#       <th id="T_e404a_level0_col1" class="col_heading level0 col1" >Nombre de séances sur 1 an</th>
#       <th id="T_e404a_level0_col2" class="col_heading level0 col2" >Classement en fonction de l'activité sur 1 an</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e404a_row0_col0" class="data row0 col0" >T0613 - Aqua Kiné Santé</td>
#       <td id="T_e404a_row0_col1" class="data row0 col1" >5564</td>
#       <td id="T_e404a_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row1_col0" class="data row1 col0" >T0100 - Franck ARCHIMBAUD</td>
#       <td id="T_e404a_row1_col1" class="data row1 col1" >4026</td>
#       <td id="T_e404a_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row2_col0" class="data row2 col0" >T0108 - UAB MEDA LT</td>
#       <td id="T_e404a_row2_col1" class="data row2 col1" >3449</td>
#       <td id="T_e404a_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row3_col0" class="data row3 col0" >T0711 - KINE FLOW</td>
#       <td id="T_e404a_row3_col1" class="data row3 col1" >2677</td>
#       <td id="T_e404a_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row4_col0" class="data row4 col0" >T0821 - PROKINETIC</td>
#       <td id="T_e404a_row4_col1" class="data row4 col1" >2497</td>
#       <td id="T_e404a_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row5_col0" class="data row5 col0" >T0745 - Thibaut LEONE</td>
#       <td id="T_e404a_row5_col1" class="data row5 col1" >2285</td>
#       <td id="T_e404a_row5_col2" class="data row5 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row6_col0" class="data row6 col0" >T0091 - Selarl MEDVASC 32</td>
#       <td id="T_e404a_row6_col1" class="data row6 col1" >2193</td>
#       <td id="T_e404a_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row7_col0" class="data row7 col0" >T0689 - SCM KINE FORM'</td>
#       <td id="T_e404a_row7_col1" class="data row7 col1" >2104</td>
#       <td id="T_e404a_row7_col2" class="data row7 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row8_col0" class="data row8 col0" >T1013 - Natalia BARTOSEK</td>
#       <td id="T_e404a_row8_col1" class="data row8 col1" >1813</td>
#       <td id="T_e404a_row8_col2" class="data row8 col2" >9</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row9_col0" class="data row9 col0" >T1543 - SCM KINESIO</td>
#       <td id="T_e404a_row9_col1" class="data row9 col1" >1780</td>
#       <td id="T_e404a_row9_col2" class="data row9 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row10_col0" class="data row10 col0" >T1464 - SCM BETTAN - BERDAL</td>
#       <td id="T_e404a_row10_col1" class="data row10 col1" >1733</td>
#       <td id="T_e404a_row10_col2" class="data row10 col2" >11</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row11_col0" class="data row11 col0" >T1408 - Mandy ROURRET</td>
#       <td id="T_e404a_row11_col1" class="data row11 col1" >1710</td>
#       <td id="T_e404a_row11_col2" class="data row11 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row12_col0" class="data row12 col0" >T1406 - SOCIETE GANIER-WILLEMS-RIGOT</td>
#       <td id="T_e404a_row12_col1" class="data row12 col1" >1657</td>
#       <td id="T_e404a_row12_col2" class="data row12 col2" >13</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row13_col0" class="data row13 col0" >T1344 - Christine BERTERO BONNENFANT</td>
#       <td id="T_e404a_row13_col1" class="data row13 col1" >1575</td>
#       <td id="T_e404a_row13_col2" class="data row13 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row14_col0" class="data row14 col0" >T0098 - CAPOT PHILIPPE </td>
#       <td id="T_e404a_row14_col1" class="data row14 col1" >1535</td>
#       <td id="T_e404a_row14_col2" class="data row14 col2" >15</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row15_col0" class="data row15 col0" >T1354 - LES CURES MARINES</td>
#       <td id="T_e404a_row15_col1" class="data row15 col1" >1511</td>
#       <td id="T_e404a_row15_col2" class="data row15 col2" >16</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row16_col0" class="data row16 col0" >T1421 - Sandra BONDON</td>
#       <td id="T_e404a_row16_col1" class="data row16 col1" >1383</td>
#       <td id="T_e404a_row16_col2" class="data row16 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row17_col0" class="data row17 col0" >T1428 - 9298-5316 Québec Inc.</td>
#       <td id="T_e404a_row17_col1" class="data row17 col1" >1358</td>
#       <td id="T_e404a_row17_col2" class="data row17 col2" >19</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row18_col0" class="data row18 col0" >T0798 - Sophie FLAGEY LETONDAL</td>
#       <td id="T_e404a_row18_col1" class="data row18 col1" >1358</td>
#       <td id="T_e404a_row18_col2" class="data row18 col2" >19</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row19_col0" class="data row19 col0" >T1360 - Guillaume BRUNEL - Pauline GAGNIERE</td>
#       <td id="T_e404a_row19_col1" class="data row19 col1" >1348</td>
#       <td id="T_e404a_row19_col2" class="data row19 col2" >21</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row20_col0" class="data row20 col0" >T0421 - SCM LAU ET CO</td>
#       <td id="T_e404a_row20_col1" class="data row20 col1" >1327</td>
#       <td id="T_e404a_row20_col2" class="data row20 col2" >23</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row21_col0" class="data row21 col0" >T1507 - AXE KINE</td>
#       <td id="T_e404a_row21_col1" class="data row21 col1" >1319</td>
#       <td id="T_e404a_row21_col2" class="data row21 col2" >24</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row22_col0" class="data row22 col0" >T0649 - Marie-Caroline CHARBONNIER MONTAUDIE</td>
#       <td id="T_e404a_row22_col1" class="data row22 col1" >1304</td>
#       <td id="T_e404a_row22_col2" class="data row22 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row23_col0" class="data row23 col0" >T0820 - Nicolas BOCACCIO</td>
#       <td id="T_e404a_row23_col1" class="data row23 col1" >1304</td>
#       <td id="T_e404a_row23_col2" class="data row23 col2" >25</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row24_col0" class="data row24 col0" >T1315 - SCM KINEFLEX</td>
#       <td id="T_e404a_row24_col1" class="data row24 col1" >1296</td>
#       <td id="T_e404a_row24_col2" class="data row24 col2" >27</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row25_col0" class="data row25 col0" >T1410 - MAGIKTRADE</td>
#       <td id="T_e404a_row25_col1" class="data row25 col1" >1284</td>
#       <td id="T_e404a_row25_col2" class="data row25 col2" >28</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row26_col0" class="data row26 col0" >T0139 - KIWI SANTE</td>
#       <td id="T_e404a_row26_col1" class="data row26 col1" >1266</td>
#       <td id="T_e404a_row26_col2" class="data row26 col2" >29</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row27_col0" class="data row27 col0" >T0109 - Olivier BORTOLASO</td>
#       <td id="T_e404a_row27_col1" class="data row27 col1" >1265</td>
#       <td id="T_e404a_row27_col2" class="data row27 col2" >30</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row28_col0" class="data row28 col0" >T0830 - Eve CAVALIE</td>
#       <td id="T_e404a_row28_col1" class="data row28 col1" >1253</td>
#       <td id="T_e404a_row28_col2" class="data row28 col2" >31</td>
#     </tr>
#     <tr>
#       <td id="T_e404a_row29_col0" class="data row29 col0" >T1488 - SCM KINES SANTE FORME</td>
#       <td id="T_e404a_row29_col1" class="data row29 col1" >1233</td>
#       <td id="T_e404a_row29_col2" class="data row29 col2" >32</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(display_30_best_clients_activity_year.head(30)['Nom du client'], display_30_best_clients_activity_year.head(30)['Nombre de séances sur 1 an'], alpha=0.7)
plt.xlabel('Nom du client')
plt.ylabel('Nombres de séances par jours')
plt.title('Classement des 30 clients européens avec le plus de séances sur 1 an')
_ = plt.xticks(rotation=90)

# %% [markdown]
# # Tests sortie détails d'un client

# %%
# @title
# prompt: From the database sorted_activity_europe_50 display the following information:
# 1. The current date
# 2. The rank_activity_per_day of the full_name.1 called T0613 - Aqua Kiné Santé
# 3. The counts of the full_name.1 called T0613 - Aqua Kiné Santé
# 4. The activity_per_day of the full_name.1 called T0613 - Aqua Kiné Santé
# 5. The first_activity of the full_name.1 called T0613 - Aqua Kiné Santé
# 6. The last_activity of the full_name.1 called T0613 - Aqua Kiné Santé
# 7. The number_days of the full_name.1 called T0613 - Aqua Kiné Santé
# 8. The activity_last_7_days of the full_name.1 called T0613 - Aqua Kiné Santé
# 9. The activity_last_14_days of the full_name.1 called T0613 - Aqua Kiné Santé
# 10. The activity_last_30_days of the full_name.1 called T0613 - Aqua Kiné Santé

import datetime

# Assuming 'sorted_activity_europe_50' DataFrame is already available from the previous code

# Filter the DataFrame for the specific full_name.1
target_activity = sorted_activity_europe_50[sorted_activity_europe_50['full_name.1'] == 'T0613 - Aqua Kiné Santé']

if not target_activity.empty:
  current_date = datetime.date.today()
  rank = target_activity['rank_activity_per_day_since_acquisition'].iloc[0]
  counts = target_activity['counts'].iloc[0]
  activity_per_day = target_activity['activity_per_day_since_acquisition'].iloc[0]
  first_activity = target_activity['first_activity'].iloc[0]
  last_activity = target_activity['last_activity'].iloc[0]
  since_asquisition = target_activity['formatted_duration'].iloc[0]
  days_since_acquisition = target_activity['number_days'].iloc[0]
  activity_last_7_days = target_activity['activity_last_7_days'].iloc[0]
  activity_per_day_last_week = target_activity['activity_per_day_7_days'].iloc[0]
  rank_last_week = target_activity['rank_activity_7_days'].iloc[0]
  activity_last_14_days = target_activity['activity_last_14_days'].iloc[0]
  activity_per_day_last_2_week = target_activity['activity_per_day_14_days'].iloc[0]
  rank_last_2_week = target_activity['rank_activity_14_days'].iloc[0]
  activity_last_30_days = target_activity['activity_last_30_days'].iloc[0]
  activity_per_day_last_30_days = target_activity['activity_per_day_30_days'].iloc[0]
  rank_last_30_days = target_activity['rank_activity_30_days'].iloc[0]
  activity_last_90_days = target_activity['activity_last_90_days'].iloc[0]
  activity_per_day_last_90_days = target_activity['activity_per_day_90_days'].iloc[0]
  rank_last_90_days = target_activity['rank_activity_90_days'].iloc[0]
  activity_last_365_days = target_activity['activity_last_365_days'].iloc[0]
  activity_per_day_last_year = target_activity['activity_per_day_year'].iloc[0]
  rank_last_year = target_activity['rank_activity_year'].iloc[0]

  print('\033[1;4m' + "Détails pour le client T0613 - Aqua Kiné Santé:" + '\033[0m')
  print("\n")
  print(f"Date d\'aujourd\'hui: {current_date}")
  print(f"Date de la première séance: {first_activity}")
  print(f"Date de la dernière séance: {last_activity}")
  print(f"Première utilisation il y a: {since_asquisition} (ou {days_since_acquisition} jours)")
  print("\n")

  print('\033[1;4m' + "Stats sur les 7 derniers jours" + '\033[0m')
  if target_activity['number_days'].iloc[0] < 7:
    print("Première séance effectué il ya moins de 7 jours.")
  print(f"Nombres de séances: {activity_last_7_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_week}")
  print(f"Classement: {rank_last_week} ")

  print("\n")
  print('\033[1;4m' + "Stats sur les 14 derniers jours" + '\033[0m')
  if target_activity['number_days'].iloc[0] < 14:
    print("Première séance effectué il ya moins de 14 jours.")
  print(f"Nombres de séances: {activity_last_14_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_2_week}")
  print(f"Classement: {rank_last_2_week}")

  print("\n")
  print('\033[1;4m' + "Stats sur les 30 derniers jours" + '\033[0m')
  if target_activity['number_days'].iloc[0] < 30:
    print("Première séance effectué il ya moins de 30 jours.")
  print(f"Nombres de séances: {activity_last_30_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_30_days}")
  print(f"Classement: {rank_last_30_days}")
  print("\n")

  print('\033[1;4m' + "Stats sur les 90 derniers jours" + '\033[0m')
  if target_activity['number_days'].iloc[0] < 90:
    print("Première séance effectué il ya moins de 90 jours.")
  print(f"Nombres de séances: {activity_last_90_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_90_days}")
  print(f"Classement: {rank_last_90_days}")

  print("\n")
  print('\033[1;4m' + "Stats sur 1 an" + '\033[0m')
  if target_activity['number_days'].iloc[0] < 365:
    print("Première séance effectué il ya moins de 365 jours.")
  print(f"Nombres de séances: {activity_last_365_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_year}")
  print(f"Classement: {rank_last_year}")
  print("\n")

  print('\033[1;4m' + "Stats depuis l\'acquisition" + '\033[0m')
  print(f"Nombres de séances: {counts}")
  print(f"Nombres moyen de séances par jour: {activity_per_day}")
  print(f"Classement: {rank}")
else:
  print("T0613 - Aqua Kiné Santé not found in the database.")
# Out:
# Détails pour le client T0613 - Aqua Kiné Santé:
#
#
# Date d'aujourd'hui: 2025-01-14
# Date de la première séance: 2021-05-31 08:37:59
# Date de la dernière séance: 2025-01-06 14:29:11
# Première utilisation il y a: 3 an(s), 7 mois, 14 jour(s) (ou 1324 jours)
#
#
# Stats sur les 7 derniers jours
# Nombres de séances: 0
# Nombres de séances par jour: 0.0
# Classement: 1
#
#
# Stats sur les 14 derniers jours
# Nombres de séances: 35
# Nombres de séances par jour: 3.5
# Classement: 3
#
#
# Stats sur les 30 derniers jours
# Nombres de séances: 155
# Nombres de séances par jour: 7.75
# Classement: 4
#
#
# Stats sur les 90 derniers jours
# Nombres de séances: 974
# Nombres de séances par jour: 17.71
# Classement: 1
#
#
# Stats sur 1 an
# Nombres de séances: 5564
# Nombres de séances par jour: 25.29
# Classement: 1
#
#
# Stats depuis l'acquisition
# Nombres de séances: 21593
# Nombres moyen de séances par jour: 16.31
# Classement: 1

# %%
# @title
# prompt: From the database sorted_activity_europe_50 display the following information:
# 1. The current date
# 2. The rank_activity_per_day of the full_name.1 called T0613 - Aqua Kiné Santé
# 3. The counts of the full_name.1 called T0613 - Aqua Kiné Santé
# 4. The activity_per_day of the full_name.1 called T0613 - Aqua Kiné Santé
# 5. The first_activity of the full_name.1 called T0613 - Aqua Kiné Santé
# 6. The last_activity of the full_name.1 called T0613 - Aqua Kiné Santé
# 7. The number_days of the full_name.1 called T0613 - Aqua Kiné Santé
# 8. The activity_last_7_days of the full_name.1 called T0613 - Aqua Kiné Santé
# 9. The activity_last_14_days of the full_name.1 called T0613 - Aqua Kiné Santé
# 10. The activity_last_30_days of the full_name.1 called T0613 - Aqua Kiné Santé

import datetime

# Assuming 'sorted_activity_europe_50' DataFrame is already available from the previous code

# Filter the DataFrame for the specific full_name.1
target_activity = sorted_activity_europe_50[sorted_activity_europe_50['full_name.1'] == 'T0100 - Franck ARCHIMBAUD']

if not target_activity.empty:
  current_date = datetime.date.today()
  rank = target_activity['rank_activity_per_day_since_acquisition'].iloc[0]
  counts = target_activity['counts'].iloc[0]
  activity_per_day = target_activity['activity_per_day_since_acquisition'].iloc[0]
  first_activity = target_activity['first_activity'].iloc[0]
  last_activity = target_activity['last_activity'].iloc[0]
  since_asquisition = target_activity['formatted_duration'].iloc[0]
  days_since_acquisition = target_activity['number_days'].iloc[0]
  activity_last_7_days = target_activity['activity_last_7_days'].iloc[0]
  activity_per_day_last_week = target_activity['activity_per_day_7_days'].iloc[0]
  rank_last_week = target_activity['rank_activity_7_days'].iloc[0]
  activity_last_14_days = target_activity['activity_last_14_days'].iloc[0]
  activity_per_day_last_2_week = target_activity['activity_per_day_14_days'].iloc[0]
  rank_last_2_week = target_activity['rank_activity_14_days'].iloc[0]
  activity_last_30_days = target_activity['activity_last_30_days'].iloc[0]
  activity_per_day_last_30_days = target_activity['activity_per_day_30_days'].iloc[0]
  rank_last_30_days = target_activity['rank_activity_30_days'].iloc[0]
  activity_last_90_days = target_activity['activity_last_90_days'].iloc[0]
  activity_per_day_last_90_days = target_activity['activity_per_day_90_days'].iloc[0]
  rank_last_90_days = target_activity['rank_activity_90_days'].iloc[0]
  activity_last_365_days = target_activity['activity_last_365_days'].iloc[0]
  activity_per_day_last_year = target_activity['activity_per_day_year'].iloc[0]
  rank_last_year = target_activity['rank_activity_year'].iloc[0]

  print('\033[1;4m' + "Détails pour le client T0100 - Franck ARCHIMBAUD:" + '\033[0m')
  print("\n")
  print(f"Date d\'aujourd\'hui: {current_date}")
  print(f"Date de la première séance: {first_activity}")
  print(f"Date de la dernière séance: {last_activity}")
  print(f"Première utilisation il y a: {since_asquisition} (ou {days_since_acquisition} jours)")
  print("\n")

  print('\033[1;4m' + "Stats sur les 7 derniers jours" + '\033[0m')
  if target_activity['number_days'].iloc[0] < 7:
    print("Première séance effectué il ya moins de 7 jours.")
  print(f"Nombres de séances: {activity_last_7_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_week}")
  print(f"Classement: {rank_last_week} ")

  print("\n")
  print('\033[1;4m' + "Stats sur les 14 derniers jours" + '\033[0m')
  if target_activity['number_days'].iloc[0] < 14:
    print("Première séance effectué il ya moins de 14 jours.")
  print(f"Nombres de séances: {activity_last_14_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_2_week}")
  print(f"Classement: {rank_last_2_week}")

  print("\n")
  print('\033[1;4m' + "Stats sur les 30 derniers jours" + '\033[0m')
  if target_activity['number_days'].iloc[0] < 30:
    print("Première séance effectué il ya moins de 30 jours.")
  print(f"Nombres de séances: {activity_last_30_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_30_days}")
  print(f"Classement: {rank_last_30_days}")
  print("\n")

  print('\033[1;4m' + "Stats sur les 90 derniers jours" + '\033[0m')
  if target_activity['number_days'].iloc[0] < 90:
    print("Première séance effectué il ya moins de 90 jours.")
  print(f"Nombres de séances: {activity_last_90_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_90_days}")
  print(f"Classement: {rank_last_90_days}")

  print("\n")
  print('\033[1;4m' + "Stats sur 1 an" + '\033[0m')
  if target_activity['number_days'].iloc[0] < 365:
    print("Première séance effectué il ya moins de 365 jours.")
  print(f"Nombres de séances: {activity_last_365_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_year}")
  print(f"Classement: {rank_last_year}")
  print("\n")

  print('\033[1;4m' + "Stats depuis l\'acquisition" + '\033[0m')
  print(f"Nombres de séances: {counts}")
  print(f"Nombres moyen de séances par jour: {activity_per_day}")
  print(f"Classement: {rank}")
else:
  print("T0100 - Franck ARCHIMBAUD not found in the database.")
# Out:
# Détails pour le client T0100 - Franck ARCHIMBAUD:
#
#
# Date d'aujourd'hui: 2025-01-14
# Date de la première séance: 2020-02-10 16:07:32
# Date de la dernière séance: 2025-01-06 14:53:22
# Première utilisation il y a: 4 an(s), 11 mois, 4 jour(s) (ou 1800 jours)
#
#
# Stats sur les 7 derniers jours
# Nombres de séances: 0
# Nombres de séances par jour: 0.0
# Classement: 1
#
#
# Stats sur les 14 derniers jours
# Nombres de séances: 22
# Nombres de séances par jour: 2.2
# Classement: 10
#
#
# Stats sur les 30 derniers jours
# Nombres de séances: 107
# Nombres de séances par jour: 5.35
# Classement: 5
#
#
# Stats sur les 90 derniers jours
# Nombres de séances: 552
# Nombres de séances par jour: 10.04
# Classement: 7
#
#
# Stats sur 1 an
# Nombres de séances: 4026
# Nombres de séances par jour: 18.3
# Classement: 2
#
#
# Stats depuis l'acquisition
# Nombres de séances: 21681
# Nombres moyen de séances par jour: 12.04
# Classement: 2

# %%
# @title
# prompt: From the database sorted_activity_europe_50 display the following information:
# 1. The current date
# 2. The rank_activity_per_day of the full_name.1 called T0613 - Aqua Kiné Santé
# 3. The counts of the full_name.1 called T0613 - Aqua Kiné Santé
# 4. The activity_per_day of the full_name.1 called T0613 - Aqua Kiné Santé
# 5. The first_activity of the full_name.1 called T0613 - Aqua Kiné Santé
# 6. The last_activity of the full_name.1 called T0613 - Aqua Kiné Santé
# 7. The number_days of the full_name.1 called T0613 - Aqua Kiné Santé
# 8. The activity_last_7_days of the full_name.1 called T0613 - Aqua Kiné Santé
# 9. The activity_last_14_days of the full_name.1 called T0613 - Aqua Kiné Santé
# 10. The activity_last_30_days of the full_name.1 called T0613 - Aqua Kiné Santé

import datetime

# Assuming 'sorted_activity_europe_50' DataFrame is already available from the previous code

# Filter the DataFrame for the specific full_name.1
target_activity = sorted_activity_europe_50[sorted_activity_europe_50['full_name.1'] == 'T1680 - Laure GIULIANI']

if not target_activity.empty:
  current_date = datetime.date.today()
  rank = target_activity['rank_activity_per_day_since_acquisition'].iloc[0]
  counts = target_activity['counts'].iloc[0]
  activity_per_day = target_activity['activity_per_day_since_acquisition'].iloc[0]
  first_activity = target_activity['first_activity'].iloc[0]
  last_activity = target_activity['last_activity'].iloc[0]
  since_asquisition = target_activity['formatted_duration'].iloc[0]
  days_since_acquisition = target_activity['number_days'].iloc[0]
  activity_last_7_days = target_activity['activity_last_7_days'].iloc[0]
  activity_per_day_last_week = target_activity['activity_per_day_7_days'].iloc[0]
  rank_last_week = target_activity['rank_activity_7_days'].iloc[0]
  activity_last_14_days = target_activity['activity_last_14_days'].iloc[0]
  activity_per_day_last_2_week = target_activity['activity_per_day_14_days'].iloc[0]
  rank_last_2_week = target_activity['rank_activity_14_days'].iloc[0]
  activity_last_30_days = target_activity['activity_last_30_days'].iloc[0]
  activity_per_day_last_30_days = target_activity['activity_per_day_30_days'].iloc[0]
  rank_last_30_days = target_activity['rank_activity_30_days'].iloc[0]
  activity_last_90_days = target_activity['activity_last_90_days'].iloc[0]
  activity_per_day_last_90_days = target_activity['activity_per_day_90_days'].iloc[0]
  rank_last_90_days = target_activity['rank_activity_90_days'].iloc[0]
  activity_last_365_days = target_activity['activity_last_365_days'].iloc[0]
  activity_per_day_last_year = target_activity['activity_per_day_year'].iloc[0]
  rank_last_year = target_activity['rank_activity_year'].iloc[0]

  print('\033[1;4m' + "Détails pour le client T1680 - Laure GIULIANI:" + '\033[0m')
  print("\n")
  print(f"Date d\'aujourd\'hui: {current_date}")
  print(f"Date de la première séance: {first_activity}")
  print(f"Date de la dernière séance: {last_activity}")
  print(f"Première utilisation il y a: {since_asquisition} (ou {days_since_acquisition} jours)")
  print("\n")

  print('\033[1;4m' + "Stats sur les 7 derniers jours" + '\033[0m')
  if target_activity['number_days'].iloc[0] < 7:
    print("Première séance effectué il ya moins de 7 jours.")
  print(f"Nombres de séances: {activity_last_7_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_week}")
  print(f"Classement: {rank_last_week} ")

  print("\n")
  print('\033[1;4m' + "Stats sur les 14 derniers jours" + '\033[0m')
  if target_activity['number_days'].iloc[0] < 14:
    print("Première séance effectué il ya moins de 14 jours.")
  print(f"Nombres de séances: {activity_last_14_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_2_week}")
  print(f"Classement: {rank_last_2_week}")

  print("\n")
  print('\033[1;4m' + "Stats sur les 30 derniers jours" + '\033[0m')
  if target_activity['number_days'].iloc[0] < 30:
    print("Première séance effectué il ya moins de 30 jours.")
  print(f"Nombres de séances: {activity_last_30_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_30_days}")
  print(f"Classement: {rank_last_30_days}")
  print("\n")

  print('\033[1;4m' + "Stats sur les 90 derniers jours" + '\033[0m')
  if target_activity['number_days'].iloc[0] < 90:
    print("Première séance effectué il ya moins de 90 jours.")
  print(f"Nombres de séances: {activity_last_90_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_90_days}")
  print(f"Classement: {rank_last_90_days}")

  print("\n")
  print('\033[1;4m' + "Stats sur 1 an" + '\033[0m')
  if target_activity['number_days'].iloc[0] < 365:
    print("Première séance effectué il ya moins de 365 jours.")
  print(f"Nombres de séances: {activity_last_365_days}")
  print(f"Nombres de séances par jour: {activity_per_day_last_year}")
  print(f"Classement: {rank_last_year}")
  print("\n")

  print('\033[1;4m' + "Stats depuis l\'acquisition" + '\033[0m')
  print(f"Nombres de séances: {counts}")
  print(f"Nombres moyen de séances par jour: {activity_per_day}")
  print(f"Classement: {rank}")
else:
  print("T1680 - Laure GIULIANI not found in the database.")
# Out:
# Détails pour le client T1680 - Laure GIULIANI:
#
#
# Date d'aujourd'hui: 2025-01-14
# Date de la première séance: 2024-07-18 11:00:30
# Date de la dernière séance: 2025-01-06 14:26:00
# Première utilisation il y a: 0 an(s), 5 mois, 27 jour(s) (ou 180 jours)
#
#
# Stats sur les 7 derniers jours
# Nombres de séances: 0
# Nombres de séances par jour: 0.0
# Classement: 1
#
#
# Stats sur les 14 derniers jours
# Nombres de séances: 34
# Nombres de séances par jour: 3.4
# Classement: 4
#
#
# Stats sur les 30 derniers jours
# Nombres de séances: 160
# Nombres de séances par jour: 8.0
# Classement: 3
#
#
# Stats sur les 90 derniers jours
# Nombres de séances: 639
# Nombres de séances par jour: 11.62
# Classement: 4
#
#
# Stats sur 1 an
# Première séance effectué il ya moins de 365 jours.
# Nombres de séances: 1337
# Nombres de séances par jour: 6.08
# Classement: 22
#
#
# Stats depuis l'acquisition
# Nombres de séances: 1337
# Nombres moyen de séances par jour: 7.43
# Classement: 5
